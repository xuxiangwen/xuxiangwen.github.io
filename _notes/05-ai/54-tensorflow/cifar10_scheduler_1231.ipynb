# %% [markdown]
# ---
# title: Fashion MNIST
# categories: deep-learning
# date: 2020-12-15
# ---
#
#
# 数据集State-of-the-Art详见
#
# - [mnist](https://paperswithcode.com/sota/image-classification-on-mnist)
# - [fashion-mnist](https://paperswithcode.com/sota/image-classification-on-fashion-mnist)
# - [cifar-10](https://paperswithcode.com/sota/image-classification-on-cifar-10)
#
# ## 初始化
#
# 首先引入所用的包。然后是一些公共函数。下面代码比较长，可以先把函数的中文解释看过就好，细节忽略，后面用到再回来看。

# %%
import sys
import numpy as np
from tensorflow.keras import Model, layers, regularizers, preprocessing

base_path = '/tf/eipi10/xuxiangwen.github.io/_notes/05-ai/54-tensorflow/code'
sys.path.append(base_path)

from image_classification import set_gpu_memory, lr_schedule, image_data_generator 
from image_classification import ImageClassificationHelper, ImageDataset

set_gpu_memory(1024)
model_results={}

# 代码自动重新加载
# %load_ext autoreload
# %autoreload 2

# #当module有新的方法的时候，需要运行下面方法。
# %reload_ext autoreload
# Out:
# set max gpu memory to 1024

# %% [markdown]
# 下面初始化模型运行的参数。

# %%
params = {
    'dataset_name': 'cifar10',
    'validation_percent': 0,    
    'use_data_augmentation': False,
    'augmentation_generator': image_data_generator(),     
    'batch_size': 32,    
    'epochs': 120,    
    'learning_rate':0.001,
    'dropout':0.1,
    'metrics':['accuracy'], 
    'restore_best_checkpoint':True,
    'callbacks': {
        'ModelCheckpoint': {
            'enabled': True,
            'monitor': 'val_accuracy',               
        },
        'EarlyStopping': {
            'enabled': True,
            'patience': 40,   
            'monitor': 'val_accuracy',            
        },
        'ReduceLROnPlateau': {
            'enabled': True,
            'monitor': 'val_loss',
            'patience': 15,
            'factor': np.sqrt(0.1),            
        },
        'LearningRateScheduler': {
            'enabled': True,
            'schedule': lr_schedule,            
        }             
    },
    'model_params':{
        'mlp':{'dropout':0.1},
        'lenet':{'dropout':0.2},
        'custom':{'dropout':0.2},
        'vgg':{'dropout':0.4},
        'resnet':{}
    }
}

params = DictToObject(params)
helper = ImageClassificationHelper(params=params, 
                                   data=ImageDataset(params), 
                                   model_results=model_results)
# Out:
# load cifar10 data from source
# train: (50000, 32, 32, 3) (50000,)
# test: (10000, 32, 32, 3) (10000,)
# create train, validation and test dataset

# %%
# This is an example snippet!
# To create your own, add a new snippet block to the
# snippets.json file in your jupyter nbextensions directory:
# /nbextensions/snippets/snippets.json
import this

# %%
# This is an example snippet!
# To create your own, add a new snippet block to the
# snippets.json file in your jupyter nbextensions directory:
# /nbextensions/snippets/snippets.json
import this

# %% [markdown]
# ## 数据
#
# MNIST数据集包含60,000张training图片和10,000张test图片，每张图片由$28\times28$ 个像素点构成，每个像素点用一个灰度值(0−255)表示。下面查看一下其中的图片。

# %%
images, labels = iter(helper.data.train_dataset).next()
helper.show_images(images, labels, x_num=4, y_num=8, figsize=(12, 6))

# %% [markdown]
# 然后看看做了data augmentation的图片。

# %%
images, labels = helper.data.train_dataset_aug.next()
helper.show_images(images, labels, x_num=4, y_num=8, figsize=(12, 6))

# %% [markdown]
# 下面来看看各个class的数据分布。可以看到各个数字的分布还是比较均匀的。

# %%
helper.plot_distribution()

# %% [markdown]
# ## MLP

# %%
def get_mlp(helper, name='mlp', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name) 
    print('dropout={}'.format(dropout))
    
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Flatten()(input)
    x = layers.Dense(128, activation='relu')(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model

model = get_mlp(helper)
model.summary()
# Out:
# dropout=0.1
# learning_rate=0.001
# checkpoint_path=./checkpoints/cifar10/mlp/checkpoint
# Model: "mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               393344
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 394,634
# Trainable params: 394,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 下面来训练模型。

# %%
history = helper.train(model, epochs=helper.params.epochs)
# Out:
# 2020-12-31 08:02:08,194: INFO: start training
# use ModelCheckpoint(filepath=./checkpoints/cifar10/mlp/checkpoint, monitor=val_accuracy)
# use EarlyStopping(monitor=val_accuracy, patience=40)
# use ReduceLROnPlateau(monitor=val_loss, factor=0.31622776601683794, patience=15)
# use LearningRateScheduler()
# Epoch 1/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.9615 - accuracy: 0.2848 - val_loss: 1.8377 - val_accuracy: 0.3486
# Epoch 2/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.8625 - accuracy: 0.3204 - val_loss: 1.7833 - val_accuracy: 0.3590
# Epoch 3/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.8352 - accuracy: 0.3349 - val_loss: 1.7701 - val_accuracy: 0.3686
# Epoch 4/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.8123 - accuracy: 0.3375 - val_loss: 1.7692 - val_accuracy: 0.3657
# Epoch 5/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7993 - accuracy: 0.3435 - val_loss: 1.7395 - val_accuracy: 0.3825
# Epoch 6/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7906 - accuracy: 0.3464 - val_loss: 1.7097 - val_accuracy: 0.3881
# Epoch 7/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7854 - accuracy: 0.3513 - val_loss: 1.7339 - val_accuracy: 0.3756
# Epoch 8/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7788 - accuracy: 0.3528 - val_loss: 1.7349 - val_accuracy: 0.3692
# Epoch 9/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7770 - accuracy: 0.3529 - val_loss: 1.7267 - val_accuracy: 0.3784
# Epoch 10/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7708 - accuracy: 0.3550 - val_loss: 1.7138 - val_accuracy: 0.3793
# Epoch 11/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7665 - accuracy: 0.3570 - val_loss: 1.7115 - val_accuracy: 0.3824
# Epoch 12/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7626 - accuracy: 0.3587 - val_loss: 1.7127 - val_accuracy: 0.3809
# Epoch 13/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7643 - accuracy: 0.3576 - val_loss: 1.7150 - val_accuracy: 0.3772
# Epoch 14/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7592 - accuracy: 0.3592 - val_loss: 1.7093 - val_accuracy: 0.3780
# Epoch 15/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7564 - accuracy: 0.3602 - val_loss: 1.7182 - val_accuracy: 0.3818
# Epoch 16/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7560 - accuracy: 0.3618 - val_loss: 1.7200 - val_accuracy: 0.3799
# Epoch 17/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7508 - accuracy: 0.3624 - val_loss: 1.7038 - val_accuracy: 0.3792
# Epoch 18/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7515 - accuracy: 0.3644 - val_loss: 1.7331 - val_accuracy: 0.3662
# Epoch 19/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7491 - accuracy: 0.3646 - val_loss: 1.7111 - val_accuracy: 0.3808
# Epoch 20/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7485 - accuracy: 0.3662 - val_loss: 1.6992 - val_accuracy: 0.3866
# Epoch 21/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7518 - accuracy: 0.3635 - val_loss: 1.6926 - val_accuracy: 0.3873
# Epoch 22/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7465 - accuracy: 0.3655 - val_loss: 1.6849 - val_accuracy: 0.3971
# Epoch 23/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7465 - accuracy: 0.3671 - val_loss: 1.6825 - val_accuracy: 0.3898
# Epoch 24/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7404 - accuracy: 0.3665 - val_loss: 1.6932 - val_accuracy: 0.3859
# Epoch 25/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7399 - accuracy: 0.3648 - val_loss: 1.7032 - val_accuracy: 0.3822
# Epoch 26/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7402 - accuracy: 0.3664 - val_loss: 1.7026 - val_accuracy: 0.3800
# Epoch 27/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7388 - accuracy: 0.3675 - val_loss: 1.7155 - val_accuracy: 0.3747
# Epoch 28/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7391 - accuracy: 0.3686 - val_loss: 1.7156 - val_accuracy: 0.3772
# Epoch 29/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7335 - accuracy: 0.3708 - val_loss: 1.6812 - val_accuracy: 0.3968
# Epoch 30/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7334 - accuracy: 0.3705 - val_loss: 1.6969 - val_accuracy: 0.3880
# Epoch 31/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7355 - accuracy: 0.3696 - val_loss: 1.7159 - val_accuracy: 0.3664
# Epoch 32/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7347 - accuracy: 0.3706 - val_loss: 1.6882 - val_accuracy: 0.3845
# Epoch 33/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7282 - accuracy: 0.3719 - val_loss: 1.6942 - val_accuracy: 0.3893
# Epoch 34/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7338 - accuracy: 0.3709 - val_loss: 1.7118 - val_accuracy: 0.3762
# Epoch 35/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7330 - accuracy: 0.3704 - val_loss: 1.7269 - val_accuracy: 0.3609
# Epoch 36/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7295 - accuracy: 0.3701 - val_loss: 1.7179 - val_accuracy: 0.3737
# Epoch 37/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7320 - accuracy: 0.3728 - val_loss: 1.6870 - val_accuracy: 0.3866
# Epoch 38/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7256 - accuracy: 0.3720 - val_loss: 1.6893 - val_accuracy: 0.3878
# Epoch 39/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7253 - accuracy: 0.3709 - val_loss: 1.7072 - val_accuracy: 0.3849
# Epoch 40/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7298 - accuracy: 0.3682 - val_loss: 1.6868 - val_accuracy: 0.3879
# Epoch 41/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7252 - accuracy: 0.3745 - val_loss: 1.6976 - val_accuracy: 0.3881
# Epoch 42/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7253 - accuracy: 0.3718 - val_loss: 1.7207 - val_accuracy: 0.3698
# Epoch 43/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7280 - accuracy: 0.3727 - val_loss: 1.6941 - val_accuracy: 0.3968
# Epoch 44/120
# 1543/1562 [============================>.] - ETA: 0s - loss: 1.7222 - accuracy: 0.3724
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7230 - accuracy: 0.3722 - val_loss: 1.7058 - val_accuracy: 0.3732
# Epoch 00045: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 45/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6999 - accuracy: 0.3862 - val_loss: 1.6754 - val_accuracy: 0.3931
# Epoch 00046: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 46/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6941 - accuracy: 0.3856 - val_loss: 1.6789 - val_accuracy: 0.3954
# Epoch 00047: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 47/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.7005 - accuracy: 0.3841 - val_loss: 1.6805 - val_accuracy: 0.3891
# Epoch 00048: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 48/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6970 - accuracy: 0.3859 - val_loss: 1.6740 - val_accuracy: 0.3929
# Epoch 00049: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 49/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6975 - accuracy: 0.3847 - val_loss: 1.6825 - val_accuracy: 0.3893
# Epoch 00050: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 50/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6955 - accuracy: 0.3859 - val_loss: 1.6743 - val_accuracy: 0.3954
# Epoch 00051: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 51/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6975 - accuracy: 0.3841 - val_loss: 1.6766 - val_accuracy: 0.3921
# Epoch 00052: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 52/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6952 - accuracy: 0.3854 - val_loss: 1.6757 - val_accuracy: 0.3918
# Epoch 00053: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 53/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6954 - accuracy: 0.3845 - val_loss: 1.6773 - val_accuracy: 0.3937
# Epoch 00054: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 54/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6928 - accuracy: 0.3880 - val_loss: 1.6868 - val_accuracy: 0.3864
# Epoch 00055: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 55/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6896 - accuracy: 0.3864 - val_loss: 1.6845 - val_accuracy: 0.3979
# Epoch 00056: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 56/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6917 - accuracy: 0.3862 - val_loss: 1.6763 - val_accuracy: 0.3972
# Epoch 00057: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 57/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6942 - accuracy: 0.3872 - val_loss: 1.6772 - val_accuracy: 0.3887
# Epoch 00058: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 58/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6926 - accuracy: 0.3875 - val_loss: 1.6795 - val_accuracy: 0.3896
# Epoch 00059: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 59/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6929 - accuracy: 0.3867 - val_loss: 1.6865 - val_accuracy: 0.3871
# Epoch 00060: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 60/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6907 - accuracy: 0.3873 - val_loss: 1.6750 - val_accuracy: 0.3946
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001 from 0.0003162.
# Epoch 61/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6824 - accuracy: 0.3903 - val_loss: 1.6709 - val_accuracy: 0.3972
# Epoch 62/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6824 - accuracy: 0.3905 - val_loss: 1.6745 - val_accuracy: 0.3948
# Epoch 63/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6836 - accuracy: 0.3906 - val_loss: 1.6771 - val_accuracy: 0.3942
# Epoch 64/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6811 - accuracy: 0.3928 - val_loss: 1.6716 - val_accuracy: 0.3970
# Epoch 65/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6847 - accuracy: 0.3927 - val_loss: 1.6711 - val_accuracy: 0.3974
# Epoch 66/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6818 - accuracy: 0.3935 - val_loss: 1.6748 - val_accuracy: 0.3943
# Epoch 67/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6822 - accuracy: 0.3921 - val_loss: 1.6730 - val_accuracy: 0.3965
# Epoch 68/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6805 - accuracy: 0.3919 - val_loss: 1.6764 - val_accuracy: 0.3943
# Epoch 69/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6785 - accuracy: 0.3924 - val_loss: 1.6768 - val_accuracy: 0.3914
# Epoch 70/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6802 - accuracy: 0.3905 - val_loss: 1.6734 - val_accuracy: 0.3933
# Epoch 71/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6793 - accuracy: 0.3923 - val_loss: 1.6709 - val_accuracy: 0.3963
# Epoch 72/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6826 - accuracy: 0.3908 - val_loss: 1.6729 - val_accuracy: 0.3931
# Epoch 73/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6812 - accuracy: 0.3904 - val_loss: 1.6732 - val_accuracy: 0.3966
# Epoch 74/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6781 - accuracy: 0.3932 - val_loss: 1.6786 - val_accuracy: 0.3886
# Epoch 75/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6820 - accuracy: 0.3911 - val_loss: 1.6781 - val_accuracy: 0.3892
# Epoch 76/120
# 1549/1562 [============================>.] - ETA: 0s - loss: 1.6782 - accuracy: 0.3926
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6788 - accuracy: 0.3922 - val_loss: 1.6750 - val_accuracy: 0.3941
# Epoch 00077: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 77/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6791 - accuracy: 0.3900 - val_loss: 1.6724 - val_accuracy: 0.3958
# Epoch 00078: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 78/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6762 - accuracy: 0.3911 - val_loss: 1.6721 - val_accuracy: 0.3955
# Epoch 00079: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 79/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6782 - accuracy: 0.3918 - val_loss: 1.6722 - val_accuracy: 0.3947
# Epoch 00080: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 80/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6797 - accuracy: 0.3908 - val_loss: 1.6725 - val_accuracy: 0.3968
# Epoch 00081: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 81/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6752 - accuracy: 0.3930 - val_loss: 1.6730 - val_accuracy: 0.3939
# Epoch 00082: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 82/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6768 - accuracy: 0.3939 - val_loss: 1.6731 - val_accuracy: 0.3967
# Epoch 00083: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 83/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6761 - accuracy: 0.3920 - val_loss: 1.6717 - val_accuracy: 0.3949
# Epoch 00084: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 84/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6775 - accuracy: 0.3937 - val_loss: 1.6752 - val_accuracy: 0.3946
# Epoch 00085: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 85/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6748 - accuracy: 0.3947 - val_loss: 1.6723 - val_accuracy: 0.3946
# Epoch 00086: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 86/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6746 - accuracy: 0.3934 - val_loss: 1.6723 - val_accuracy: 0.3973
# Epoch 00087: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 87/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6744 - accuracy: 0.3933 - val_loss: 1.6737 - val_accuracy: 0.3967
# Epoch 00088: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 88/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6763 - accuracy: 0.3933 - val_loss: 1.6747 - val_accuracy: 0.3950
# Epoch 00089: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 89/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6738 - accuracy: 0.3925 - val_loss: 1.6735 - val_accuracy: 0.3952
# Epoch 00090: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 90/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6752 - accuracy: 0.3942 - val_loss: 1.6721 - val_accuracy: 0.3984
# Epoch 00091: LearningRateScheduler reducing learning rate to 1e-05 from 3.16e-05.
# Epoch 91/120
# 1542/1562 [============================>.] - ETA: 0s - loss: 1.6763 - accuracy: 0.3930
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 3.1622775802825263e-06.
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6758 - accuracy: 0.3932 - val_loss: 1.6732 - val_accuracy: 0.3963
# Epoch 00092: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 92/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6741 - accuracy: 0.3953 - val_loss: 1.6719 - val_accuracy: 0.3968
# Epoch 00093: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 93/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6731 - accuracy: 0.3970 - val_loss: 1.6721 - val_accuracy: 0.3962
# Epoch 00094: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 94/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6746 - accuracy: 0.3938 - val_loss: 1.6719 - val_accuracy: 0.3965
# Epoch 00095: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 95/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6772 - accuracy: 0.3928 - val_loss: 1.6719 - val_accuracy: 0.3969
# Epoch 00096: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 96/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6721 - accuracy: 0.3955 - val_loss: 1.6720 - val_accuracy: 0.3972
# Epoch 00097: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 97/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6760 - accuracy: 0.3951 - val_loss: 1.6721 - val_accuracy: 0.3966
# Epoch 00098: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 98/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6765 - accuracy: 0.3939 - val_loss: 1.6724 - val_accuracy: 0.3976
# Epoch 00099: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 99/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6759 - accuracy: 0.3913 - val_loss: 1.6725 - val_accuracy: 0.3977
# Epoch 00100: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 100/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6755 - accuracy: 0.3942 - val_loss: 1.6720 - val_accuracy: 0.3965
# Epoch 00101: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 101/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6747 - accuracy: 0.3957 - val_loss: 1.6721 - val_accuracy: 0.3967
# Epoch 00102: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 102/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6734 - accuracy: 0.3943 - val_loss: 1.6722 - val_accuracy: 0.3968
# Epoch 00103: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 103/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6774 - accuracy: 0.3917 - val_loss: 1.6723 - val_accuracy: 0.3970
# Epoch 00104: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 104/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6764 - accuracy: 0.3927 - val_loss: 1.6723 - val_accuracy: 0.3968
# Epoch 00105: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 105/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6739 - accuracy: 0.3939 - val_loss: 1.6723 - val_accuracy: 0.3961
# Epoch 00106: LearningRateScheduler reducing learning rate to 1e-06 from 3.2e-06.
# Epoch 106/120
# 1553/1562 [============================>.] - ETA: 0s - loss: 1.6732 - accuracy: 0.3941
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 5e-07.
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6733 - accuracy: 0.3938 - val_loss: 1.6722 - val_accuracy: 0.3967
# Epoch 00107: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 107/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6732 - accuracy: 0.3956 - val_loss: 1.6722 - val_accuracy: 0.3971
# Epoch 00108: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 108/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6744 - accuracy: 0.3941 - val_loss: 1.6721 - val_accuracy: 0.3966
# Epoch 00109: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 109/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6734 - accuracy: 0.3941 - val_loss: 1.6722 - val_accuracy: 0.3969
# Epoch 00110: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 110/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6732 - accuracy: 0.3946 - val_loss: 1.6721 - val_accuracy: 0.3971
# Epoch 00111: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 111/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6733 - accuracy: 0.3948 - val_loss: 1.6721 - val_accuracy: 0.3974
# Epoch 00112: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 112/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6730 - accuracy: 0.3941 - val_loss: 1.6721 - val_accuracy: 0.3973
# Epoch 00113: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 113/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6756 - accuracy: 0.3933 - val_loss: 1.6721 - val_accuracy: 0.3974
# Epoch 00114: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 114/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6746 - accuracy: 0.3951 - val_loss: 1.6721 - val_accuracy: 0.3972
# Epoch 00115: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 115/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6749 - accuracy: 0.3946 - val_loss: 1.6721 - val_accuracy: 0.3974
# Epoch 00116: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 116/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6719 - accuracy: 0.3961 - val_loss: 1.6721 - val_accuracy: 0.3975
# Epoch 00117: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 117/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6751 - accuracy: 0.3939 - val_loss: 1.6721 - val_accuracy: 0.3971
# Epoch 00118: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 118/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6766 - accuracy: 0.3932 - val_loss: 1.6721 - val_accuracy: 0.3971
# Epoch 00119: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 119/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6748 - accuracy: 0.3941 - val_loss: 1.6721 - val_accuracy: 0.3971
# Epoch 00120: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 120/120
# 1562/1562 [==============================] - 4s 2ms/step - loss: 1.6738 - accuracy: 0.3953 - val_loss: 1.6721 - val_accuracy: 0.3972
# 2020-12-31 08:11:18,674: INFO: finish training [elapsed time: 550.48 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:1.6721, Test Accuracy:39.84%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#      train_loss  train_accuracy  test_loss  test_accuracy  weight_number  \
# mlp    1.594395          0.4305    1.67206         0.3984         394634
#
#      train_time
# mlp       550.0

# %% [markdown]
# 从上面的错误来看，模型对一些细节的判断不是很准。下面来尝试一下LeNet。
#
# ## LeNet
#
# ![image-20201019113632136](images/image-20201019113632136.png)
#
# LeNet诞生于1994年，是Yann LeCun等人提出的，是最早的卷积神经网络之一。在LeNet中，输入层是32×32的图片，而MNIST是28×28的图片，为了保持模型的结构不变，在第一个Conv2D设置参数padding=’same’。首先创建模型，并训练。

# %%
def get_lenet(helper, name='lenet', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name) 
    print('dropout={}'.format(dropout))
    
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Conv2D(6, (5, 5), activation='relu', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(16, (5, 5), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)   
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(120, activation='relu')(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(84, activation='relu')(x)   
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)  

    return model    

# 创建模型
model = get_lenet(helper)
model.summary()
# Out:
# dropout=0.2
# learning_rate=0.001
# checkpoint_path=./checkpoints/cifar10/lenet/checkpoint
# Model: "lenet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 6)         456
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 6)         24
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 6)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 16)        2416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 12, 12, 16)        64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 16)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               69240
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 84)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                850
# =================================================================
# Total params: 83,214
# Trainable params: 83,170
# Non-trainable params: 44
# _________________________________________________________________

# %% [markdown]
# 下面来训练模型。

# %%
# 训练
history = helper.train(model, epochs=helper.params.epochs)
# Out:
# 2020-12-31 08:11:27,706: INFO: start training
# use ModelCheckpoint(filepath=./checkpoints/cifar10/lenet/checkpoint, monitor=val_accuracy)
# use EarlyStopping(monitor=val_accuracy, patience=40)
# use ReduceLROnPlateau(monitor=val_loss, factor=0.31622776601683794, patience=15)
# use LearningRateScheduler()
# Epoch 1/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.7150 - accuracy: 0.3731 - val_loss: 1.4573 - val_accuracy: 0.4709
# Epoch 2/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.4350 - accuracy: 0.4846 - val_loss: 1.2605 - val_accuracy: 0.5445
# Epoch 3/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.3363 - accuracy: 0.5192 - val_loss: 1.4299 - val_accuracy: 0.4824
# Epoch 4/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.2771 - accuracy: 0.5431 - val_loss: 1.3957 - val_accuracy: 0.5123
# Epoch 5/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.2306 - accuracy: 0.5624 - val_loss: 1.4276 - val_accuracy: 0.4882
# Epoch 6/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.2009 - accuracy: 0.5733 - val_loss: 1.0957 - val_accuracy: 0.6071
# Epoch 7/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.1603 - accuracy: 0.5882 - val_loss: 1.0373 - val_accuracy: 0.6233
# Epoch 8/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.1385 - accuracy: 0.5969 - val_loss: 1.0259 - val_accuracy: 0.6323
# Epoch 9/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.1127 - accuracy: 0.6052 - val_loss: 1.1205 - val_accuracy: 0.6030
# Epoch 10/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0934 - accuracy: 0.6139 - val_loss: 1.1017 - val_accuracy: 0.6117
# Epoch 11/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0781 - accuracy: 0.6192 - val_loss: 1.0130 - val_accuracy: 0.6431
# Epoch 12/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0643 - accuracy: 0.6231 - val_loss: 1.0735 - val_accuracy: 0.6183
# Epoch 13/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0494 - accuracy: 0.6286 - val_loss: 0.9937 - val_accuracy: 0.6461
# Epoch 14/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0362 - accuracy: 0.6330 - val_loss: 1.2752 - val_accuracy: 0.5605
# Epoch 15/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0182 - accuracy: 0.6403 - val_loss: 1.0255 - val_accuracy: 0.6379
# Epoch 16/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0151 - accuracy: 0.6414 - val_loss: 0.9443 - val_accuracy: 0.6633
# Epoch 17/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0015 - accuracy: 0.6472 - val_loss: 0.9471 - val_accuracy: 0.6645
# Epoch 18/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9877 - accuracy: 0.6505 - val_loss: 0.9419 - val_accuracy: 0.6642
# Epoch 19/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9805 - accuracy: 0.6544 - val_loss: 1.1087 - val_accuracy: 0.6190
# Epoch 20/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9707 - accuracy: 0.6592 - val_loss: 0.9207 - val_accuracy: 0.6736
# Epoch 21/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9655 - accuracy: 0.6600 - val_loss: 0.9444 - val_accuracy: 0.6661
# Epoch 22/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9567 - accuracy: 0.6625 - val_loss: 0.9317 - val_accuracy: 0.6741
# Epoch 23/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9549 - accuracy: 0.6656 - val_loss: 0.9188 - val_accuracy: 0.6757
# Epoch 24/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9427 - accuracy: 0.6653 - val_loss: 0.8937 - val_accuracy: 0.6843
# Epoch 25/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9368 - accuracy: 0.6691 - val_loss: 0.9504 - val_accuracy: 0.6688
# Epoch 26/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9230 - accuracy: 0.6763 - val_loss: 0.8920 - val_accuracy: 0.6887
# Epoch 27/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9247 - accuracy: 0.6737 - val_loss: 0.8960 - val_accuracy: 0.6821
# Epoch 28/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9119 - accuracy: 0.6811 - val_loss: 0.8825 - val_accuracy: 0.6923
# Epoch 29/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9075 - accuracy: 0.6830 - val_loss: 0.8947 - val_accuracy: 0.6857
# Epoch 30/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9047 - accuracy: 0.6839 - val_loss: 1.0227 - val_accuracy: 0.6429
# Epoch 31/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8978 - accuracy: 0.6850 - val_loss: 1.0979 - val_accuracy: 0.6248
# Epoch 32/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8885 - accuracy: 0.6839 - val_loss: 0.8777 - val_accuracy: 0.6915
# Epoch 33/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8880 - accuracy: 0.6874 - val_loss: 0.8846 - val_accuracy: 0.6915
# Epoch 34/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8839 - accuracy: 0.6895 - val_loss: 0.8631 - val_accuracy: 0.6959
# Epoch 35/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8761 - accuracy: 0.6892 - val_loss: 0.9747 - val_accuracy: 0.6611
# Epoch 36/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8756 - accuracy: 0.6925 - val_loss: 0.8957 - val_accuracy: 0.6915
# Epoch 37/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8736 - accuracy: 0.6912 - val_loss: 0.8741 - val_accuracy: 0.6940
# Epoch 38/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8673 - accuracy: 0.6963 - val_loss: 0.8497 - val_accuracy: 0.7020
# Epoch 39/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8615 - accuracy: 0.6963 - val_loss: 0.8791 - val_accuracy: 0.6889
# Epoch 40/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8627 - accuracy: 0.6981 - val_loss: 0.9221 - val_accuracy: 0.6784
# Epoch 41/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8554 - accuracy: 0.6990 - val_loss: 1.0015 - val_accuracy: 0.6519
# Epoch 42/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8582 - accuracy: 0.6986 - val_loss: 0.9042 - val_accuracy: 0.6832
# Epoch 43/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8549 - accuracy: 0.6993 - val_loss: 0.8416 - val_accuracy: 0.7049
# Epoch 44/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8478 - accuracy: 0.7037 - val_loss: 0.9906 - val_accuracy: 0.6548
# Epoch 45/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8485 - accuracy: 0.7028 - val_loss: 0.8483 - val_accuracy: 0.7050
# Epoch 46/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8460 - accuracy: 0.7019 - val_loss: 0.8819 - val_accuracy: 0.6948
# Epoch 47/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8433 - accuracy: 0.7030 - val_loss: 0.8523 - val_accuracy: 0.7018
# Epoch 48/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8439 - accuracy: 0.7048 - val_loss: 0.9236 - val_accuracy: 0.6791
# Epoch 49/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8424 - accuracy: 0.7038 - val_loss: 0.8570 - val_accuracy: 0.7001
# Epoch 50/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8370 - accuracy: 0.7071 - val_loss: 0.9599 - val_accuracy: 0.6622
# Epoch 51/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8319 - accuracy: 0.7094 - val_loss: 0.9156 - val_accuracy: 0.6857
# Epoch 52/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8378 - accuracy: 0.7072 - val_loss: 0.8402 - val_accuracy: 0.7065
# Epoch 53/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8282 - accuracy: 0.7086 - val_loss: 0.8695 - val_accuracy: 0.6949
# Epoch 54/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8306 - accuracy: 0.7065 - val_loss: 0.8296 - val_accuracy: 0.7076
# Epoch 55/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8207 - accuracy: 0.7092 - val_loss: 0.8220 - val_accuracy: 0.7113
# Epoch 56/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8222 - accuracy: 0.7125 - val_loss: 0.8380 - val_accuracy: 0.7064
# Epoch 57/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8251 - accuracy: 0.7094 - val_loss: 0.8580 - val_accuracy: 0.6999
# Epoch 58/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8277 - accuracy: 0.7118 - val_loss: 0.9032 - val_accuracy: 0.6809
# Epoch 59/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8144 - accuracy: 0.7132 - val_loss: 0.8416 - val_accuracy: 0.7063
# Epoch 60/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8154 - accuracy: 0.7131 - val_loss: 0.8138 - val_accuracy: 0.7176
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001 from 0.001.
# Epoch 61/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7785 - accuracy: 0.7266 - val_loss: 0.8362 - val_accuracy: 0.7085
# Epoch 62/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7668 - accuracy: 0.7308 - val_loss: 0.8109 - val_accuracy: 0.7196
# Epoch 63/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7627 - accuracy: 0.7315 - val_loss: 0.7976 - val_accuracy: 0.7231
# Epoch 64/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7675 - accuracy: 0.7288 - val_loss: 0.7917 - val_accuracy: 0.7242
# Epoch 65/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7574 - accuracy: 0.7329 - val_loss: 0.8129 - val_accuracy: 0.7160
# Epoch 66/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7599 - accuracy: 0.7315 - val_loss: 0.8003 - val_accuracy: 0.7210
# Epoch 67/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7588 - accuracy: 0.7322 - val_loss: 0.7977 - val_accuracy: 0.7228
# Epoch 68/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7596 - accuracy: 0.7334 - val_loss: 0.8156 - val_accuracy: 0.7161
# Epoch 69/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7581 - accuracy: 0.7322 - val_loss: 0.7926 - val_accuracy: 0.7242
# Epoch 70/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7543 - accuracy: 0.7346 - val_loss: 0.8029 - val_accuracy: 0.7214
# Epoch 71/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7533 - accuracy: 0.7334 - val_loss: 0.7966 - val_accuracy: 0.7232
# Epoch 72/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7588 - accuracy: 0.7332 - val_loss: 0.7923 - val_accuracy: 0.7245
# Epoch 73/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7587 - accuracy: 0.7326 - val_loss: 0.8181 - val_accuracy: 0.7157
# Epoch 74/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7524 - accuracy: 0.7337 - val_loss: 0.7945 - val_accuracy: 0.7236
# Epoch 75/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7512 - accuracy: 0.7355 - val_loss: 0.7931 - val_accuracy: 0.7228
# Epoch 76/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7471 - accuracy: 0.7380 - val_loss: 0.7902 - val_accuracy: 0.7238
# Epoch 77/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7478 - accuracy: 0.7375 - val_loss: 0.7924 - val_accuracy: 0.7258
# Epoch 78/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7515 - accuracy: 0.7371 - val_loss: 0.7973 - val_accuracy: 0.7234
# Epoch 79/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7471 - accuracy: 0.7380 - val_loss: 0.7961 - val_accuracy: 0.7240
# Epoch 80/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7403 - accuracy: 0.7401 - val_loss: 0.8031 - val_accuracy: 0.7228
# Epoch 81/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7498 - accuracy: 0.7364 - val_loss: 0.7980 - val_accuracy: 0.7245
# Epoch 82/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7492 - accuracy: 0.7348 - val_loss: 0.7874 - val_accuracy: 0.7272
# Epoch 83/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7440 - accuracy: 0.7375 - val_loss: 0.7834 - val_accuracy: 0.7274
# Epoch 84/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7499 - accuracy: 0.7356 - val_loss: 0.7816 - val_accuracy: 0.7271
# Epoch 85/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7477 - accuracy: 0.7381 - val_loss: 0.7841 - val_accuracy: 0.7267
# Epoch 86/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7466 - accuracy: 0.7362 - val_loss: 0.7952 - val_accuracy: 0.7243
# Epoch 87/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7417 - accuracy: 0.7381 - val_loss: 0.8064 - val_accuracy: 0.7204
# Epoch 88/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7472 - accuracy: 0.7371 - val_loss: 0.7882 - val_accuracy: 0.7279
# Epoch 89/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7414 - accuracy: 0.7409 - val_loss: 0.7841 - val_accuracy: 0.7287
# Epoch 90/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7439 - accuracy: 0.7376 - val_loss: 0.7892 - val_accuracy: 0.7273
# Epoch 00091: LearningRateScheduler reducing learning rate to 1e-05 from 0.0001.
# Epoch 91/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7406 - accuracy: 0.7379 - val_loss: 0.7891 - val_accuracy: 0.7269
# Epoch 92/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7372 - accuracy: 0.7399 - val_loss: 0.7860 - val_accuracy: 0.7273
# Epoch 93/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7325 - accuracy: 0.7422 - val_loss: 0.7892 - val_accuracy: 0.7273
# Epoch 94/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7416 - accuracy: 0.7355 - val_loss: 0.7866 - val_accuracy: 0.7281
# Epoch 95/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7366 - accuracy: 0.7405 - val_loss: 0.7868 - val_accuracy: 0.7285
# Epoch 96/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7365 - accuracy: 0.7404 - val_loss: 0.7884 - val_accuracy: 0.7278
# Epoch 97/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7399 - accuracy: 0.7387 - val_loss: 0.7877 - val_accuracy: 0.7274
# Epoch 98/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7403 - accuracy: 0.7394 - val_loss: 0.7905 - val_accuracy: 0.7260
# Epoch 99/120
# 1549/1562 [============================>.] - ETA: 0s - loss: 0.7391 - accuracy: 0.7393
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 3.1622775802825263e-06.
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7397 - accuracy: 0.7393 - val_loss: 0.7896 - val_accuracy: 0.7258
# Epoch 00100: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 100/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7361 - accuracy: 0.7403 - val_loss: 0.7884 - val_accuracy: 0.7265
# Epoch 00101: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 101/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7370 - accuracy: 0.7397 - val_loss: 0.7889 - val_accuracy: 0.7256
# Epoch 00102: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 102/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7364 - accuracy: 0.7388 - val_loss: 0.7883 - val_accuracy: 0.7276
# Epoch 00103: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 103/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7370 - accuracy: 0.7412 - val_loss: 0.7870 - val_accuracy: 0.7282
# Epoch 00104: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 104/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7381 - accuracy: 0.7401 - val_loss: 0.7881 - val_accuracy: 0.7267
# Epoch 00105: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 105/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7353 - accuracy: 0.7418 - val_loss: 0.7887 - val_accuracy: 0.7271
# Epoch 00106: LearningRateScheduler reducing learning rate to 1e-06 from 3.2e-06.
# Epoch 106/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7420 - accuracy: 0.7382 - val_loss: 0.7875 - val_accuracy: 0.7274
# Epoch 107/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7382 - accuracy: 0.7406 - val_loss: 0.7879 - val_accuracy: 0.7272
# Epoch 108/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7413 - accuracy: 0.7383 - val_loss: 0.7879 - val_accuracy: 0.7277
# Epoch 109/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7378 - accuracy: 0.7398 - val_loss: 0.7884 - val_accuracy: 0.7272
# Epoch 110/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7315 - accuracy: 0.7435 - val_loss: 0.7883 - val_accuracy: 0.7272
# Epoch 111/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7300 - accuracy: 0.7436 - val_loss: 0.7879 - val_accuracy: 0.7279
# Epoch 112/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7329 - accuracy: 0.7405 - val_loss: 0.7888 - val_accuracy: 0.7270
# Epoch 113/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7348 - accuracy: 0.7409 - val_loss: 0.7876 - val_accuracy: 0.7279
# Epoch 114/120
# 1549/1562 [============================>.] - ETA: 0s - loss: 0.7340 - accuracy: 0.7407
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 5e-07.
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7349 - accuracy: 0.7403 - val_loss: 0.7885 - val_accuracy: 0.7265
# Epoch 00115: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 115/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7312 - accuracy: 0.7424 - val_loss: 0.7890 - val_accuracy: 0.7265
# Epoch 00116: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 116/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7307 - accuracy: 0.7422 - val_loss: 0.7869 - val_accuracy: 0.7285
# Epoch 00117: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 117/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7312 - accuracy: 0.7441 - val_loss: 0.7879 - val_accuracy: 0.7282
# Epoch 00118: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 118/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7392 - accuracy: 0.7407 - val_loss: 0.7868 - val_accuracy: 0.7284
# Epoch 00119: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 119/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7391 - accuracy: 0.7395 - val_loss: 0.7876 - val_accuracy: 0.7279
# Epoch 00120: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 120/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7364 - accuracy: 0.7423 - val_loss: 0.7869 - val_accuracy: 0.7281
# 2020-12-31 08:24:36,038: INFO: finish training [elapsed time: 788.33 seconds]

# %% [markdown]
# 下面来评估模型并和mlp模型进行对比。

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.7841, Test Accuracy:72.87%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#        train_loss  train_accuracy  test_loss  test_accuracy  weight_number  \
# lenet    0.466231          0.8435   0.784104         0.7287          83170
# mlp      1.594395          0.4305   1.672060         0.3984         394634
#
#        train_time
# lenet       788.0
# mlp         550.0

# %% [markdown]
# 从上面的图中，可以看到，Lenet的参数只有mlp的60%，但其的准确率比mlp提升了差不多1%。上面最后一张图中，有三列，第一列是数字图片，它们是mlp中分错的数字，第二列是mlp中的分类，第三列是lenet中的分类，可以看到lenet的确学到了一些mlp中没有的模式。下面再来看看哪些数字在lenet也分错了。

# %% [markdown]
# 上图中，可以看到对于部分数字的识别，mlp甚至要更好一点啊，还有一些数字，则是一起都错了。
#
# ## Custom 1
#
# 下面自己定义一个模型，这个模型和lenet的主要区别是，增加了卷积的深度。

# %%
def get_custom1(helper, name='custom_cnn', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name)
    print('dropout={}'.format(dropout))
        
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x) 
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation='relu')(x)  
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model   

# 创建模型
model = get_custom1(helper)
model.summary()
# Out:
# dropout=0.2
# learning_rate=0.001
# checkpoint_path=./checkpoints/cifar10/custom_cnn/checkpoint
# Model: "custom_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 64)          36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 64)          256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 74,058
# Trainable params: 73,738
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# 可以发现参数的个数已经和mlp差不多了，下面来训练模型。

# %%
# 训练
history = helper.train(model, epochs=helper.params.epochs)
# Out:
# 2020-12-31 08:24:50,894: INFO: start training
# use ModelCheckpoint(filepath=./checkpoints/cifar10/custom_cnn/checkpoint, monitor=val_accuracy)
# use EarlyStopping(monitor=val_accuracy, patience=40)
# use ReduceLROnPlateau(monitor=val_loss, factor=0.31622776601683794, patience=15)
# use LearningRateScheduler()
# Epoch 1/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.6131 - accuracy: 0.4181 - val_loss: 1.6826 - val_accuracy: 0.4410
# Epoch 2/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.2741 - accuracy: 0.5478 - val_loss: 1.4585 - val_accuracy: 0.4911
# Epoch 3/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.1473 - accuracy: 0.5934 - val_loss: 1.2097 - val_accuracy: 0.5671
# Epoch 4/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0684 - accuracy: 0.6259 - val_loss: 0.9716 - val_accuracy: 0.6549
# Epoch 5/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 1.0069 - accuracy: 0.6453 - val_loss: 0.8946 - val_accuracy: 0.6820
# Epoch 6/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9618 - accuracy: 0.6623 - val_loss: 0.9559 - val_accuracy: 0.6691
# Epoch 7/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9275 - accuracy: 0.6769 - val_loss: 1.0305 - val_accuracy: 0.6468
# Epoch 8/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.9060 - accuracy: 0.6829 - val_loss: 1.3466 - val_accuracy: 0.5430
# Epoch 9/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8826 - accuracy: 0.6909 - val_loss: 1.2161 - val_accuracy: 0.5922
# Epoch 10/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8587 - accuracy: 0.6988 - val_loss: 0.9016 - val_accuracy: 0.6870
# Epoch 11/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8412 - accuracy: 0.7067 - val_loss: 0.8461 - val_accuracy: 0.7055
# Epoch 12/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8292 - accuracy: 0.7110 - val_loss: 0.7575 - val_accuracy: 0.7363
# Epoch 13/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8160 - accuracy: 0.7157 - val_loss: 0.7856 - val_accuracy: 0.7278
# Epoch 14/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.8034 - accuracy: 0.7197 - val_loss: 0.8834 - val_accuracy: 0.6922
# Epoch 15/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7943 - accuracy: 0.7211 - val_loss: 0.8017 - val_accuracy: 0.7198
# Epoch 16/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7859 - accuracy: 0.7268 - val_loss: 0.8509 - val_accuracy: 0.7039
# Epoch 17/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7734 - accuracy: 0.7303 - val_loss: 0.7182 - val_accuracy: 0.7491
# Epoch 18/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7671 - accuracy: 0.7322 - val_loss: 0.7653 - val_accuracy: 0.7364
# Epoch 19/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7592 - accuracy: 0.7347 - val_loss: 0.8692 - val_accuracy: 0.7063
# Epoch 20/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7497 - accuracy: 0.7400 - val_loss: 0.7132 - val_accuracy: 0.7508
# Epoch 21/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7361 - accuracy: 0.7441 - val_loss: 0.7908 - val_accuracy: 0.7281
# Epoch 22/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7397 - accuracy: 0.7418 - val_loss: 0.7215 - val_accuracy: 0.7495
# Epoch 23/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7276 - accuracy: 0.7474 - val_loss: 0.6912 - val_accuracy: 0.7618
# Epoch 24/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7237 - accuracy: 0.7480 - val_loss: 0.9063 - val_accuracy: 0.6978
# Epoch 25/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7169 - accuracy: 0.7508 - val_loss: 0.7321 - val_accuracy: 0.7495
# Epoch 26/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7118 - accuracy: 0.7521 - val_loss: 0.7125 - val_accuracy: 0.7542
# Epoch 27/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7069 - accuracy: 0.7542 - val_loss: 0.7800 - val_accuracy: 0.7246
# Epoch 28/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.7054 - accuracy: 0.7533 - val_loss: 0.7557 - val_accuracy: 0.7421
# Epoch 29/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6987 - accuracy: 0.7566 - val_loss: 0.6916 - val_accuracy: 0.7618
# Epoch 30/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6947 - accuracy: 0.7588 - val_loss: 0.7183 - val_accuracy: 0.7516
# Epoch 31/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6926 - accuracy: 0.7570 - val_loss: 0.6913 - val_accuracy: 0.7624
# Epoch 32/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6872 - accuracy: 0.7595 - val_loss: 0.9362 - val_accuracy: 0.6906
# Epoch 33/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6832 - accuracy: 0.7633 - val_loss: 0.6671 - val_accuracy: 0.7697
# Epoch 34/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6788 - accuracy: 0.7630 - val_loss: 0.6672 - val_accuracy: 0.7701
# Epoch 35/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6789 - accuracy: 0.7606 - val_loss: 0.6909 - val_accuracy: 0.7592
# Epoch 36/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6733 - accuracy: 0.7654 - val_loss: 0.7031 - val_accuracy: 0.7600
# Epoch 37/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6687 - accuracy: 0.7663 - val_loss: 0.6666 - val_accuracy: 0.7722
# Epoch 38/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6666 - accuracy: 0.7659 - val_loss: 0.6892 - val_accuracy: 0.7645
# Epoch 39/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6639 - accuracy: 0.7669 - val_loss: 0.7599 - val_accuracy: 0.7327
# Epoch 40/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6588 - accuracy: 0.7694 - val_loss: 0.7043 - val_accuracy: 0.7594
# Epoch 41/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6560 - accuracy: 0.7705 - val_loss: 0.6907 - val_accuracy: 0.7644
# Epoch 42/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6579 - accuracy: 0.7695 - val_loss: 0.7489 - val_accuracy: 0.7465
# Epoch 43/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6484 - accuracy: 0.7728 - val_loss: 0.6856 - val_accuracy: 0.7625
# Epoch 44/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6536 - accuracy: 0.7713 - val_loss: 0.7954 - val_accuracy: 0.7333
# Epoch 45/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6463 - accuracy: 0.7721 - val_loss: 0.7093 - val_accuracy: 0.7574
# Epoch 46/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6485 - accuracy: 0.7739 - val_loss: 0.6706 - val_accuracy: 0.7687
# Epoch 47/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6444 - accuracy: 0.7761 - val_loss: 0.6510 - val_accuracy: 0.7757
# Epoch 48/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6342 - accuracy: 0.7774 - val_loss: 0.6881 - val_accuracy: 0.7642
# Epoch 49/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6429 - accuracy: 0.7759 - val_loss: 0.6743 - val_accuracy: 0.7707
# Epoch 50/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6381 - accuracy: 0.7768 - val_loss: 1.0359 - val_accuracy: 0.6791
# Epoch 51/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6340 - accuracy: 0.7793 - val_loss: 0.6478 - val_accuracy: 0.7735
# Epoch 52/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6355 - accuracy: 0.7787 - val_loss: 0.7348 - val_accuracy: 0.7480
# Epoch 53/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6377 - accuracy: 0.7775 - val_loss: 0.6806 - val_accuracy: 0.7633
# Epoch 54/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6313 - accuracy: 0.7783 - val_loss: 0.6639 - val_accuracy: 0.7702
# Epoch 55/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6285 - accuracy: 0.7796 - val_loss: 0.6454 - val_accuracy: 0.7772
# Epoch 56/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6292 - accuracy: 0.7823 - val_loss: 0.6994 - val_accuracy: 0.7618
# Epoch 57/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6272 - accuracy: 0.7820 - val_loss: 0.7851 - val_accuracy: 0.7354
# Epoch 58/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6221 - accuracy: 0.7822 - val_loss: 0.6644 - val_accuracy: 0.7720
# Epoch 59/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6235 - accuracy: 0.7827 - val_loss: 0.6256 - val_accuracy: 0.7838
# Epoch 60/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.6246 - accuracy: 0.7814 - val_loss: 0.6264 - val_accuracy: 0.7873
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001 from 0.001.
# Epoch 61/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5819 - accuracy: 0.7965 - val_loss: 0.6035 - val_accuracy: 0.7945
# Epoch 62/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5751 - accuracy: 0.7970 - val_loss: 0.6021 - val_accuracy: 0.7932
# Epoch 63/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5693 - accuracy: 0.7984 - val_loss: 0.6173 - val_accuracy: 0.7888
# Epoch 64/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5688 - accuracy: 0.8003 - val_loss: 0.5924 - val_accuracy: 0.7986
# Epoch 65/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5653 - accuracy: 0.7998 - val_loss: 0.6016 - val_accuracy: 0.7950
# Epoch 66/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5622 - accuracy: 0.8028 - val_loss: 0.6044 - val_accuracy: 0.7958
# Epoch 67/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5604 - accuracy: 0.8018 - val_loss: 0.6061 - val_accuracy: 0.7913
# Epoch 68/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5640 - accuracy: 0.8021 - val_loss: 0.5849 - val_accuracy: 0.7980
# Epoch 69/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5586 - accuracy: 0.8050 - val_loss: 0.6164 - val_accuracy: 0.7933
# Epoch 70/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5592 - accuracy: 0.8031 - val_loss: 0.5993 - val_accuracy: 0.7949
# Epoch 71/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5578 - accuracy: 0.8042 - val_loss: 0.5943 - val_accuracy: 0.7977
# Epoch 72/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5579 - accuracy: 0.8050 - val_loss: 0.6048 - val_accuracy: 0.7950
# Epoch 73/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5573 - accuracy: 0.8052 - val_loss: 0.6163 - val_accuracy: 0.7889
# Epoch 74/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5555 - accuracy: 0.8047 - val_loss: 0.5973 - val_accuracy: 0.7951
# Epoch 75/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5558 - accuracy: 0.8055 - val_loss: 0.5884 - val_accuracy: 0.7971
# Epoch 76/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5549 - accuracy: 0.8034 - val_loss: 0.5840 - val_accuracy: 0.7999
# Epoch 77/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5530 - accuracy: 0.8070 - val_loss: 0.5855 - val_accuracy: 0.7965
# Epoch 78/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5465 - accuracy: 0.8086 - val_loss: 0.5890 - val_accuracy: 0.7993
# Epoch 79/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5508 - accuracy: 0.8070 - val_loss: 0.5912 - val_accuracy: 0.7978
# Epoch 80/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5551 - accuracy: 0.8064 - val_loss: 0.5908 - val_accuracy: 0.7993
# Epoch 81/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5531 - accuracy: 0.8068 - val_loss: 0.5946 - val_accuracy: 0.7968
# Epoch 82/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5529 - accuracy: 0.8053 - val_loss: 0.5933 - val_accuracy: 0.7973
# Epoch 83/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5481 - accuracy: 0.8071 - val_loss: 0.6029 - val_accuracy: 0.7945
# Epoch 84/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5442 - accuracy: 0.8094 - val_loss: 0.5928 - val_accuracy: 0.7962
# Epoch 85/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5507 - accuracy: 0.8048 - val_loss: 0.5857 - val_accuracy: 0.7986
# Epoch 86/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5466 - accuracy: 0.8070 - val_loss: 0.5843 - val_accuracy: 0.7990
# Epoch 87/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5446 - accuracy: 0.8078 - val_loss: 0.6070 - val_accuracy: 0.7945
# Epoch 88/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5466 - accuracy: 0.8075 - val_loss: 0.6023 - val_accuracy: 0.7950
# Epoch 89/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5504 - accuracy: 0.8074 - val_loss: 0.5880 - val_accuracy: 0.7985
# Epoch 90/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5459 - accuracy: 0.8085 - val_loss: 0.5832 - val_accuracy: 0.7978
# Epoch 00091: LearningRateScheduler reducing learning rate to 1e-05 from 0.0001.
# Epoch 91/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5389 - accuracy: 0.8106 - val_loss: 0.5878 - val_accuracy: 0.7984
# Epoch 92/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5432 - accuracy: 0.8084 - val_loss: 0.5864 - val_accuracy: 0.7984
# Epoch 93/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5428 - accuracy: 0.8096 - val_loss: 0.5887 - val_accuracy: 0.7963
# Epoch 94/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5391 - accuracy: 0.8100 - val_loss: 0.5875 - val_accuracy: 0.7996
# Epoch 95/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5362 - accuracy: 0.8106 - val_loss: 0.5867 - val_accuracy: 0.7994
# Epoch 96/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5394 - accuracy: 0.8099 - val_loss: 0.5868 - val_accuracy: 0.7986
# Epoch 97/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5427 - accuracy: 0.8088 - val_loss: 0.5876 - val_accuracy: 0.7986
# Epoch 98/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5384 - accuracy: 0.8107 - val_loss: 0.5895 - val_accuracy: 0.7982
# Epoch 99/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5426 - accuracy: 0.8086 - val_loss: 0.5874 - val_accuracy: 0.7977
# Epoch 100/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5461 - accuracy: 0.8080 - val_loss: 0.5881 - val_accuracy: 0.7982
# Epoch 101/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5463 - accuracy: 0.8080 - val_loss: 0.5879 - val_accuracy: 0.7984
# Epoch 102/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5416 - accuracy: 0.8102 - val_loss: 0.5899 - val_accuracy: 0.7980
# Epoch 103/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5400 - accuracy: 0.8105 - val_loss: 0.5897 - val_accuracy: 0.7965
# Epoch 104/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5390 - accuracy: 0.8091 - val_loss: 0.5879 - val_accuracy: 0.7967
# Epoch 105/120
# 1553/1562 [============================>.] - ETA: 0s - loss: 0.5417 - accuracy: 0.8099
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 3.1622775802825263e-06.
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5412 - accuracy: 0.8101 - val_loss: 0.5887 - val_accuracy: 0.7976
# Epoch 00106: LearningRateScheduler reducing learning rate to 1e-06 from 3.2e-06.
# Epoch 106/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5368 - accuracy: 0.8109 - val_loss: 0.5871 - val_accuracy: 0.7987
# Epoch 107/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5394 - accuracy: 0.8111 - val_loss: 0.5902 - val_accuracy: 0.7973
# Epoch 108/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5384 - accuracy: 0.8116 - val_loss: 0.5880 - val_accuracy: 0.7981
# Epoch 109/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5453 - accuracy: 0.8108 - val_loss: 0.5868 - val_accuracy: 0.7986
# Epoch 110/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5386 - accuracy: 0.8099 - val_loss: 0.5872 - val_accuracy: 0.7989
# Epoch 111/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5436 - accuracy: 0.8082 - val_loss: 0.5899 - val_accuracy: 0.7979
# Epoch 112/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5421 - accuracy: 0.8093 - val_loss: 0.5882 - val_accuracy: 0.7983
# Epoch 113/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5366 - accuracy: 0.8111 - val_loss: 0.5888 - val_accuracy: 0.7975
# Epoch 114/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5358 - accuracy: 0.8125 - val_loss: 0.5876 - val_accuracy: 0.7974
# Epoch 115/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5443 - accuracy: 0.8092 - val_loss: 0.5890 - val_accuracy: 0.7972
# Epoch 116/120
# 1562/1562 [==============================] - 6s 4ms/step - loss: 0.5378 - accuracy: 0.8109 - val_loss: 0.5899 - val_accuracy: 0.7976
# Epoch 00116: early stopping
# 2020-12-31 08:38:36,455: INFO: finish training [elapsed time: 825.56 seconds]

# %% [markdown]
# 下面来评估模型并和lenet模型进行对比。

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.5840, Test Accuracy:79.99%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#             train_loss  train_accuracy  test_loss  test_accuracy  \
# custom_cnn    0.310251          0.8954   0.583991         0.7999
# lenet         0.466231          0.8435   0.784104         0.7287
# mlp           1.594395          0.4305   1.672060         0.3984
#
#             weight_number  train_time
# custom_cnn          73738       825.0
# lenet               83170       788.0
# mlp                394634       550.0

# %% [markdown]
# 可以看到custom1模型的效果比lenet有些许提升（经过多次测试，平均好0.1-0.3个百分点）。上面最后一幅图，也能看到custom1模型学习到了不少新的模式。下面来看错误分析。

# %% [markdown]
# ## VGG

# %%
def get_block(x, filters, conv_count, kernel_size=(3, 3), padding='same', use_bn=True, dropout=0, block_name='block'):
    for i in range(conv_count):
        x = layers.Conv2D(filters, kernel_size, padding=padding, name='{}_con{}'.format(block_name, i+1))(x)
        if use_bn: x = layers.BatchNormalization(name='{}_bn{}'.format(block_name, i+1))(x)
        x = layers.ReLU(name='{}_relu{}'.format(block_name, i+1))(x)
    x = layers.MaxPooling2D((2, 2), name='{}_maxpooling1'.format(block_name))(x)
    if dropout>0: x = layers.Dropout(dropout, name='{}_dropout1'.format(block_name))(x)
    return x
    
def get_vgg(helper, name='vgg',
              dense_layer_count=1, 
              dense_layer_units=128,
              conv_filters=64,
              block_count=3,
              use_bn=True,
              dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name)
    print('dropout={}'.format(dropout))
        
    input = layers.Input(shape=helper.data.input_shape)
    x = input    
    for i in range(block_count): 
        x = get_block(x, conv_filters, conv_count=2, use_bn=use_bn, dropout=dropout, 
                      block_name='block{}'.format(i+1))
        conv_filters = conv_filters*2
                    
    x = layers.Flatten()(x)
    for i in range(dense_layer_count):
        x = layers.Dense(128, activation='relu')(x)
        if dropout>0: x = layers.Dropout(dropout)(x)    
    x = layers.Dense(10)(x)
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model


model = get_vgg(helper, dense_layer_count=1, block_count=3, name='vgg8')
model.summary()
# Out:
# dropout=0.4
# learning_rate=0.001
# checkpoint_path=./checkpoints/cifar10/vgg8/checkpoint
# Model: "vgg8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_con1 (Conv2D)         (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_bn1 (BatchNormalizati (None, 32, 32, 64)        256
# _________________________________________________________________
# block1_relu1 (ReLU)          (None, 32, 32, 64)        0
# _________________________________________________________________
# block1_con2 (Conv2D)         (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_bn2 (BatchNormalizati (None, 32, 32, 64)        256
# _________________________________________________________________
# block1_relu2 (ReLU)          (None, 32, 32, 64)        0
# _________________________________________________________________
# block1_maxpooling1 (MaxPooli (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_dropout1 (Dropout)    (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_con1 (Conv2D)         (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_bn1 (BatchNormalizati (None, 16, 16, 128)       512
# _________________________________________________________________
# block2_relu1 (ReLU)          (None, 16, 16, 128)       0
# _________________________________________________________________
# block2_con2 (Conv2D)         (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_bn2 (BatchNormalizati (None, 16, 16, 128)       512
# _________________________________________________________________
# block2_relu2 (ReLU)          (None, 16, 16, 128)       0
# _________________________________________________________________
# block2_maxpooling1 (MaxPooli (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_dropout1 (Dropout)    (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_con1 (Conv2D)         (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_bn1 (BatchNormalizati (None, 8, 8, 256)         1024
# _________________________________________________________________
# block3_relu1 (ReLU)          (None, 8, 8, 256)         0
# _________________________________________________________________
# block3_con2 (Conv2D)         (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_bn2 (BatchNormalizati (None, 8, 8, 256)         1024
# _________________________________________________________________
# block3_relu2 (ReLU)          (None, 8, 8, 256)         0
# _________________________________________________________________
# block3_maxpooling1 (MaxPooli (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_dropout1 (Dropout)    (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               524416
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,674,698
# Trainable params: 1,672,906
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
# 训练
history = helper.train(model, epochs=helper.params.epochs)
# Out:
# 2020-12-31 08:38:52,721: INFO: start training
# use ModelCheckpoint(filepath=./checkpoints/cifar10/vgg8/checkpoint, monitor=val_accuracy)
# use EarlyStopping(monitor=val_accuracy, patience=40)
# use ReduceLROnPlateau(monitor=val_loss, factor=0.31622776601683794, patience=15)
# use LearningRateScheduler()
# Epoch 1/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 2.1626 - accuracy: 0.1599 - val_loss: 2.0322 - val_accuracy: 0.2080
# Epoch 2/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 2.0556 - accuracy: 0.1772 - val_loss: 1.9797 - val_accuracy: 0.1944
# Epoch 3/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 2.0276 - accuracy: 0.1870 - val_loss: 1.9738 - val_accuracy: 0.2145
# Epoch 4/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.9480 - accuracy: 0.2383 - val_loss: 1.8064 - val_accuracy: 0.3000
# Epoch 5/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.8126 - accuracy: 0.2966 - val_loss: 1.5506 - val_accuracy: 0.4121
# Epoch 6/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.7435 - accuracy: 0.3217 - val_loss: 1.4896 - val_accuracy: 0.4700
# Epoch 7/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.6104 - accuracy: 0.3816 - val_loss: 1.2736 - val_accuracy: 0.5264
# Epoch 8/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.3853 - accuracy: 0.4811 - val_loss: 1.1066 - val_accuracy: 0.6008
# Epoch 9/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.2068 - accuracy: 0.5579 - val_loss: 0.9225 - val_accuracy: 0.6858
# Epoch 10/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.1031 - accuracy: 0.5980 - val_loss: 0.7889 - val_accuracy: 0.7343
# Epoch 11/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.0038 - accuracy: 0.6361 - val_loss: 0.7887 - val_accuracy: 0.7408
# Epoch 12/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.9135 - accuracy: 0.6746 - val_loss: 0.7427 - val_accuracy: 0.7502
# Epoch 13/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.8242 - accuracy: 0.7167 - val_loss: 0.6996 - val_accuracy: 0.7642
# Epoch 14/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.7364 - accuracy: 0.7483 - val_loss: 0.6451 - val_accuracy: 0.7834
# Epoch 15/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.6703 - accuracy: 0.7731 - val_loss: 0.7294 - val_accuracy: 0.7602
# Epoch 16/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.6253 - accuracy: 0.7919 - val_loss: 0.6042 - val_accuracy: 0.8072
# Epoch 17/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.5779 - accuracy: 0.8075 - val_loss: 0.6086 - val_accuracy: 0.8111
# Epoch 18/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.5491 - accuracy: 0.8167 - val_loss: 0.5558 - val_accuracy: 0.8195
# Epoch 19/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.5115 - accuracy: 0.8308 - val_loss: 0.6459 - val_accuracy: 0.7995
# Epoch 20/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4881 - accuracy: 0.8380 - val_loss: 0.5505 - val_accuracy: 0.8208
# Epoch 21/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.4539 - accuracy: 0.8489 - val_loss: 0.5341 - val_accuracy: 0.8324
# Epoch 22/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4385 - accuracy: 0.8549 - val_loss: 0.5265 - val_accuracy: 0.8345
# Epoch 23/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4161 - accuracy: 0.8606 - val_loss: 0.4838 - val_accuracy: 0.8505
# Epoch 24/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.4006 - accuracy: 0.8647 - val_loss: 0.5175 - val_accuracy: 0.8345
# Epoch 25/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3795 - accuracy: 0.8726 - val_loss: 0.4741 - val_accuracy: 0.8543
# Epoch 26/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3738 - accuracy: 0.8757 - val_loss: 0.5167 - val_accuracy: 0.8400
# Epoch 27/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3566 - accuracy: 0.8804 - val_loss: 0.5107 - val_accuracy: 0.8499
# Epoch 28/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3417 - accuracy: 0.8852 - val_loss: 0.4811 - val_accuracy: 0.8511
# Epoch 29/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3217 - accuracy: 0.8900 - val_loss: 0.4921 - val_accuracy: 0.8571
# Epoch 30/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.3212 - accuracy: 0.8909 - val_loss: 0.5003 - val_accuracy: 0.8524
# Epoch 31/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3035 - accuracy: 0.8983 - val_loss: 0.4417 - val_accuracy: 0.8688
# Epoch 32/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2943 - accuracy: 0.9012 - val_loss: 0.4329 - val_accuracy: 0.8678
# Epoch 33/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2889 - accuracy: 0.9034 - val_loss: 0.4613 - val_accuracy: 0.8584
# Epoch 34/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2726 - accuracy: 0.9069 - val_loss: 0.4961 - val_accuracy: 0.8596
# Epoch 35/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2720 - accuracy: 0.9081 - val_loss: 0.5283 - val_accuracy: 0.8533
# Epoch 36/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2609 - accuracy: 0.9106 - val_loss: 0.5401 - val_accuracy: 0.8520
# Epoch 37/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2553 - accuracy: 0.9123 - val_loss: 0.4863 - val_accuracy: 0.8643
# Epoch 38/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2487 - accuracy: 0.9179 - val_loss: 0.5030 - val_accuracy: 0.8572
# Epoch 39/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2381 - accuracy: 0.9186 - val_loss: 0.4842 - val_accuracy: 0.8695
# Epoch 40/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2321 - accuracy: 0.9216 - val_loss: 0.4596 - val_accuracy: 0.8702
# Epoch 41/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2226 - accuracy: 0.9245 - val_loss: 0.5037 - val_accuracy: 0.8640
# Epoch 42/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2259 - accuracy: 0.9228 - val_loss: 0.4846 - val_accuracy: 0.8686
# Epoch 43/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2218 - accuracy: 0.9251 - val_loss: 0.4539 - val_accuracy: 0.8777
# Epoch 44/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2120 - accuracy: 0.9266 - val_loss: 0.5046 - val_accuracy: 0.8668
# Epoch 45/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2063 - accuracy: 0.9288 - val_loss: 0.4714 - val_accuracy: 0.8773
# Epoch 46/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.2000 - accuracy: 0.9314 - val_loss: 0.5113 - val_accuracy: 0.8677
# Epoch 47/120
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9352
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1928 - accuracy: 0.9352 - val_loss: 0.4841 - val_accuracy: 0.8737
# Epoch 00048: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 48/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.1591 - accuracy: 0.9471 - val_loss: 0.4957 - val_accuracy: 0.8802
# Epoch 00049: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 49/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.1426 - accuracy: 0.9503 - val_loss: 0.4588 - val_accuracy: 0.8870
# Epoch 00050: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 50/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.1342 - accuracy: 0.9543 - val_loss: 0.4590 - val_accuracy: 0.8871
# Epoch 00051: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 51/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1272 - accuracy: 0.9572 - val_loss: 0.4780 - val_accuracy: 0.8854
# Epoch 00052: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 52/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.1218 - accuracy: 0.9578 - val_loss: 0.4806 - val_accuracy: 0.8898
# Epoch 00053: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 53/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1215 - accuracy: 0.9590 - val_loss: 0.4742 - val_accuracy: 0.8878
# Epoch 00054: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 54/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1167 - accuracy: 0.9598 - val_loss: 0.4872 - val_accuracy: 0.8850
# Epoch 00055: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 55/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1153 - accuracy: 0.9603 - val_loss: 0.4896 - val_accuracy: 0.8860
# Epoch 00056: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 56/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1111 - accuracy: 0.9610 - val_loss: 0.4849 - val_accuracy: 0.8862
# Epoch 00057: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 57/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1089 - accuracy: 0.9644 - val_loss: 0.4801 - val_accuracy: 0.8893
# Epoch 00058: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 58/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1076 - accuracy: 0.9635 - val_loss: 0.4836 - val_accuracy: 0.8881
# Epoch 00059: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 59/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1035 - accuracy: 0.9643 - val_loss: 0.4988 - val_accuracy: 0.8869
# Epoch 00060: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 60/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.1041 - accuracy: 0.9651 - val_loss: 0.5025 - val_accuracy: 0.8889
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001 from 0.0003162.
# Epoch 61/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0928 - accuracy: 0.9685 - val_loss: 0.5047 - val_accuracy: 0.8866
# Epoch 62/120
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0897 - accuracy: 0.9694
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0898 - accuracy: 0.9694 - val_loss: 0.5041 - val_accuracy: 0.8906
# Epoch 00063: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 63/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0868 - accuracy: 0.9696 - val_loss: 0.4946 - val_accuracy: 0.8898
# Epoch 00064: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 64/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0816 - accuracy: 0.9728 - val_loss: 0.5057 - val_accuracy: 0.8886
# Epoch 00065: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 65/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0853 - accuracy: 0.9714 - val_loss: 0.5074 - val_accuracy: 0.8885
# Epoch 00066: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 66/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0836 - accuracy: 0.9718 - val_loss: 0.5075 - val_accuracy: 0.8893
# Epoch 00067: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 67/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0809 - accuracy: 0.9719 - val_loss: 0.5083 - val_accuracy: 0.8904
# Epoch 00068: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 68/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0822 - accuracy: 0.9719 - val_loss: 0.5041 - val_accuracy: 0.8897
# Epoch 00069: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 69/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0825 - accuracy: 0.9722 - val_loss: 0.5028 - val_accuracy: 0.8907
# Epoch 00070: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 70/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0785 - accuracy: 0.9730 - val_loss: 0.5105 - val_accuracy: 0.8899
# Epoch 00071: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 71/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0760 - accuracy: 0.9745 - val_loss: 0.5069 - val_accuracy: 0.8910
# Epoch 00072: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 72/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0796 - accuracy: 0.9731 - val_loss: 0.5072 - val_accuracy: 0.8912
# Epoch 00073: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 73/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0738 - accuracy: 0.9748 - val_loss: 0.5115 - val_accuracy: 0.8903
# Epoch 00074: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 74/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0758 - accuracy: 0.9740 - val_loss: 0.5063 - val_accuracy: 0.8901
# Epoch 00075: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 75/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0741 - accuracy: 0.9745 - val_loss: 0.5128 - val_accuracy: 0.8907
# Epoch 00076: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 76/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0779 - accuracy: 0.9738 - val_loss: 0.5124 - val_accuracy: 0.8912
# Epoch 00077: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 77/120
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0781 - accuracy: 0.9734
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 9.999999259090306e-06.
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0781 - accuracy: 0.9734 - val_loss: 0.5197 - val_accuracy: 0.8901
# Epoch 00078: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 78/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0762 - accuracy: 0.9741 - val_loss: 0.5115 - val_accuracy: 0.8904
# Epoch 00079: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 79/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0773 - accuracy: 0.9741 - val_loss: 0.5109 - val_accuracy: 0.8914
# Epoch 00080: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 80/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0764 - accuracy: 0.9735 - val_loss: 0.5106 - val_accuracy: 0.8912
# Epoch 00081: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 81/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0758 - accuracy: 0.9741 - val_loss: 0.5141 - val_accuracy: 0.8911
# Epoch 00082: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 82/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0724 - accuracy: 0.9751 - val_loss: 0.5100 - val_accuracy: 0.8907
# Epoch 00083: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 83/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0758 - accuracy: 0.9742 - val_loss: 0.5126 - val_accuracy: 0.8921
# Epoch 00084: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 84/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0732 - accuracy: 0.9753 - val_loss: 0.5157 - val_accuracy: 0.8918
# Epoch 00085: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 85/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0753 - accuracy: 0.9746 - val_loss: 0.5075 - val_accuracy: 0.8916
# Epoch 00086: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 86/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0748 - accuracy: 0.9751 - val_loss: 0.5148 - val_accuracy: 0.8913
# Epoch 00087: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 87/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0726 - accuracy: 0.9756 - val_loss: 0.5106 - val_accuracy: 0.8916
# Epoch 00088: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 88/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0725 - accuracy: 0.9754 - val_loss: 0.5139 - val_accuracy: 0.8911
# Epoch 00089: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 89/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0739 - accuracy: 0.9750 - val_loss: 0.5112 - val_accuracy: 0.8921
# Epoch 00090: Still keep learning rate 1e-05 instead of 0.0001
# Epoch 90/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0738 - accuracy: 0.9755 - val_loss: 0.5158 - val_accuracy: 0.8917
# Epoch 91/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0697 - accuracy: 0.9767 - val_loss: 0.5141 - val_accuracy: 0.8922
# Epoch 92/120
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0720 - accuracy: 0.9753
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 3.1622775802825263e-06.
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0719 - accuracy: 0.9753 - val_loss: 0.5133 - val_accuracy: 0.8920
# Epoch 00093: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 93/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0726 - accuracy: 0.9753 - val_loss: 0.5150 - val_accuracy: 0.8915
# Epoch 00094: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 94/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0771 - accuracy: 0.9744 - val_loss: 0.5157 - val_accuracy: 0.8918
# Epoch 00095: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 95/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0741 - accuracy: 0.9754 - val_loss: 0.5180 - val_accuracy: 0.8917
# Epoch 00096: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 96/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0700 - accuracy: 0.9751 - val_loss: 0.5142 - val_accuracy: 0.8911
# Epoch 00097: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 97/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0746 - accuracy: 0.9753 - val_loss: 0.5165 - val_accuracy: 0.8911
# Epoch 00098: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 98/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0739 - accuracy: 0.9749 - val_loss: 0.5171 - val_accuracy: 0.8923
# Epoch 00099: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 99/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0735 - accuracy: 0.9742 - val_loss: 0.5190 - val_accuracy: 0.8913
# Epoch 00100: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 100/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0707 - accuracy: 0.9756 - val_loss: 0.5181 - val_accuracy: 0.8911
# Epoch 00101: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 101/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0740 - accuracy: 0.9749 - val_loss: 0.5170 - val_accuracy: 0.8925
# Epoch 00102: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 102/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0740 - accuracy: 0.9746 - val_loss: 0.5153 - val_accuracy: 0.8918
# Epoch 00103: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 103/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0763 - accuracy: 0.9742 - val_loss: 0.5164 - val_accuracy: 0.8919
# Epoch 00104: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 104/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0732 - accuracy: 0.9759 - val_loss: 0.5152 - val_accuracy: 0.8922
# Epoch 00105: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 105/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0721 - accuracy: 0.9759 - val_loss: 0.5177 - val_accuracy: 0.8919
# Epoch 00106: LearningRateScheduler reducing learning rate to 1e-06 from 3.2e-06.
# Epoch 106/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0718 - accuracy: 0.9755 - val_loss: 0.5186 - val_accuracy: 0.8912
# Epoch 107/120
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0742 - accuracy: 0.9739
# Epoch 00107: ReduceLROnPlateau reducing learning rate to 5e-07.
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0743 - accuracy: 0.9739 - val_loss: 0.5200 - val_accuracy: 0.8914
# Epoch 00108: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 108/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0711 - accuracy: 0.9761 - val_loss: 0.5180 - val_accuracy: 0.8919
# Epoch 00109: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 109/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0736 - accuracy: 0.9759 - val_loss: 0.5174 - val_accuracy: 0.8909
# Epoch 00110: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 110/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0704 - accuracy: 0.9756 - val_loss: 0.5167 - val_accuracy: 0.8918
# Epoch 00111: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 111/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0701 - accuracy: 0.9762 - val_loss: 0.5153 - val_accuracy: 0.8919
# Epoch 00112: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 112/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0747 - accuracy: 0.9744 - val_loss: 0.5168 - val_accuracy: 0.8918
# Epoch 00113: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 113/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0716 - accuracy: 0.9754 - val_loss: 0.5174 - val_accuracy: 0.8916
# Epoch 00114: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 114/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0723 - accuracy: 0.9751 - val_loss: 0.5168 - val_accuracy: 0.8918
# Epoch 00115: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 115/120
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.0717 - accuracy: 0.9757 - val_loss: 0.5180 - val_accuracy: 0.8919
# Epoch 00116: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 116/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0713 - accuracy: 0.9752 - val_loss: 0.5191 - val_accuracy: 0.8921
# Epoch 00117: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 117/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0726 - accuracy: 0.9748 - val_loss: 0.5183 - val_accuracy: 0.8916
# Epoch 00118: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 118/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0729 - accuracy: 0.9748 - val_loss: 0.5192 - val_accuracy: 0.8910
# Epoch 00119: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 119/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0712 - accuracy: 0.9763 - val_loss: 0.5154 - val_accuracy: 0.8920
# Epoch 00120: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 120/120
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.0716 - accuracy: 0.9760 - val_loss: 0.5154 - val_accuracy: 0.8915
# 2020-12-31 09:11:42,072: INFO: finish training [elapsed time: 1969.35 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.5170, Test Accuracy:89.25%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#             train_loss  train_accuracy  test_loss  test_accuracy  \
# vgg8          0.002738          0.9997   0.516973         0.8925
# custom_cnn    0.310251          0.8954   0.583991         0.7999
# lenet         0.466231          0.8435   0.784104         0.7287
# mlp           1.594395          0.4305   1.672060         0.3984
#
#             weight_number  train_time
# vgg8              1672906      1969.0
# custom_cnn          73738       825.0
# lenet               83170       788.0
# mlp                394634       550.0

# %% [markdown]
# ## Resnet
#
# 参考https://github.com/PacktPublishing/Advanced-Deep-Learning-with-Keras/blob/master/chapter2-deep-networks/resnet-cifar10-2.2.1.py

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = layers.Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
    else:
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10, name='resnet_v1'):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = layers.Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = layers.add([x, y])
            x = layers.Activation('relu')(x)

        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = layers.AveragePooling2D(pool_size=7)(x)
    y = layers.Flatten()(x)
    outputs = layers.Dense(num_classes, kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs, name=name)
    return model

def get_resnet_v1(helper, depth=32, name='resnet_v1'):       
    model = resnet_v1(helper.data.input_shape, depth=depth, name='{}_{}'.format(name, depth))
    helper.compile(model)
    return model

model = get_resnet_v1(helper, depth=20)
model.summary()
# Out:
# learning_rate=0.001
# checkpoint_path=./checkpoints/cifar10/resnet_v1_20/checkpoint
# Model: "resnet_v1_20"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   448         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 16)   0           activation[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 16)   64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_4[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   4640        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 32)   544         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 32)   0           conv2d_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           activation_8[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 32)   0           activation_10[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     18496       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     2112        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 64)     0           conv2d_21[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 64)     256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 64)     256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           activation_14[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 64)     256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 64)     256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           activation_16[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10)           650         flatten_4[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
history = helper.train(model, epochs=helper.params.epochs)
# Out:
# 2020-12-31 09:12:02,963: INFO: start training
# use ModelCheckpoint(filepath=./checkpoints/cifar10/resnet_v1_20/checkpoint, monitor=val_accuracy)
# use EarlyStopping(monitor=val_accuracy, patience=40)
# use ReduceLROnPlateau(monitor=val_loss, factor=0.31622776601683794, patience=15)
# use LearningRateScheduler()
# Epoch 1/120
# 1562/1562 [==============================] - 23s 14ms/step - loss: 1.4820 - accuracy: 0.5192 - val_loss: 1.6416 - val_accuracy: 0.5078
# Epoch 2/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 1.0728 - accuracy: 0.6770 - val_loss: 1.2015 - val_accuracy: 0.6437
# Epoch 3/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.9095 - accuracy: 0.7388 - val_loss: 1.0062 - val_accuracy: 0.7074
# Epoch 4/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.8071 - accuracy: 0.7777 - val_loss: 1.0038 - val_accuracy: 0.7172
# Epoch 5/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.7341 - accuracy: 0.8056 - val_loss: 0.8636 - val_accuracy: 0.7565
# Epoch 6/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.6858 - accuracy: 0.8226 - val_loss: 1.1511 - val_accuracy: 0.6968
# Epoch 7/120
# 1562/1562 [==============================] - 21s 14ms/step - loss: 0.6434 - accuracy: 0.8405 - val_loss: 0.9899 - val_accuracy: 0.7324
# Epoch 8/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.6030 - accuracy: 0.8564 - val_loss: 0.8705 - val_accuracy: 0.7736
# Epoch 9/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.5768 - accuracy: 0.8673 - val_loss: 0.9944 - val_accuracy: 0.7519
# Epoch 10/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.5547 - accuracy: 0.8763 - val_loss: 0.9556 - val_accuracy: 0.7636
# Epoch 11/120
# 1562/1562 [==============================] - 21s 14ms/step - loss: 0.5305 - accuracy: 0.8872 - val_loss: 1.1261 - val_accuracy: 0.7400
# Epoch 12/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.5126 - accuracy: 0.8955 - val_loss: 1.2047 - val_accuracy: 0.7224
# Epoch 13/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4995 - accuracy: 0.9013 - val_loss: 0.9700 - val_accuracy: 0.7715
# Epoch 14/120
# 1562/1562 [==============================] - 21s 14ms/step - loss: 0.4840 - accuracy: 0.9085 - val_loss: 1.4905 - val_accuracy: 0.6919
# Epoch 15/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4706 - accuracy: 0.9162 - val_loss: 1.0797 - val_accuracy: 0.7617
# Epoch 16/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4636 - accuracy: 0.9198 - val_loss: 1.0271 - val_accuracy: 0.7778
# Epoch 17/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4573 - accuracy: 0.9233 - val_loss: 1.0971 - val_accuracy: 0.7496
# Epoch 18/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4528 - accuracy: 0.9266 - val_loss: 0.9700 - val_accuracy: 0.7817
# Epoch 19/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4482 - accuracy: 0.9279 - val_loss: 1.1192 - val_accuracy: 0.7590
# Epoch 20/120
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.4404 - accuracy: 0.9332
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4405 - accuracy: 0.9332 - val_loss: 1.0865 - val_accuracy: 0.7785
# Epoch 00021: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 21/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.3205 - accuracy: 0.9772 - val_loss: 0.8834 - val_accuracy: 0.8279
# Epoch 00022: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 22/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2721 - accuracy: 0.9906 - val_loss: 0.9677 - val_accuracy: 0.8224
# Epoch 00023: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 23/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2561 - accuracy: 0.9902 - val_loss: 1.0585 - val_accuracy: 0.8122
# Epoch 00024: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 24/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2428 - accuracy: 0.9905 - val_loss: 1.0668 - val_accuracy: 0.8203
# Epoch 00025: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 25/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2346 - accuracy: 0.9901 - val_loss: 1.0515 - val_accuracy: 0.8163
# Epoch 00026: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 26/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2275 - accuracy: 0.9899 - val_loss: 1.2340 - val_accuracy: 0.7993
# Epoch 00027: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 27/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2190 - accuracy: 0.9904 - val_loss: 1.0811 - val_accuracy: 0.8181
# Epoch 00028: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 28/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2153 - accuracy: 0.9895 - val_loss: 1.0085 - val_accuracy: 0.8210
# Epoch 00029: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 29/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2085 - accuracy: 0.9900 - val_loss: 1.0153 - val_accuracy: 0.8198
# Epoch 00030: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 30/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2052 - accuracy: 0.9900 - val_loss: 1.0395 - val_accuracy: 0.8190
# Epoch 00031: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 31/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2019 - accuracy: 0.9898 - val_loss: 1.1003 - val_accuracy: 0.8109
# Epoch 00032: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 32/120
# 1562/1562 [==============================] - 21s 14ms/step - loss: 0.1990 - accuracy: 0.9889 - val_loss: 1.0443 - val_accuracy: 0.8190
# Epoch 00033: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 33/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1944 - accuracy: 0.9899 - val_loss: 1.1359 - val_accuracy: 0.8141
# Epoch 00034: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 34/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1933 - accuracy: 0.9887 - val_loss: 1.1469 - val_accuracy: 0.8079
# Epoch 00035: Still keep learning rate 0.0003162 instead of 0.001
# Epoch 35/120
# 1558/1562 [============================>.] - ETA: 0s - loss: 0.1883 - accuracy: 0.9904
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1883 - accuracy: 0.9904 - val_loss: 1.1612 - val_accuracy: 0.8030
# Epoch 00036: Still keep learning rate 0.0001 instead of 0.001
# Epoch 36/120
# 1562/1562 [==============================] - 21s 14ms/step - loss: 0.1677 - accuracy: 0.9968 - val_loss: 1.0018 - val_accuracy: 0.8316
# Epoch 00037: Still keep learning rate 0.0001 instead of 0.001
# Epoch 37/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1578 - accuracy: 0.9990 - val_loss: 1.0252 - val_accuracy: 0.8327
# Epoch 00038: Still keep learning rate 0.0001 instead of 0.001
# Epoch 38/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1527 - accuracy: 0.9992 - val_loss: 1.0262 - val_accuracy: 0.8329
# Epoch 00039: Still keep learning rate 0.0001 instead of 0.001
# Epoch 39/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1486 - accuracy: 0.9989 - val_loss: 1.0344 - val_accuracy: 0.8378
# Epoch 00040: Still keep learning rate 0.0001 instead of 0.001
# Epoch 40/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1446 - accuracy: 0.9989 - val_loss: 1.0347 - val_accuracy: 0.8365
# Epoch 00041: Still keep learning rate 0.0001 instead of 0.001
# Epoch 41/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1396 - accuracy: 0.9992 - val_loss: 1.0594 - val_accuracy: 0.8318
# Epoch 00042: Still keep learning rate 0.0001 instead of 0.001
# Epoch 42/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1368 - accuracy: 0.9989 - val_loss: 1.1179 - val_accuracy: 0.8250
# Epoch 00043: Still keep learning rate 0.0001 instead of 0.001
# Epoch 43/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1327 - accuracy: 0.9991 - val_loss: 1.0720 - val_accuracy: 0.8310
# Epoch 00044: Still keep learning rate 0.0001 instead of 0.001
# Epoch 44/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1295 - accuracy: 0.9990 - val_loss: 1.0853 - val_accuracy: 0.8323
# Epoch 00045: Still keep learning rate 0.0001 instead of 0.001
# Epoch 45/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1264 - accuracy: 0.9989 - val_loss: 1.0697 - val_accuracy: 0.8312
# Epoch 00046: Still keep learning rate 0.0001 instead of 0.001
# Epoch 46/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1235 - accuracy: 0.9991 - val_loss: 1.0823 - val_accuracy: 0.8291
# Epoch 00047: Still keep learning rate 0.0001 instead of 0.001
# Epoch 47/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1200 - accuracy: 0.9993 - val_loss: 1.0915 - val_accuracy: 0.8310
# Epoch 00048: Still keep learning rate 0.0001 instead of 0.001
# Epoch 48/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1185 - accuracy: 0.9987 - val_loss: 1.1851 - val_accuracy: 0.8197
# Epoch 00049: Still keep learning rate 0.0001 instead of 0.001
# Epoch 49/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1172 - accuracy: 0.9984 - val_loss: 1.0950 - val_accuracy: 0.8287
# Epoch 00050: Still keep learning rate 0.0001 instead of 0.001
# Epoch 50/120
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9991
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1135 - accuracy: 0.9991 - val_loss: 1.1854 - val_accuracy: 0.8235
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.001 from 3.16e-05.
# Epoch 51/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.6229 - accuracy: 0.8429 - val_loss: 0.8704 - val_accuracy: 0.7872
# Epoch 52/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4439 - accuracy: 0.9024 - val_loss: 1.1475 - val_accuracy: 0.7522
# Epoch 53/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4175 - accuracy: 0.9185 - val_loss: 0.9275 - val_accuracy: 0.7927
# Epoch 54/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4075 - accuracy: 0.9259 - val_loss: 1.2216 - val_accuracy: 0.7554
# Epoch 55/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4074 - accuracy: 0.9301 - val_loss: 1.0237 - val_accuracy: 0.7849
# Epoch 56/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.3986 - accuracy: 0.9365 - val_loss: 0.9982 - val_accuracy: 0.7863
# Epoch 57/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4042 - accuracy: 0.9384 - val_loss: 1.0594 - val_accuracy: 0.7831
# Epoch 58/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4021 - accuracy: 0.9409 - val_loss: 1.0461 - val_accuracy: 0.7848
# Epoch 59/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4013 - accuracy: 0.9432 - val_loss: 1.3633 - val_accuracy: 0.7352
# Epoch 60/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.4020 - accuracy: 0.9451 - val_loss: 1.0120 - val_accuracy: 0.7999
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001 from 0.001.
# Epoch 61/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.3022 - accuracy: 0.9833 - val_loss: 0.8475 - val_accuracy: 0.8404
# Epoch 62/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2659 - accuracy: 0.9950 - val_loss: 0.8810 - val_accuracy: 0.8396
# Epoch 63/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2494 - accuracy: 0.9974 - val_loss: 0.9128 - val_accuracy: 0.8424
# Epoch 64/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2355 - accuracy: 0.9985 - val_loss: 0.9571 - val_accuracy: 0.8383
# Epoch 65/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2232 - accuracy: 0.9988 - val_loss: 0.9574 - val_accuracy: 0.8405
# Epoch 66/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2118 - accuracy: 0.9991 - val_loss: 0.9667 - val_accuracy: 0.8425
# Epoch 67/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.2018 - accuracy: 0.9989 - val_loss: 1.0065 - val_accuracy: 0.8398
# Epoch 68/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1925 - accuracy: 0.9991 - val_loss: 1.0090 - val_accuracy: 0.8392
# Epoch 69/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1839 - accuracy: 0.9993 - val_loss: 1.0111 - val_accuracy: 0.8413
# Epoch 70/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1774 - accuracy: 0.9989 - val_loss: 1.0165 - val_accuracy: 0.8403
# Epoch 71/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1705 - accuracy: 0.9990 - val_loss: 1.0207 - val_accuracy: 0.8408
# Epoch 72/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1648 - accuracy: 0.9991 - val_loss: 1.0510 - val_accuracy: 0.8376
# Epoch 73/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1588 - accuracy: 0.9991 - val_loss: 1.0462 - val_accuracy: 0.8392
# Epoch 74/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1540 - accuracy: 0.9990 - val_loss: 1.0149 - val_accuracy: 0.8417
# Epoch 75/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1486 - accuracy: 0.9992 - val_loss: 1.0398 - val_accuracy: 0.8378
# Epoch 76/120
# 1562/1562 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9989
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1443 - accuracy: 0.9989 - val_loss: 1.0739 - val_accuracy: 0.8364
# Epoch 00077: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 77/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1397 - accuracy: 0.9995 - val_loss: 1.0151 - val_accuracy: 0.8407
# Epoch 00078: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 78/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1371 - accuracy: 0.9998 - val_loss: 1.0071 - val_accuracy: 0.8425
# Epoch 00079: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 79/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1347 - accuracy: 0.9998 - val_loss: 1.0235 - val_accuracy: 0.8423
# Epoch 00080: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 80/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1320 - accuracy: 0.9999 - val_loss: 1.0173 - val_accuracy: 0.8420
# Epoch 00081: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 81/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1291 - accuracy: 0.9999 - val_loss: 1.0313 - val_accuracy: 0.8413
# Epoch 00082: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 82/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1262 - accuracy: 0.9999 - val_loss: 1.0240 - val_accuracy: 0.8436
# Epoch 00083: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 83/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1237 - accuracy: 0.9998 - val_loss: 1.0407 - val_accuracy: 0.8425
# Epoch 00084: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 84/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1209 - accuracy: 0.9999 - val_loss: 1.0330 - val_accuracy: 0.8419
# Epoch 00085: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 85/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1182 - accuracy: 0.9999 - val_loss: 1.0271 - val_accuracy: 0.8411
# Epoch 00086: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 86/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1157 - accuracy: 0.9999 - val_loss: 1.0356 - val_accuracy: 0.8430
# Epoch 00087: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 87/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1133 - accuracy: 0.9999 - val_loss: 1.0379 - val_accuracy: 0.8410
# Epoch 00088: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 88/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1111 - accuracy: 0.9999 - val_loss: 1.0277 - val_accuracy: 0.8410
# Epoch 00089: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 89/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1091 - accuracy: 0.9999 - val_loss: 1.0320 - val_accuracy: 0.8407
# Epoch 00090: Still keep learning rate 3.16e-05 instead of 0.0001
# Epoch 90/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1069 - accuracy: 0.9999 - val_loss: 1.0361 - val_accuracy: 0.8393
# Epoch 00091: LearningRateScheduler reducing learning rate to 1e-05 from 3.16e-05.
# Epoch 91/120
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9999
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 3.1622775802825263e-06.
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1055 - accuracy: 0.9999 - val_loss: 1.0315 - val_accuracy: 0.8403
# Epoch 00092: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 92/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1048 - accuracy: 0.9999 - val_loss: 1.0331 - val_accuracy: 0.8398
# Epoch 00093: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 93/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1046 - accuracy: 0.9999 - val_loss: 1.0339 - val_accuracy: 0.8410
# Epoch 00094: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 94/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1043 - accuracy: 0.9999 - val_loss: 1.0309 - val_accuracy: 0.8411
# Epoch 00095: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 95/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1039 - accuracy: 1.0000 - val_loss: 1.0336 - val_accuracy: 0.8405
# Epoch 00096: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 96/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1036 - accuracy: 1.0000 - val_loss: 1.0323 - val_accuracy: 0.8402
# Epoch 00097: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 97/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1032 - accuracy: 1.0000 - val_loss: 1.0311 - val_accuracy: 0.8407
# Epoch 00098: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 98/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1030 - accuracy: 1.0000 - val_loss: 1.0318 - val_accuracy: 0.8412
# Epoch 00099: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 99/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1026 - accuracy: 1.0000 - val_loss: 1.0324 - val_accuracy: 0.8400
# Epoch 00100: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 100/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1024 - accuracy: 0.9999 - val_loss: 1.0358 - val_accuracy: 0.8414
# Epoch 00101: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 101/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1022 - accuracy: 0.9999 - val_loss: 1.0359 - val_accuracy: 0.8407
# Epoch 00102: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 102/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1017 - accuracy: 0.9999 - val_loss: 1.0368 - val_accuracy: 0.8406
# Epoch 00103: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 103/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1015 - accuracy: 0.9999 - val_loss: 1.0351 - val_accuracy: 0.8417
# Epoch 00104: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 104/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1012 - accuracy: 1.0000 - val_loss: 1.0386 - val_accuracy: 0.8407
# Epoch 00105: Still keep learning rate 3.2e-06 instead of 1e-05
# Epoch 105/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1009 - accuracy: 1.0000 - val_loss: 1.0336 - val_accuracy: 0.8414
# Epoch 00106: LearningRateScheduler reducing learning rate to 1e-06 from 3.2e-06.
# Epoch 106/120
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.1006 - accuracy: 1.0000
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 5e-07.
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1006 - accuracy: 1.0000 - val_loss: 1.0363 - val_accuracy: 0.8419
# Epoch 00107: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 107/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1005 - accuracy: 1.0000 - val_loss: 1.0355 - val_accuracy: 0.8411
# Epoch 00108: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 108/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1006 - accuracy: 1.0000 - val_loss: 1.0367 - val_accuracy: 0.8408
# Epoch 00109: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 109/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1004 - accuracy: 1.0000 - val_loss: 1.0355 - val_accuracy: 0.8410
# Epoch 00110: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 110/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1004 - accuracy: 1.0000 - val_loss: 1.0381 - val_accuracy: 0.8412
# Epoch 00111: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 111/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 1.0342 - val_accuracy: 0.8416
# Epoch 00112: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 112/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 1.0364 - val_accuracy: 0.8408
# Epoch 00113: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 113/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 1.0377 - val_accuracy: 0.8415
# Epoch 00114: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 114/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1002 - accuracy: 0.9999 - val_loss: 1.0361 - val_accuracy: 0.8409
# Epoch 00115: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 115/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1001 - accuracy: 0.9999 - val_loss: 1.0392 - val_accuracy: 0.8403
# Epoch 00116: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 116/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1001 - accuracy: 1.0000 - val_loss: 1.0354 - val_accuracy: 0.8416
# Epoch 00117: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 117/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1000 - accuracy: 0.9999 - val_loss: 1.0341 - val_accuracy: 0.8420
# Epoch 00118: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 118/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.1000 - accuracy: 0.9999 - val_loss: 1.0343 - val_accuracy: 0.8419
# Epoch 00119: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 119/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.0999 - accuracy: 1.0000 - val_loss: 1.0374 - val_accuracy: 0.8406
# Epoch 00120: Still keep learning rate 5e-07 instead of 1e-06
# Epoch 120/120
# 1562/1562 [==============================] - 22s 14ms/step - loss: 0.0998 - accuracy: 1.0000 - val_loss: 1.0343 - val_accuracy: 0.8410
# 2020-12-31 09:57:40,262: INFO: finish training [elapsed time: 2737.30 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:1.0240, Test Accuracy:84.36%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#               train_loss  train_accuracy  test_loss  test_accuracy  \
# vgg8            0.002738          0.9997   0.516973         0.8925
# resnet_v1_20    0.123710          1.0000   1.023972         0.8436
# custom_cnn      0.310251          0.8954   0.583991         0.7999
# lenet           0.466231          0.8435   0.784104         0.7287
# mlp             1.594395          0.4305   1.672060         0.3984
#
#               weight_number  train_time
# vgg8                1672906      1969.0
# resnet_v1_20         273066      2737.0
# custom_cnn            73738       825.0
# lenet                 83170       788.0
# mlp                  394634       550.0

# %% [markdown]
# ## 总结
