# %% [markdown]
# ---
# title: Fashion MNIST
# categories: deep-learning
# date: 2020-12-15
# ---
#
#
# 数据集State-of-the-Art详见
#
# - [mnist](https://paperswithcode.com/sota/image-classification-on-mnist)
# - [fashion-mnist](https://paperswithcode.com/sota/image-classification-on-fashion-mnist)
# - [cifar-10](https://paperswithcode.com/sota/image-classification-on-cifar-10)
#
# ## 初始化
#
# 首先引入所用的包。然后是一些公共函数。下面代码比较长，可以先把函数的中文解释看过就好，细节忽略，后面用到再回来看。

# %%
import sys
from tensorflow.keras import Model, layers, regularizers, preprocessing

base_path = '/tf/eipi10/xuxiangwen.github.io/_notes/05-ai/54-tensorflow/code'
sys.path.append(base_path)

from image_classification import set_gpu_memory, lr_schedule, image_data_generator 
from image_classification import ImageClassificationHelper, ImageDataset

set_gpu_memory(1024)
model_results={}

# 代码自动重新加载
# %load_ext autoreload
# %autoreload 2

# #当module有新的方法的时候，需要运行下面方法。
# %reload_ext autoreload
# Out:
# set max gpu memory to 1024

# %% [markdown]
# 下面初始化模型运行的参数。

# %%
def image_data_generator():
    datagen = preprocessing.image.ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=False,
        # randomly flip images
        vertical_flip=False
    )    
    return datagen  

params = {
    'dataset_name': 'fashion-mnist-aug',
    'validation_percent': 0,    
    'use_data_augmentation': True,
    'augmentation_generator': image_data_generator(),   
    'batch_size': 32,    
    'epochs': 120,    
    'learning_rate':0.001,
    'dropout':0.1,
    'metrics':['accuracy'], 
    'use_lr_schedule': False,
    'lr_schedule': lr_schedule,
    'model_params':{
        'mlp':{'dropout':0.1},
        'lenet':{'dropout':0.1},
        'custom':{'dropout':0.2},
        'vgg':{'dropout':0.3},
        'resnet':{}
    }
}

helper = ImageClassificationHelper()
helper.set_params(params)
helper.set_model_results(model_results)
helper.set_data(ImageDataset(params))
# Out:
# load fashion-mnist-aug data from source
# train: (60000, 28, 28, 1) (60000,)
# test: (10000, 28, 28, 1) (10000,)
# create train, validation and test dataset

# %% [markdown]
# ## 数据
#
# MNIST数据集包含60,000张training图片和10,000张test图片，每张图片由$28\times28$ 个像素点构成，每个像素点用一个灰度值(0−255)表示。下面查看一下其中的图片。

# %%
images, labels = iter(helper.data.train_dataset).next()
helper.show_images(images, labels, x_num=4, y_num=8, figsize=(12, 6))

# %% [markdown]
# 然后看看做了data augmentation的图片。

# %%
images, labels = helper.data.train_dataset_aug.next()
helper.show_images(images, labels, x_num=4, y_num=8, figsize=(12, 6))

# %% [markdown]
# 下面来看看各个class的数据分布。可以看到各个数字的分布还是比较均匀的。

# %%
helper.plot_distribution()

# %% [markdown]
# ## MLP

# %%
def get_mlp(helper, name='mlp', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name) 
    print('dropout={}'.format(dropout))
    
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Flatten()(input)
    x = layers.Dense(128, activation='relu')(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model

model = get_mlp(helper)
model.summary()
# Out:
# dropout=0.1
# learning_rate=0.001
# checkpoint_path=./checkpoints/fashion-mnist-aug/mlp/checkpoint
# Model: "mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 下面来训练模型。

# %%
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 16:01:12,017: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.7406 - accuracy: 0.7252 - val_loss: 0.5724 - val_accuracy: 0.7910
# Epoch 2/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.5813 - accuracy: 0.7836 - val_loss: 0.5054 - val_accuracy: 0.8149
# Epoch 3/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.5375 - accuracy: 0.8005 - val_loss: 0.4841 - val_accuracy: 0.8150
# Epoch 4/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.5164 - accuracy: 0.8081 - val_loss: 0.4842 - val_accuracy: 0.8049
# Epoch 5/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.5003 - accuracy: 0.8130 - val_loss: 0.4509 - val_accuracy: 0.8342
# Epoch 6/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4881 - accuracy: 0.8188 - val_loss: 0.4633 - val_accuracy: 0.8267
# Epoch 7/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4792 - accuracy: 0.8224 - val_loss: 0.4570 - val_accuracy: 0.8356
# Epoch 8/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4703 - accuracy: 0.8256 - val_loss: 0.4479 - val_accuracy: 0.8307
# Epoch 9/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4623 - accuracy: 0.8294 - val_loss: 0.4133 - val_accuracy: 0.8514
# Epoch 10/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4575 - accuracy: 0.8313 - val_loss: 0.4127 - val_accuracy: 0.8510
# Epoch 11/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4520 - accuracy: 0.8336 - val_loss: 0.4226 - val_accuracy: 0.8450
# Epoch 12/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4505 - accuracy: 0.8342 - val_loss: 0.4017 - val_accuracy: 0.8547
# Epoch 13/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4457 - accuracy: 0.8346 - val_loss: 0.4107 - val_accuracy: 0.8491
# Epoch 14/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4440 - accuracy: 0.8364 - val_loss: 0.4096 - val_accuracy: 0.8507
# Epoch 15/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4417 - accuracy: 0.8360 - val_loss: 0.4096 - val_accuracy: 0.8513
# Epoch 16/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4387 - accuracy: 0.8372 - val_loss: 0.4068 - val_accuracy: 0.8518
# Epoch 17/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4372 - accuracy: 0.8388 - val_loss: 0.4002 - val_accuracy: 0.8509
# Epoch 18/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4308 - accuracy: 0.8404 - val_loss: 0.4046 - val_accuracy: 0.8570
# Epoch 19/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4315 - accuracy: 0.8406 - val_loss: 0.3897 - val_accuracy: 0.8603
# Epoch 20/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4312 - accuracy: 0.8401 - val_loss: 0.3855 - val_accuracy: 0.8631
# Epoch 21/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4281 - accuracy: 0.8420 - val_loss: 0.3940 - val_accuracy: 0.8592
# Epoch 22/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4268 - accuracy: 0.8418 - val_loss: 0.3931 - val_accuracy: 0.8612
# Epoch 23/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4256 - accuracy: 0.8420 - val_loss: 0.4114 - val_accuracy: 0.8485
# Epoch 24/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4212 - accuracy: 0.8442 - val_loss: 0.4002 - val_accuracy: 0.8595
# Epoch 25/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4197 - accuracy: 0.8441 - val_loss: 0.4033 - val_accuracy: 0.8545
# Epoch 26/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4226 - accuracy: 0.8438 - val_loss: 0.3905 - val_accuracy: 0.8601
# Epoch 27/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4221 - accuracy: 0.8433 - val_loss: 0.3887 - val_accuracy: 0.8606
# Epoch 28/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4174 - accuracy: 0.8470 - val_loss: 0.3855 - val_accuracy: 0.8623
# Epoch 29/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4155 - accuracy: 0.8465 - val_loss: 0.3962 - val_accuracy: 0.8585
# Epoch 30/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4152 - accuracy: 0.8462 - val_loss: 0.3913 - val_accuracy: 0.8651
# Epoch 31/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4152 - accuracy: 0.8457 - val_loss: 0.3978 - val_accuracy: 0.8570
# Epoch 32/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4141 - accuracy: 0.8458 - val_loss: 0.4046 - val_accuracy: 0.8555
# Epoch 33/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4105 - accuracy: 0.8493 - val_loss: 0.3949 - val_accuracy: 0.8591
# Epoch 34/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4112 - accuracy: 0.8483 - val_loss: 0.3803 - val_accuracy: 0.8660
# Epoch 35/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4078 - accuracy: 0.8491 - val_loss: 0.3941 - val_accuracy: 0.8637
# Epoch 36/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4079 - accuracy: 0.8505 - val_loss: 0.3855 - val_accuracy: 0.8626
# Epoch 37/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4075 - accuracy: 0.8488 - val_loss: 0.3923 - val_accuracy: 0.8584
# Epoch 38/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4084 - accuracy: 0.8503 - val_loss: 0.3842 - val_accuracy: 0.8628
# Epoch 39/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4049 - accuracy: 0.8515 - val_loss: 0.3799 - val_accuracy: 0.8639
# Epoch 40/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4060 - accuracy: 0.8501 - val_loss: 0.3788 - val_accuracy: 0.8657
# Epoch 41/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4034 - accuracy: 0.8521 - val_loss: 0.3829 - val_accuracy: 0.8641
# Epoch 42/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4028 - accuracy: 0.8507 - val_loss: 0.3808 - val_accuracy: 0.8610
# Epoch 43/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4035 - accuracy: 0.8514 - val_loss: 0.3787 - val_accuracy: 0.8645
# Epoch 44/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4007 - accuracy: 0.8523 - val_loss: 0.3725 - val_accuracy: 0.8707
# Epoch 45/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4045 - accuracy: 0.8503 - val_loss: 0.3672 - val_accuracy: 0.8718
# Epoch 46/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4001 - accuracy: 0.8521 - val_loss: 0.3701 - val_accuracy: 0.8705
# Epoch 47/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4021 - accuracy: 0.8499 - val_loss: 0.3694 - val_accuracy: 0.8693
# Epoch 48/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4029 - accuracy: 0.8512 - val_loss: 0.3836 - val_accuracy: 0.8612
# Epoch 49/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3998 - accuracy: 0.8523 - val_loss: 0.3994 - val_accuracy: 0.8584
# Epoch 50/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3999 - accuracy: 0.8529 - val_loss: 0.3777 - val_accuracy: 0.8661
# Epoch 51/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3992 - accuracy: 0.8527 - val_loss: 0.3799 - val_accuracy: 0.8620
# Epoch 52/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3963 - accuracy: 0.8551 - val_loss: 0.3711 - val_accuracy: 0.8686
# Epoch 53/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4001 - accuracy: 0.8520 - val_loss: 0.3791 - val_accuracy: 0.8647
# Epoch 54/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3920 - accuracy: 0.8544 - val_loss: 0.3677 - val_accuracy: 0.8687
# Epoch 55/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3979 - accuracy: 0.8537 - val_loss: 0.3765 - val_accuracy: 0.8651
# Epoch 56/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4006 - accuracy: 0.8531 - val_loss: 0.3783 - val_accuracy: 0.8656
# Epoch 57/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3956 - accuracy: 0.8548 - val_loss: 0.3672 - val_accuracy: 0.8713
# Epoch 58/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3961 - accuracy: 0.8551 - val_loss: 0.3841 - val_accuracy: 0.8583
# Epoch 59/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3940 - accuracy: 0.8554 - val_loss: 0.3805 - val_accuracy: 0.8631
# Epoch 60/120
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.3913 - accuracy: 0.8553
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3914 - accuracy: 0.8553 - val_loss: 0.3846 - val_accuracy: 0.8662
# Epoch 61/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3706 - accuracy: 0.8616 - val_loss: 0.3549 - val_accuracy: 0.8734
# Epoch 62/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3700 - accuracy: 0.8640 - val_loss: 0.3549 - val_accuracy: 0.8746
# Epoch 63/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3656 - accuracy: 0.8654 - val_loss: 0.3547 - val_accuracy: 0.8745
# Epoch 64/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3656 - accuracy: 0.8652 - val_loss: 0.3482 - val_accuracy: 0.8768
# Epoch 65/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3657 - accuracy: 0.8652 - val_loss: 0.3543 - val_accuracy: 0.8732
# Epoch 66/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3681 - accuracy: 0.8657 - val_loss: 0.3547 - val_accuracy: 0.8735
# Epoch 67/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3660 - accuracy: 0.8664 - val_loss: 0.3527 - val_accuracy: 0.8763
# Epoch 68/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3628 - accuracy: 0.8660 - val_loss: 0.3521 - val_accuracy: 0.8744
# Epoch 69/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3616 - accuracy: 0.8667 - val_loss: 0.3511 - val_accuracy: 0.8759
# Epoch 70/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3641 - accuracy: 0.8658 - val_loss: 0.3526 - val_accuracy: 0.8737
# Epoch 71/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3653 - accuracy: 0.8653 - val_loss: 0.3557 - val_accuracy: 0.8746
# Epoch 72/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3629 - accuracy: 0.8649 - val_loss: 0.3514 - val_accuracy: 0.8760
# Epoch 73/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3671 - accuracy: 0.8640 - val_loss: 0.3532 - val_accuracy: 0.8768
# Epoch 74/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3638 - accuracy: 0.8669 - val_loss: 0.3482 - val_accuracy: 0.8771
# Epoch 75/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3649 - accuracy: 0.8647 - val_loss: 0.3550 - val_accuracy: 0.8748
# Epoch 76/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3603 - accuracy: 0.8685 - val_loss: 0.3535 - val_accuracy: 0.8759
# Epoch 77/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3636 - accuracy: 0.8661 - val_loss: 0.3521 - val_accuracy: 0.8758
# Epoch 78/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3626 - accuracy: 0.8658 - val_loss: 0.3527 - val_accuracy: 0.8756
# Epoch 79/120
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.3625 - accuracy: 0.8656
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3625 - accuracy: 0.8657 - val_loss: 0.3544 - val_accuracy: 0.8764
# Epoch 80/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3557 - accuracy: 0.8688 - val_loss: 0.3495 - val_accuracy: 0.8787
# Epoch 81/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3562 - accuracy: 0.8691 - val_loss: 0.3489 - val_accuracy: 0.8799
# Epoch 82/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3533 - accuracy: 0.8696 - val_loss: 0.3489 - val_accuracy: 0.8770
# Epoch 83/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3534 - accuracy: 0.8689 - val_loss: 0.3458 - val_accuracy: 0.8780
# Epoch 84/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3560 - accuracy: 0.8700 - val_loss: 0.3462 - val_accuracy: 0.8798
# Epoch 85/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3542 - accuracy: 0.8696 - val_loss: 0.3473 - val_accuracy: 0.8781
# Epoch 86/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3530 - accuracy: 0.8692 - val_loss: 0.3459 - val_accuracy: 0.8797
# Epoch 87/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3540 - accuracy: 0.8698 - val_loss: 0.3465 - val_accuracy: 0.8791
# Epoch 88/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3539 - accuracy: 0.8701 - val_loss: 0.3486 - val_accuracy: 0.8773
# Epoch 89/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3543 - accuracy: 0.8689 - val_loss: 0.3457 - val_accuracy: 0.8791
# Epoch 90/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3544 - accuracy: 0.8702 - val_loss: 0.3463 - val_accuracy: 0.8787
# Epoch 91/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3541 - accuracy: 0.8684 - val_loss: 0.3451 - val_accuracy: 0.8805
# Epoch 92/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3522 - accuracy: 0.8699 - val_loss: 0.3463 - val_accuracy: 0.8793
# Epoch 93/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3555 - accuracy: 0.8686 - val_loss: 0.3474 - val_accuracy: 0.8779
# Epoch 94/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3505 - accuracy: 0.8694 - val_loss: 0.3438 - val_accuracy: 0.8798
# Epoch 95/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3529 - accuracy: 0.8711 - val_loss: 0.3454 - val_accuracy: 0.8788
# Epoch 96/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3537 - accuracy: 0.8693 - val_loss: 0.3444 - val_accuracy: 0.8791
# Epoch 97/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3539 - accuracy: 0.8694 - val_loss: 0.3446 - val_accuracy: 0.8797
# Epoch 98/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3548 - accuracy: 0.8692 - val_loss: 0.3435 - val_accuracy: 0.8797
# Epoch 99/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3534 - accuracy: 0.8708 - val_loss: 0.3459 - val_accuracy: 0.8787
# Epoch 100/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3524 - accuracy: 0.8704 - val_loss: 0.3467 - val_accuracy: 0.8776
# Epoch 101/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3545 - accuracy: 0.8686 - val_loss: 0.3463 - val_accuracy: 0.8770
# Epoch 102/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3559 - accuracy: 0.8687 - val_loss: 0.3428 - val_accuracy: 0.8768
# Epoch 103/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3519 - accuracy: 0.8701 - val_loss: 0.3474 - val_accuracy: 0.8781
# Epoch 104/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3526 - accuracy: 0.8696 - val_loss: 0.3437 - val_accuracy: 0.8781
# Epoch 105/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3491 - accuracy: 0.8716 - val_loss: 0.3466 - val_accuracy: 0.8798
# Epoch 106/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3521 - accuracy: 0.8712 - val_loss: 0.3453 - val_accuracy: 0.8767
# Epoch 107/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3484 - accuracy: 0.8713 - val_loss: 0.3446 - val_accuracy: 0.8808
# Epoch 108/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3504 - accuracy: 0.8718 - val_loss: 0.3451 - val_accuracy: 0.8776
# Epoch 109/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3499 - accuracy: 0.8711 - val_loss: 0.3478 - val_accuracy: 0.8768
# Epoch 110/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3504 - accuracy: 0.8704 - val_loss: 0.3455 - val_accuracy: 0.8770
# Epoch 111/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3492 - accuracy: 0.8707 - val_loss: 0.3465 - val_accuracy: 0.8780
# Epoch 112/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3524 - accuracy: 0.8701 - val_loss: 0.3466 - val_accuracy: 0.8790
# Epoch 113/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3521 - accuracy: 0.8708 - val_loss: 0.3470 - val_accuracy: 0.8780
# Epoch 114/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3521 - accuracy: 0.8701 - val_loss: 0.3475 - val_accuracy: 0.8763
# Epoch 115/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3498 - accuracy: 0.8717 - val_loss: 0.3449 - val_accuracy: 0.8779
# Epoch 116/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3500 - accuracy: 0.8724 - val_loss: 0.3431 - val_accuracy: 0.8797
# Epoch 117/120
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.3510 - accuracy: 0.8717
# Epoch 00117: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3510 - accuracy: 0.8717 - val_loss: 0.3438 - val_accuracy: 0.8773
# Epoch 118/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3474 - accuracy: 0.8721 - val_loss: 0.3436 - val_accuracy: 0.8785
# Epoch 119/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3487 - accuracy: 0.8718 - val_loss: 0.3430 - val_accuracy: 0.8782
# Epoch 120/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3485 - accuracy: 0.8731 - val_loss: 0.3424 - val_accuracy: 0.8784
# 2020-12-25 16:41:29,808: INFO: finish training [elapsed time: 2417.79 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.3446, Test Accuracy:88.08%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#      train_loss  train_accuracy  test_loss  test_accuracy  weight_number  \
# mlp    0.290463          0.8934   0.344575         0.8808         101770
#
#      train_time
# mlp      2417.0

# %% [markdown]
# 从上面的错误来看，模型对一些细节的判断不是很准。下面来尝试一下LeNet。
#
# ## LeNet
#
# ![image-20201019113632136](images/image-20201019113632136.png)
#
# LeNet诞生于1994年，是Yann LeCun等人提出的，是最早的卷积神经网络之一。在LeNet中，输入层是32×32的图片，而MNIST是28×28的图片，为了保持模型的结构不变，在第一个Conv2D设置参数padding=’same’。首先创建模型，并训练。

# %%
def get_lenet(helper, name='lenet', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name) 
    print('dropout={}'.format(dropout))
    
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Conv2D(6, (5, 5), activation='relu', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(16, (5, 5), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)   
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(120, activation='relu')(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(84, activation='relu')(x)   
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)  

    return model    

# 创建模型
model = get_lenet(helper)
model.summary()
# Out:
# dropout=0.1
# learning_rate=0.001
# checkpoint_path=./checkpoints/fashion-mnist-aug/lenet/checkpoint
# Model: "lenet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 6)         24
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 16)        64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 84)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,794
# Trainable params: 61,750
# Non-trainable params: 44
# _________________________________________________________________

# %% [markdown]
# 下面来训练模型。

# %%
# 训练
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 16:41:37,964: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.6238 - accuracy: 0.7636 - val_loss: 0.4453 - val_accuracy: 0.8353
# Epoch 2/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4723 - accuracy: 0.8223 - val_loss: 0.3764 - val_accuracy: 0.8603
# Epoch 3/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4346 - accuracy: 0.8364 - val_loss: 0.3506 - val_accuracy: 0.8663
# Epoch 4/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4121 - accuracy: 0.8438 - val_loss: 0.3323 - val_accuracy: 0.8723
# Epoch 5/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3978 - accuracy: 0.8508 - val_loss: 0.3179 - val_accuracy: 0.8775
# Epoch 6/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3805 - accuracy: 0.8572 - val_loss: 0.3255 - val_accuracy: 0.8760
# Epoch 7/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3713 - accuracy: 0.8597 - val_loss: 0.3096 - val_accuracy: 0.8812
# Epoch 8/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3634 - accuracy: 0.8631 - val_loss: 0.3118 - val_accuracy: 0.8824
# Epoch 9/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3553 - accuracy: 0.8655 - val_loss: 0.3071 - val_accuracy: 0.8832
# Epoch 10/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3492 - accuracy: 0.8676 - val_loss: 0.3716 - val_accuracy: 0.8500
# Epoch 11/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3453 - accuracy: 0.8688 - val_loss: 0.2840 - val_accuracy: 0.8944
# Epoch 12/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3388 - accuracy: 0.8712 - val_loss: 0.2989 - val_accuracy: 0.8858
# Epoch 13/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3414 - accuracy: 0.8720 - val_loss: 0.2804 - val_accuracy: 0.8939
# Epoch 14/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3330 - accuracy: 0.8756 - val_loss: 0.2778 - val_accuracy: 0.8970
# Epoch 15/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3283 - accuracy: 0.8777 - val_loss: 0.2741 - val_accuracy: 0.8938
# Epoch 16/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3253 - accuracy: 0.8780 - val_loss: 0.2784 - val_accuracy: 0.8948
# Epoch 17/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3245 - accuracy: 0.8802 - val_loss: 0.2942 - val_accuracy: 0.8875
# Epoch 18/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3168 - accuracy: 0.8800 - val_loss: 0.2813 - val_accuracy: 0.8934
# Epoch 19/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3149 - accuracy: 0.8805 - val_loss: 0.2725 - val_accuracy: 0.8969
# Epoch 20/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3147 - accuracy: 0.8802 - val_loss: 0.2893 - val_accuracy: 0.8882
# Epoch 21/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3128 - accuracy: 0.8812 - val_loss: 0.2713 - val_accuracy: 0.8983
# Epoch 22/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3107 - accuracy: 0.8830 - val_loss: 0.2616 - val_accuracy: 0.9016
# Epoch 23/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3094 - accuracy: 0.8827 - val_loss: 0.2619 - val_accuracy: 0.9010
# Epoch 24/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3063 - accuracy: 0.8845 - val_loss: 0.2797 - val_accuracy: 0.8945
# Epoch 25/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3039 - accuracy: 0.8850 - val_loss: 0.2661 - val_accuracy: 0.9021
# Epoch 26/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3012 - accuracy: 0.8863 - val_loss: 0.2682 - val_accuracy: 0.8990
# Epoch 27/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3016 - accuracy: 0.8866 - val_loss: 0.3009 - val_accuracy: 0.8860
# Epoch 28/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2970 - accuracy: 0.8879 - val_loss: 0.2624 - val_accuracy: 0.9017
# Epoch 29/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2956 - accuracy: 0.8892 - val_loss: 0.2826 - val_accuracy: 0.8965
# Epoch 30/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2956 - accuracy: 0.8888 - val_loss: 0.2732 - val_accuracy: 0.8958
# Epoch 31/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2963 - accuracy: 0.8868 - val_loss: 0.2693 - val_accuracy: 0.8948
# Epoch 32/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2918 - accuracy: 0.8895 - val_loss: 0.2663 - val_accuracy: 0.8986
# Epoch 33/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2936 - accuracy: 0.8900 - val_loss: 0.2958 - val_accuracy: 0.8891
# Epoch 34/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2942 - accuracy: 0.8899 - val_loss: 0.2491 - val_accuracy: 0.9076
# Epoch 35/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2901 - accuracy: 0.8915 - val_loss: 0.2896 - val_accuracy: 0.8894
# Epoch 36/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2935 - accuracy: 0.8892 - val_loss: 0.2578 - val_accuracy: 0.9060
# Epoch 37/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2894 - accuracy: 0.8916 - val_loss: 0.2701 - val_accuracy: 0.8941
# Epoch 38/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2881 - accuracy: 0.8926 - val_loss: 0.2529 - val_accuracy: 0.9042
# Epoch 39/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2878 - accuracy: 0.8913 - val_loss: 0.2546 - val_accuracy: 0.9043
# Epoch 40/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2863 - accuracy: 0.8916 - val_loss: 0.2567 - val_accuracy: 0.9034
# Epoch 41/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2832 - accuracy: 0.8914 - val_loss: 0.2537 - val_accuracy: 0.9018
# Epoch 42/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2861 - accuracy: 0.8931 - val_loss: 0.2798 - val_accuracy: 0.8969
# Epoch 43/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2858 - accuracy: 0.8918 - val_loss: 0.2504 - val_accuracy: 0.9068
# Epoch 44/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2850 - accuracy: 0.8915 - val_loss: 0.2486 - val_accuracy: 0.9070
# Epoch 45/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2831 - accuracy: 0.8933 - val_loss: 0.2481 - val_accuracy: 0.9091
# Epoch 46/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2838 - accuracy: 0.8937 - val_loss: 0.2835 - val_accuracy: 0.8915
# Epoch 47/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2807 - accuracy: 0.8939 - val_loss: 0.2506 - val_accuracy: 0.9070
# Epoch 48/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2817 - accuracy: 0.8952 - val_loss: 0.2468 - val_accuracy: 0.9089
# Epoch 49/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2802 - accuracy: 0.8939 - val_loss: 0.2467 - val_accuracy: 0.9058
# Epoch 50/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2819 - accuracy: 0.8943 - val_loss: 0.2521 - val_accuracy: 0.9048
# Epoch 51/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2748 - accuracy: 0.8973 - val_loss: 0.2408 - val_accuracy: 0.9083
# Epoch 52/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2783 - accuracy: 0.8946 - val_loss: 0.2455 - val_accuracy: 0.9099
# Epoch 53/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2752 - accuracy: 0.8968 - val_loss: 0.2417 - val_accuracy: 0.9101
# Epoch 54/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2750 - accuracy: 0.8948 - val_loss: 0.2556 - val_accuracy: 0.9048
# Epoch 55/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2745 - accuracy: 0.8957 - val_loss: 0.2478 - val_accuracy: 0.9086
# Epoch 56/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2778 - accuracy: 0.8949 - val_loss: 0.2586 - val_accuracy: 0.8994
# Epoch 57/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2747 - accuracy: 0.8960 - val_loss: 0.2587 - val_accuracy: 0.9033
# Epoch 58/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2776 - accuracy: 0.8964 - val_loss: 0.2454 - val_accuracy: 0.9071
# Epoch 59/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2747 - accuracy: 0.8957 - val_loss: 0.2486 - val_accuracy: 0.9069
# Epoch 60/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2746 - accuracy: 0.8956 - val_loss: 0.2497 - val_accuracy: 0.9062
# Epoch 61/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2731 - accuracy: 0.8963 - val_loss: 0.2425 - val_accuracy: 0.9108
# Epoch 62/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2722 - accuracy: 0.8979 - val_loss: 0.2456 - val_accuracy: 0.9095
# Epoch 63/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2754 - accuracy: 0.8963 - val_loss: 0.2476 - val_accuracy: 0.9111
# Epoch 64/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2715 - accuracy: 0.8984 - val_loss: 0.2497 - val_accuracy: 0.9083
# Epoch 65/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2722 - accuracy: 0.8979 - val_loss: 0.2523 - val_accuracy: 0.9071
# Epoch 66/120
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.2730 - accuracy: 0.8982
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2730 - accuracy: 0.8981 - val_loss: 0.2633 - val_accuracy: 0.9021
# Epoch 67/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2570 - accuracy: 0.9019 - val_loss: 0.2355 - val_accuracy: 0.9113
# Epoch 68/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2539 - accuracy: 0.9036 - val_loss: 0.2417 - val_accuracy: 0.9080
# Epoch 69/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2531 - accuracy: 0.9040 - val_loss: 0.2370 - val_accuracy: 0.9114
# Epoch 70/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2545 - accuracy: 0.9045 - val_loss: 0.2339 - val_accuracy: 0.9150
# Epoch 71/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2520 - accuracy: 0.9058 - val_loss: 0.2377 - val_accuracy: 0.9121
# Epoch 72/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2499 - accuracy: 0.9058 - val_loss: 0.2335 - val_accuracy: 0.9150
# Epoch 73/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2466 - accuracy: 0.9062 - val_loss: 0.2415 - val_accuracy: 0.9094
# Epoch 74/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2489 - accuracy: 0.9066 - val_loss: 0.2394 - val_accuracy: 0.9093
# Epoch 75/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2498 - accuracy: 0.9054 - val_loss: 0.2299 - val_accuracy: 0.9141
# Epoch 76/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2478 - accuracy: 0.9066 - val_loss: 0.2339 - val_accuracy: 0.9134
# Epoch 77/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2499 - accuracy: 0.9053 - val_loss: 0.2302 - val_accuracy: 0.9147
# Epoch 78/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2499 - accuracy: 0.9061 - val_loss: 0.2310 - val_accuracy: 0.9138
# Epoch 79/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2483 - accuracy: 0.9065 - val_loss: 0.2308 - val_accuracy: 0.9142
# Epoch 80/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2493 - accuracy: 0.9047 - val_loss: 0.2331 - val_accuracy: 0.9126
# Epoch 81/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2453 - accuracy: 0.9083 - val_loss: 0.2320 - val_accuracy: 0.9157
# Epoch 82/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2478 - accuracy: 0.9067 - val_loss: 0.2316 - val_accuracy: 0.9145
# Epoch 83/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2449 - accuracy: 0.9068 - val_loss: 0.2315 - val_accuracy: 0.9137
# Epoch 84/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2499 - accuracy: 0.9064 - val_loss: 0.2340 - val_accuracy: 0.9149
# Epoch 85/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2474 - accuracy: 0.9066 - val_loss: 0.2357 - val_accuracy: 0.9150
# Epoch 86/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2487 - accuracy: 0.9058 - val_loss: 0.2371 - val_accuracy: 0.9141
# Epoch 87/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2485 - accuracy: 0.9069 - val_loss: 0.2305 - val_accuracy: 0.9154
# Epoch 88/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2456 - accuracy: 0.9083 - val_loss: 0.2361 - val_accuracy: 0.9143
# Epoch 89/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2441 - accuracy: 0.9078 - val_loss: 0.2337 - val_accuracy: 0.9149
# Epoch 90/120
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.2440 - accuracy: 0.9071
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2440 - accuracy: 0.9071 - val_loss: 0.2325 - val_accuracy: 0.9128
# Epoch 91/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2412 - accuracy: 0.9101 - val_loss: 0.2280 - val_accuracy: 0.9160
# Epoch 92/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2378 - accuracy: 0.9108 - val_loss: 0.2301 - val_accuracy: 0.9158
# Epoch 93/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2381 - accuracy: 0.9103 - val_loss: 0.2282 - val_accuracy: 0.9175
# Epoch 94/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2415 - accuracy: 0.9086 - val_loss: 0.2286 - val_accuracy: 0.9164
# Epoch 95/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2387 - accuracy: 0.9098 - val_loss: 0.2280 - val_accuracy: 0.9155
# Epoch 96/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2398 - accuracy: 0.9095 - val_loss: 0.2261 - val_accuracy: 0.9175
# Epoch 97/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2379 - accuracy: 0.9097 - val_loss: 0.2262 - val_accuracy: 0.9186
# Epoch 98/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2376 - accuracy: 0.9096 - val_loss: 0.2270 - val_accuracy: 0.9170
# Epoch 99/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2389 - accuracy: 0.9090 - val_loss: 0.2294 - val_accuracy: 0.9160
# Epoch 100/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2410 - accuracy: 0.9078 - val_loss: 0.2279 - val_accuracy: 0.9161
# Epoch 101/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2380 - accuracy: 0.9101 - val_loss: 0.2259 - val_accuracy: 0.9177
# Epoch 102/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2378 - accuracy: 0.9094 - val_loss: 0.2265 - val_accuracy: 0.9188
# Epoch 103/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2371 - accuracy: 0.9114 - val_loss: 0.2245 - val_accuracy: 0.9193
# Epoch 104/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2366 - accuracy: 0.9091 - val_loss: 0.2263 - val_accuracy: 0.9191
# Epoch 105/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2381 - accuracy: 0.9099 - val_loss: 0.2247 - val_accuracy: 0.9184
# Epoch 106/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2377 - accuracy: 0.9101 - val_loss: 0.2272 - val_accuracy: 0.9163
# Epoch 107/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2355 - accuracy: 0.9109 - val_loss: 0.2273 - val_accuracy: 0.9164
# Epoch 108/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2369 - accuracy: 0.9082 - val_loss: 0.2280 - val_accuracy: 0.9177
# Epoch 109/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2377 - accuracy: 0.9100 - val_loss: 0.2265 - val_accuracy: 0.9178
# Epoch 110/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2374 - accuracy: 0.9103 - val_loss: 0.2252 - val_accuracy: 0.9184
# Epoch 111/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2390 - accuracy: 0.9084 - val_loss: 0.2249 - val_accuracy: 0.9184
# Epoch 112/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2351 - accuracy: 0.9100 - val_loss: 0.2245 - val_accuracy: 0.9183
# Epoch 113/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2363 - accuracy: 0.9098 - val_loss: 0.2249 - val_accuracy: 0.9184
# Epoch 114/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2381 - accuracy: 0.9098 - val_loss: 0.2339 - val_accuracy: 0.9118
# Epoch 115/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2372 - accuracy: 0.9111 - val_loss: 0.2241 - val_accuracy: 0.9195
# Epoch 116/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2359 - accuracy: 0.9110 - val_loss: 0.2263 - val_accuracy: 0.9175
# Epoch 117/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2380 - accuracy: 0.9094 - val_loss: 0.2290 - val_accuracy: 0.9148
# Epoch 118/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2353 - accuracy: 0.9102 - val_loss: 0.2266 - val_accuracy: 0.9181
# Epoch 119/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2345 - accuracy: 0.9110 - val_loss: 0.2268 - val_accuracy: 0.9186
# Epoch 120/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2368 - accuracy: 0.9099 - val_loss: 0.2230 - val_accuracy: 0.9198
# 2020-12-25 17:22:13,816: INFO: finish training [elapsed time: 2435.85 seconds]

# %% [markdown]
# 下面来评估模型并和mlp模型进行对比。

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.2230, Test Accuracy:91.98%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#        train_loss  train_accuracy  test_loss  test_accuracy  weight_number  \
# lenet    0.164457          0.9375   0.222985         0.9198          61750
# mlp      0.290463          0.8934   0.344575         0.8808         101770
#
#        train_time
# lenet      2435.0
# mlp        2417.0

# %% [markdown]
# 从上面的图中，可以看到，Lenet的参数只有mlp的60%，但其的准确率比mlp提升了差不多1%。上面最后一张图中，有三列，第一列是数字图片，它们是mlp中分错的数字，第二列是mlp中的分类，第三列是lenet中的分类，可以看到lenet的确学到了一些mlp中没有的模式。下面再来看看哪些数字在lenet也分错了。

# %% [markdown]
# 上图中，可以看到对于部分数字的识别，mlp甚至要更好一点啊，还有一些数字，则是一起都错了。
#
# ## Custom 1
#
# 下面自己定义一个模型，这个模型和lenet的主要区别是，增加了卷积的深度。

# %%
def get_custom1(helper, name='custom_cnn', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name)
    print('dropout={}'.format(dropout))
        
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x) 
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation='relu')(x)  
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model   

# 创建模型
model = get_custom1(helper)
model.summary()
# Out:
# dropout=0.2
# learning_rate=0.001
# checkpoint_path=./checkpoints/fashion-mnist-aug/custom_cnn/checkpoint
# Model: "custom_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 73,482
# Trainable params: 73,162
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# 可以发现参数的个数已经和mlp差不多了，下面来训练模型。

# %%
# 训练
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 17:22:28,322: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.6842 - accuracy: 0.7455 - val_loss: 0.4659 - val_accuracy: 0.8258
# Epoch 2/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.4772 - accuracy: 0.8220 - val_loss: 0.3921 - val_accuracy: 0.8504
# Epoch 3/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.4262 - accuracy: 0.8425 - val_loss: 0.3744 - val_accuracy: 0.8593
# Epoch 4/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3994 - accuracy: 0.8528 - val_loss: 0.3213 - val_accuracy: 0.8799
# Epoch 5/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3807 - accuracy: 0.8601 - val_loss: 0.3042 - val_accuracy: 0.8857
# Epoch 6/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3648 - accuracy: 0.8665 - val_loss: 0.2950 - val_accuracy: 0.8909
# Epoch 7/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3566 - accuracy: 0.8677 - val_loss: 0.3116 - val_accuracy: 0.8836
# Epoch 8/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3495 - accuracy: 0.8724 - val_loss: 0.3693 - val_accuracy: 0.8648
# Epoch 9/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3464 - accuracy: 0.8713 - val_loss: 0.3079 - val_accuracy: 0.8857
# Epoch 10/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3384 - accuracy: 0.8745 - val_loss: 0.2703 - val_accuracy: 0.8978
# Epoch 11/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3284 - accuracy: 0.8801 - val_loss: 0.2704 - val_accuracy: 0.8985
# Epoch 12/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3261 - accuracy: 0.8806 - val_loss: 0.2962 - val_accuracy: 0.8875
# Epoch 13/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3223 - accuracy: 0.8807 - val_loss: 0.2844 - val_accuracy: 0.8889
# Epoch 14/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3137 - accuracy: 0.8839 - val_loss: 0.3253 - val_accuracy: 0.8741
# Epoch 15/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3153 - accuracy: 0.8828 - val_loss: 0.2673 - val_accuracy: 0.8995
# Epoch 16/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3086 - accuracy: 0.8858 - val_loss: 0.2579 - val_accuracy: 0.9034
# Epoch 17/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3073 - accuracy: 0.8862 - val_loss: 0.2998 - val_accuracy: 0.8824
# Epoch 18/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.3043 - accuracy: 0.8870 - val_loss: 0.2631 - val_accuracy: 0.8993
# Epoch 19/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2998 - accuracy: 0.8886 - val_loss: 0.2412 - val_accuracy: 0.9077
# Epoch 20/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2979 - accuracy: 0.8905 - val_loss: 0.3723 - val_accuracy: 0.8549
# Epoch 21/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2939 - accuracy: 0.8902 - val_loss: 0.3172 - val_accuracy: 0.8805
# Epoch 22/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2959 - accuracy: 0.8915 - val_loss: 0.2366 - val_accuracy: 0.9130
# Epoch 23/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2925 - accuracy: 0.8918 - val_loss: 0.3016 - val_accuracy: 0.8872
# Epoch 24/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2903 - accuracy: 0.8923 - val_loss: 0.2811 - val_accuracy: 0.8879
# Epoch 25/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2865 - accuracy: 0.8928 - val_loss: 0.2817 - val_accuracy: 0.8961
# Epoch 26/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2859 - accuracy: 0.8954 - val_loss: 0.2409 - val_accuracy: 0.9079
# Epoch 27/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2844 - accuracy: 0.8958 - val_loss: 0.2361 - val_accuracy: 0.9104
# Epoch 28/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2802 - accuracy: 0.8967 - val_loss: 0.2403 - val_accuracy: 0.9103
# Epoch 29/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2819 - accuracy: 0.8953 - val_loss: 0.2500 - val_accuracy: 0.9047
# Epoch 30/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2776 - accuracy: 0.8970 - val_loss: 0.3256 - val_accuracy: 0.8824
# Epoch 31/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2803 - accuracy: 0.8965 - val_loss: 0.2448 - val_accuracy: 0.9042
# Epoch 32/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2785 - accuracy: 0.8969 - val_loss: 0.2574 - val_accuracy: 0.9003
# Epoch 33/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2754 - accuracy: 0.8981 - val_loss: 0.2343 - val_accuracy: 0.9107
# Epoch 34/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2736 - accuracy: 0.9008 - val_loss: 0.2615 - val_accuracy: 0.8998
# Epoch 35/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2730 - accuracy: 0.8999 - val_loss: 0.2321 - val_accuracy: 0.9126
# Epoch 36/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2721 - accuracy: 0.8993 - val_loss: 0.3447 - val_accuracy: 0.8657
# Epoch 37/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2724 - accuracy: 0.8995 - val_loss: 0.2758 - val_accuracy: 0.8955
# Epoch 38/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2689 - accuracy: 0.9010 - val_loss: 0.2327 - val_accuracy: 0.9143
# Epoch 39/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2653 - accuracy: 0.9015 - val_loss: 0.3211 - val_accuracy: 0.8853
# Epoch 40/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2694 - accuracy: 0.9018 - val_loss: 0.2281 - val_accuracy: 0.9126
# Epoch 41/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2675 - accuracy: 0.9018 - val_loss: 0.2546 - val_accuracy: 0.8997
# Epoch 42/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2668 - accuracy: 0.9008 - val_loss: 0.2201 - val_accuracy: 0.9185
# Epoch 43/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2645 - accuracy: 0.9025 - val_loss: 0.2201 - val_accuracy: 0.9156
# Epoch 44/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2640 - accuracy: 0.9031 - val_loss: 0.2631 - val_accuracy: 0.8964
# Epoch 45/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2644 - accuracy: 0.9031 - val_loss: 0.2248 - val_accuracy: 0.9144
# Epoch 46/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2620 - accuracy: 0.9029 - val_loss: 0.2205 - val_accuracy: 0.9177
# Epoch 47/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2648 - accuracy: 0.9022 - val_loss: 0.2552 - val_accuracy: 0.9021
# Epoch 48/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2624 - accuracy: 0.9034 - val_loss: 0.2485 - val_accuracy: 0.9043
# Epoch 49/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2610 - accuracy: 0.9046 - val_loss: 0.2502 - val_accuracy: 0.9027
# Epoch 50/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2602 - accuracy: 0.9037 - val_loss: 0.2192 - val_accuracy: 0.9170
# Epoch 51/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2616 - accuracy: 0.9040 - val_loss: 0.2423 - val_accuracy: 0.9058
# Epoch 52/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2573 - accuracy: 0.9044 - val_loss: 0.2192 - val_accuracy: 0.9170
# Epoch 53/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2587 - accuracy: 0.9042 - val_loss: 0.2521 - val_accuracy: 0.9024
# Epoch 54/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2568 - accuracy: 0.9052 - val_loss: 0.2300 - val_accuracy: 0.9110
# Epoch 55/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2594 - accuracy: 0.9043 - val_loss: 0.2149 - val_accuracy: 0.9202
# Epoch 56/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2556 - accuracy: 0.9066 - val_loss: 0.2270 - val_accuracy: 0.9125
# Epoch 57/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2549 - accuracy: 0.9066 - val_loss: 0.2554 - val_accuracy: 0.9026
# Epoch 58/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2551 - accuracy: 0.9050 - val_loss: 0.2530 - val_accuracy: 0.9035
# Epoch 59/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2559 - accuracy: 0.9064 - val_loss: 0.2195 - val_accuracy: 0.9188
# Epoch 60/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2559 - accuracy: 0.9065 - val_loss: 0.2456 - val_accuracy: 0.9057
# Epoch 61/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2557 - accuracy: 0.9049 - val_loss: 0.2580 - val_accuracy: 0.9006
# Epoch 62/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2530 - accuracy: 0.9061 - val_loss: 0.2283 - val_accuracy: 0.9127
# Epoch 63/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2550 - accuracy: 0.9064 - val_loss: 0.2768 - val_accuracy: 0.8934
# Epoch 64/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2518 - accuracy: 0.9066 - val_loss: 0.2558 - val_accuracy: 0.9014
# Epoch 65/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2534 - accuracy: 0.9068 - val_loss: 0.2755 - val_accuracy: 0.8907
# Epoch 66/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2539 - accuracy: 0.9070 - val_loss: 0.2116 - val_accuracy: 0.9222
# Epoch 67/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2521 - accuracy: 0.9077 - val_loss: 0.2171 - val_accuracy: 0.9194
# Epoch 68/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2505 - accuracy: 0.9077 - val_loss: 0.2306 - val_accuracy: 0.9142
# Epoch 69/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2518 - accuracy: 0.9079 - val_loss: 0.2382 - val_accuracy: 0.9108
# Epoch 70/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2520 - accuracy: 0.9067 - val_loss: 0.2189 - val_accuracy: 0.9162
# Epoch 71/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2499 - accuracy: 0.9081 - val_loss: 0.2076 - val_accuracy: 0.9222
# Epoch 72/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2492 - accuracy: 0.9070 - val_loss: 0.2131 - val_accuracy: 0.9213
# Epoch 73/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2449 - accuracy: 0.9102 - val_loss: 0.2137 - val_accuracy: 0.9212
# Epoch 74/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2500 - accuracy: 0.9076 - val_loss: 0.2121 - val_accuracy: 0.9216
# Epoch 75/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2451 - accuracy: 0.9096 - val_loss: 0.2053 - val_accuracy: 0.9237
# Epoch 76/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2492 - accuracy: 0.9057 - val_loss: 0.2138 - val_accuracy: 0.9244
# Epoch 77/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2487 - accuracy: 0.9085 - val_loss: 0.2037 - val_accuracy: 0.9223
# Epoch 78/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2489 - accuracy: 0.9073 - val_loss: 0.2392 - val_accuracy: 0.9088
# Epoch 79/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2470 - accuracy: 0.9093 - val_loss: 0.2740 - val_accuracy: 0.8947
# Epoch 80/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2447 - accuracy: 0.9101 - val_loss: 0.2298 - val_accuracy: 0.9177
# Epoch 81/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2473 - accuracy: 0.9104 - val_loss: 0.2127 - val_accuracy: 0.9214
# Epoch 82/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2444 - accuracy: 0.9097 - val_loss: 0.2383 - val_accuracy: 0.9100
# Epoch 83/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2452 - accuracy: 0.9094 - val_loss: 0.2184 - val_accuracy: 0.9175
# Epoch 84/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2458 - accuracy: 0.9093 - val_loss: 0.2044 - val_accuracy: 0.9227
# Epoch 85/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2468 - accuracy: 0.9102 - val_loss: 0.2769 - val_accuracy: 0.8936
# Epoch 86/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2452 - accuracy: 0.9090 - val_loss: 0.2296 - val_accuracy: 0.9130
# Epoch 87/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2437 - accuracy: 0.9098 - val_loss: 0.2166 - val_accuracy: 0.9216
# Epoch 88/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2426 - accuracy: 0.9118 - val_loss: 0.2155 - val_accuracy: 0.9204
# Epoch 89/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2435 - accuracy: 0.9103 - val_loss: 0.2073 - val_accuracy: 0.9223
# Epoch 90/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2427 - accuracy: 0.9093 - val_loss: 0.2273 - val_accuracy: 0.9150
# Epoch 91/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2432 - accuracy: 0.9105 - val_loss: 0.2077 - val_accuracy: 0.9240
# Epoch 92/120
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.2466 - accuracy: 0.9100
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2465 - accuracy: 0.9100 - val_loss: 0.2110 - val_accuracy: 0.9199
# Epoch 93/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2316 - accuracy: 0.9145 - val_loss: 0.2040 - val_accuracy: 0.9250
# Epoch 94/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2281 - accuracy: 0.9162 - val_loss: 0.2049 - val_accuracy: 0.9237
# Epoch 95/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2235 - accuracy: 0.9179 - val_loss: 0.2214 - val_accuracy: 0.9177
# Epoch 96/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2260 - accuracy: 0.9178 - val_loss: 0.2130 - val_accuracy: 0.9194
# Epoch 97/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2248 - accuracy: 0.9177 - val_loss: 0.2088 - val_accuracy: 0.9216
# Epoch 98/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2232 - accuracy: 0.9178 - val_loss: 0.2097 - val_accuracy: 0.9211
# Epoch 99/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2233 - accuracy: 0.9182 - val_loss: 0.2171 - val_accuracy: 0.9171
# Epoch 100/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2243 - accuracy: 0.9158 - val_loss: 0.2142 - val_accuracy: 0.9184
# Epoch 101/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2228 - accuracy: 0.9180 - val_loss: 0.2144 - val_accuracy: 0.9195
# Epoch 102/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2244 - accuracy: 0.9171 - val_loss: 0.2001 - val_accuracy: 0.9265
# Epoch 103/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2223 - accuracy: 0.9183 - val_loss: 0.2062 - val_accuracy: 0.9242
# Epoch 104/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2235 - accuracy: 0.9168 - val_loss: 0.1978 - val_accuracy: 0.9257
# Epoch 105/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2189 - accuracy: 0.9192 - val_loss: 0.2043 - val_accuracy: 0.9232
# Epoch 106/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2232 - accuracy: 0.9189 - val_loss: 0.1937 - val_accuracy: 0.9267
# Epoch 107/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2219 - accuracy: 0.9172 - val_loss: 0.1987 - val_accuracy: 0.9262
# Epoch 108/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2173 - accuracy: 0.9209 - val_loss: 0.2003 - val_accuracy: 0.9264
# Epoch 109/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2178 - accuracy: 0.9200 - val_loss: 0.1993 - val_accuracy: 0.9265
# Epoch 110/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2245 - accuracy: 0.9171 - val_loss: 0.1995 - val_accuracy: 0.9251
# Epoch 111/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2222 - accuracy: 0.9176 - val_loss: 0.1924 - val_accuracy: 0.9291
# Epoch 112/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2216 - accuracy: 0.9188 - val_loss: 0.2006 - val_accuracy: 0.9265
# Epoch 113/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2217 - accuracy: 0.9179 - val_loss: 0.2037 - val_accuracy: 0.9238
# Epoch 114/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2199 - accuracy: 0.9204 - val_loss: 0.2070 - val_accuracy: 0.9224
# Epoch 115/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2207 - accuracy: 0.9187 - val_loss: 0.1942 - val_accuracy: 0.9268
# Epoch 116/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2197 - accuracy: 0.9193 - val_loss: 0.2097 - val_accuracy: 0.9208
# Epoch 117/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2216 - accuracy: 0.9179 - val_loss: 0.2137 - val_accuracy: 0.9210
# Epoch 118/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2233 - accuracy: 0.9186 - val_loss: 0.1965 - val_accuracy: 0.9271
# Epoch 119/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2189 - accuracy: 0.9188 - val_loss: 0.2050 - val_accuracy: 0.9237
# Epoch 120/120
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.2181 - accuracy: 0.9197 - val_loss: 0.2066 - val_accuracy: 0.9229
# 2020-12-25 18:03:30,121: INFO: finish training [elapsed time: 2461.80 seconds]

# %% [markdown]
# 下面来评估模型并和lenet模型进行对比。

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.1924, Test Accuracy:92.91%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#             train_loss  train_accuracy  test_loss  test_accuracy  \
# custom_cnn    0.148819          0.9446   0.192365         0.9291
# lenet         0.164457          0.9375   0.222985         0.9198
# mlp           0.290463          0.8934   0.344575         0.8808
#
#             weight_number  train_time
# custom_cnn          73162      2461.0
# lenet               61750      2435.0
# mlp                101770      2417.0

# %% [markdown]
# 可以看到custom1模型的效果比lenet有些许提升（经过多次测试，平均好0.1-0.3个百分点）。上面最后一幅图，也能看到custom1模型学习到了不少新的模式。下面来看错误分析。

# %% [markdown]
# ## VGG

# %%
def get_block(x, filters, conv_count, kernel_size=(3, 3), padding='same', use_bn=True, dropout=0, block_name='block'):
    for i in range(conv_count):
        x = layers.Conv2D(filters, kernel_size, padding=padding, name='{}_con{}'.format(block_name, i+1))(x)
        if use_bn: x = layers.BatchNormalization(name='{}_bn{}'.format(block_name, i+1))(x)
        x = layers.ReLU(name='{}_relu{}'.format(block_name, i+1))(x)
    x = layers.MaxPooling2D((2, 2), name='{}_maxpooling1'.format(block_name))(x)
    if dropout>0: x = layers.Dropout(dropout, name='{}_dropout1'.format(block_name))(x)
    return x
    
def get_vgg(helper, name='vgg',
              dense_layer_count=1, 
              dense_layer_units=128,
              conv_filters=64,
              block_count=3,
              use_bn=True,
              dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name)
    print('dropout={}'.format(dropout))
        
    input = layers.Input(shape=helper.data.input_shape)
    x = input    
    for i in range(block_count): 
        x = get_block(x, conv_filters, conv_count=2, use_bn=use_bn, dropout=dropout, 
                      block_name='block{}'.format(i+1))
        conv_filters = conv_filters*2
                    
    x = layers.Flatten()(x)
    for i in range(dense_layer_count):
        x = layers.Dense(128, activation='relu')(x)
        if dropout>0: x = layers.Dropout(dropout)(x)    
    x = layers.Dense(10)(x)
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model


model = get_vgg(helper, dense_layer_count=1, block_count=3, name='vgg8')
model.summary()
# Out:
# dropout=0.3
# learning_rate=0.001
# checkpoint_path=./checkpoints/fashion-mnist-aug/vgg8/checkpoint
# Model: "vgg8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# block1_con1 (Conv2D)         (None, 28, 28, 64)        640
# _________________________________________________________________
# block1_bn1 (BatchNormalizati (None, 28, 28, 64)        256
# _________________________________________________________________
# block1_relu1 (ReLU)          (None, 28, 28, 64)        0
# _________________________________________________________________
# block1_con2 (Conv2D)         (None, 28, 28, 64)        36928
# _________________________________________________________________
# block1_bn2 (BatchNormalizati (None, 28, 28, 64)        256
# _________________________________________________________________
# block1_relu2 (ReLU)          (None, 28, 28, 64)        0
# _________________________________________________________________
# block1_maxpooling1 (MaxPooli (None, 14, 14, 64)        0
# _________________________________________________________________
# block1_dropout1 (Dropout)    (None, 14, 14, 64)        0
# _________________________________________________________________
# block2_con1 (Conv2D)         (None, 14, 14, 128)       73856
# _________________________________________________________________
# block2_bn1 (BatchNormalizati (None, 14, 14, 128)       512
# _________________________________________________________________
# block2_relu1 (ReLU)          (None, 14, 14, 128)       0
# _________________________________________________________________
# block2_con2 (Conv2D)         (None, 14, 14, 128)       147584
# _________________________________________________________________
# block2_bn2 (BatchNormalizati (None, 14, 14, 128)       512
# _________________________________________________________________
# block2_relu2 (ReLU)          (None, 14, 14, 128)       0
# _________________________________________________________________
# block2_maxpooling1 (MaxPooli (None, 7, 7, 128)         0
# _________________________________________________________________
# block2_dropout1 (Dropout)    (None, 7, 7, 128)         0
# _________________________________________________________________
# block3_con1 (Conv2D)         (None, 7, 7, 256)         295168
# _________________________________________________________________
# block3_bn1 (BatchNormalizati (None, 7, 7, 256)         1024
# _________________________________________________________________
# block3_relu1 (ReLU)          (None, 7, 7, 256)         0
# _________________________________________________________________
# block3_con2 (Conv2D)         (None, 7, 7, 256)         590080
# _________________________________________________________________
# block3_bn2 (BatchNormalizati (None, 7, 7, 256)         1024
# _________________________________________________________________
# block3_relu2 (ReLU)          (None, 7, 7, 256)         0
# _________________________________________________________________
# block3_maxpooling1 (MaxPooli (None, 3, 3, 256)         0
# _________________________________________________________________
# block3_dropout1 (Dropout)    (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               295040
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,444,170
# Trainable params: 1,442,378
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
# 训练
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 18:03:46,075: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.6573 - accuracy: 0.7531 - val_loss: 0.9183 - val_accuracy: 0.7437
# Epoch 2/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.4378 - accuracy: 0.8385 - val_loss: 0.3697 - val_accuracy: 0.8644
# Epoch 3/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3778 - accuracy: 0.8629 - val_loss: 0.3984 - val_accuracy: 0.8598
# Epoch 4/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3361 - accuracy: 0.8786 - val_loss: 0.2675 - val_accuracy: 0.9010
# Epoch 5/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.3113 - accuracy: 0.8878 - val_loss: 0.2517 - val_accuracy: 0.9037
# Epoch 6/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2926 - accuracy: 0.8956 - val_loss: 0.2564 - val_accuracy: 0.9063
# Epoch 7/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2726 - accuracy: 0.9035 - val_loss: 0.2265 - val_accuracy: 0.9189
# Epoch 8/120
# 1875/1875 [==============================] - 22s 11ms/step - loss: 0.2575 - accuracy: 0.9084 - val_loss: 0.2186 - val_accuracy: 0.9202
# Epoch 9/120
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.2496 - accuracy: 0.9104 - val_loss: 0.2152 - val_accuracy: 0.9224
# Epoch 10/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2429 - accuracy: 0.9124 - val_loss: 0.2207 - val_accuracy: 0.9183
# Epoch 11/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2340 - accuracy: 0.9155 - val_loss: 0.2074 - val_accuracy: 0.9233
# Epoch 12/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2274 - accuracy: 0.9183 - val_loss: 0.2141 - val_accuracy: 0.9218
# Epoch 13/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2185 - accuracy: 0.9206 - val_loss: 0.1894 - val_accuracy: 0.9313
# Epoch 14/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2114 - accuracy: 0.9237 - val_loss: 0.2145 - val_accuracy: 0.9202
# Epoch 15/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2056 - accuracy: 0.9254 - val_loss: 0.1978 - val_accuracy: 0.9274
# Epoch 16/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2008 - accuracy: 0.9265 - val_loss: 0.1930 - val_accuracy: 0.9307
# Epoch 17/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1992 - accuracy: 0.9280 - val_loss: 0.1904 - val_accuracy: 0.9289
# Epoch 18/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1971 - accuracy: 0.9288 - val_loss: 0.1944 - val_accuracy: 0.9312
# Epoch 19/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1889 - accuracy: 0.9322 - val_loss: 0.1821 - val_accuracy: 0.9341
# Epoch 20/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1857 - accuracy: 0.9326 - val_loss: 0.1871 - val_accuracy: 0.9303
# Epoch 21/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1816 - accuracy: 0.9339 - val_loss: 0.2084 - val_accuracy: 0.9255
# Epoch 22/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1770 - accuracy: 0.9342 - val_loss: 0.1906 - val_accuracy: 0.9327
# Epoch 23/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1754 - accuracy: 0.9365 - val_loss: 0.1804 - val_accuracy: 0.9336
# Epoch 24/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1742 - accuracy: 0.9368 - val_loss: 0.1735 - val_accuracy: 0.9374
# Epoch 25/120
# 1875/1875 [==============================] - 22s 11ms/step - loss: 0.1724 - accuracy: 0.9372 - val_loss: 0.1849 - val_accuracy: 0.9350
# Epoch 26/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1676 - accuracy: 0.9389 - val_loss: 0.1814 - val_accuracy: 0.9385
# Epoch 27/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1672 - accuracy: 0.9394 - val_loss: 0.1839 - val_accuracy: 0.9374
# Epoch 28/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1629 - accuracy: 0.9400 - val_loss: 0.1927 - val_accuracy: 0.9326
# Epoch 29/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1640 - accuracy: 0.9401 - val_loss: 0.1810 - val_accuracy: 0.9367
# Epoch 30/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1582 - accuracy: 0.9424 - val_loss: 0.1814 - val_accuracy: 0.9398
# Epoch 31/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1564 - accuracy: 0.9435 - val_loss: 0.1809 - val_accuracy: 0.9374
# Epoch 32/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1559 - accuracy: 0.9431 - val_loss: 0.1718 - val_accuracy: 0.9382
# Epoch 33/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1519 - accuracy: 0.9455 - val_loss: 0.1877 - val_accuracy: 0.9363
# Epoch 34/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1506 - accuracy: 0.9459 - val_loss: 0.2105 - val_accuracy: 0.9267
# Epoch 35/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1492 - accuracy: 0.9448 - val_loss: 0.1862 - val_accuracy: 0.9382
# Epoch 36/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1506 - accuracy: 0.9448 - val_loss: 0.1889 - val_accuracy: 0.9346
# Epoch 37/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1455 - accuracy: 0.9468 - val_loss: 0.1788 - val_accuracy: 0.9402
# Epoch 38/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1457 - accuracy: 0.9461 - val_loss: 0.1880 - val_accuracy: 0.9345
# Epoch 39/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1421 - accuracy: 0.9484 - val_loss: 0.1778 - val_accuracy: 0.9395
# Epoch 40/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1416 - accuracy: 0.9481 - val_loss: 0.1705 - val_accuracy: 0.9413
# Epoch 41/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1366 - accuracy: 0.9496 - val_loss: 0.1799 - val_accuracy: 0.9372
# Epoch 42/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1379 - accuracy: 0.9494 - val_loss: 0.1733 - val_accuracy: 0.9415
# Epoch 43/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1357 - accuracy: 0.9502 - val_loss: 0.1897 - val_accuracy: 0.9355
# Epoch 44/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1388 - accuracy: 0.9492 - val_loss: 0.1848 - val_accuracy: 0.9375
# Epoch 45/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1345 - accuracy: 0.9503 - val_loss: 0.1847 - val_accuracy: 0.9399
# Epoch 46/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1316 - accuracy: 0.9526 - val_loss: 0.1903 - val_accuracy: 0.9373
# Epoch 47/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1323 - accuracy: 0.9520 - val_loss: 0.1777 - val_accuracy: 0.9416
# Epoch 48/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1328 - accuracy: 0.9516 - val_loss: 0.1809 - val_accuracy: 0.9405
# Epoch 49/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1303 - accuracy: 0.9520 - val_loss: 0.1781 - val_accuracy: 0.9418
# Epoch 50/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1300 - accuracy: 0.9521 - val_loss: 0.1813 - val_accuracy: 0.9421
# Epoch 51/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1272 - accuracy: 0.9536 - val_loss: 0.1795 - val_accuracy: 0.9402
# Epoch 52/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1255 - accuracy: 0.9538 - val_loss: 0.1757 - val_accuracy: 0.9441
# Epoch 53/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1268 - accuracy: 0.9534 - val_loss: 0.1777 - val_accuracy: 0.9425
# Epoch 54/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1224 - accuracy: 0.9548 - val_loss: 0.1816 - val_accuracy: 0.9405
# Epoch 55/120
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1195 - accuracy: 0.9556
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1195 - accuracy: 0.9556 - val_loss: 0.1720 - val_accuracy: 0.9425
# Epoch 56/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1058 - accuracy: 0.9610 - val_loss: 0.1831 - val_accuracy: 0.9440
# Epoch 57/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0994 - accuracy: 0.9643 - val_loss: 0.1746 - val_accuracy: 0.9444
# Epoch 58/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0959 - accuracy: 0.9650 - val_loss: 0.1732 - val_accuracy: 0.9473
# Epoch 59/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0926 - accuracy: 0.9657 - val_loss: 0.1778 - val_accuracy: 0.9466
# Epoch 60/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0919 - accuracy: 0.9661 - val_loss: 0.1808 - val_accuracy: 0.9464
# Epoch 61/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0897 - accuracy: 0.9668 - val_loss: 0.1823 - val_accuracy: 0.9470
# Epoch 62/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0882 - accuracy: 0.9662 - val_loss: 0.1820 - val_accuracy: 0.9475
# Epoch 63/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0876 - accuracy: 0.9683 - val_loss: 0.1754 - val_accuracy: 0.9465
# Epoch 64/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0862 - accuracy: 0.9683 - val_loss: 0.1878 - val_accuracy: 0.9448
# Epoch 65/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0855 - accuracy: 0.9677 - val_loss: 0.1792 - val_accuracy: 0.9467
# Epoch 66/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0851 - accuracy: 0.9689 - val_loss: 0.1899 - val_accuracy: 0.9464
# Epoch 67/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0832 - accuracy: 0.9689 - val_loss: 0.1880 - val_accuracy: 0.9460
# Epoch 68/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0849 - accuracy: 0.9684 - val_loss: 0.1822 - val_accuracy: 0.9473
# Epoch 69/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0812 - accuracy: 0.9701 - val_loss: 0.1825 - val_accuracy: 0.9481
# Epoch 70/120
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9698
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0812 - accuracy: 0.9698 - val_loss: 0.1834 - val_accuracy: 0.9480
# Epoch 71/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0769 - accuracy: 0.9715 - val_loss: 0.1832 - val_accuracy: 0.9490
# Epoch 72/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0742 - accuracy: 0.9726 - val_loss: 0.1831 - val_accuracy: 0.9478
# Epoch 73/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0732 - accuracy: 0.9728 - val_loss: 0.1869 - val_accuracy: 0.9481
# Epoch 74/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0718 - accuracy: 0.9726 - val_loss: 0.1867 - val_accuracy: 0.9485
# Epoch 75/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0723 - accuracy: 0.9725 - val_loss: 0.1910 - val_accuracy: 0.9478
# Epoch 76/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0719 - accuracy: 0.9732 - val_loss: 0.1906 - val_accuracy: 0.9487
# Epoch 77/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0703 - accuracy: 0.9737 - val_loss: 0.1924 - val_accuracy: 0.9491
# Epoch 78/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0708 - accuracy: 0.9737 - val_loss: 0.1908 - val_accuracy: 0.9483
# Epoch 79/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0689 - accuracy: 0.9737 - val_loss: 0.1897 - val_accuracy: 0.9478
# Epoch 80/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0699 - accuracy: 0.9737 - val_loss: 0.1935 - val_accuracy: 0.9484
# Epoch 81/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0698 - accuracy: 0.9745 - val_loss: 0.1953 - val_accuracy: 0.9478
# Epoch 82/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0691 - accuracy: 0.9738 - val_loss: 0.1917 - val_accuracy: 0.9483
# Epoch 83/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0689 - accuracy: 0.9739 - val_loss: 0.1972 - val_accuracy: 0.9483
# Epoch 84/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0699 - accuracy: 0.9743 - val_loss: 0.1945 - val_accuracy: 0.9470
# Epoch 85/120
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9734
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0703 - accuracy: 0.9735 - val_loss: 0.1961 - val_accuracy: 0.9478
# Epoch 86/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0687 - accuracy: 0.9746 - val_loss: 0.1961 - val_accuracy: 0.9484
# Epoch 87/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0658 - accuracy: 0.9754 - val_loss: 0.1956 - val_accuracy: 0.9489
# Epoch 88/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0661 - accuracy: 0.9751 - val_loss: 0.1936 - val_accuracy: 0.9482
# Epoch 89/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0656 - accuracy: 0.9750 - val_loss: 0.1952 - val_accuracy: 0.9487
# Epoch 90/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0661 - accuracy: 0.9756 - val_loss: 0.1950 - val_accuracy: 0.9493
# Epoch 91/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0665 - accuracy: 0.9759 - val_loss: 0.1947 - val_accuracy: 0.9488
# Epoch 92/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0658 - accuracy: 0.9758 - val_loss: 0.1962 - val_accuracy: 0.9484
# Epoch 93/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0658 - accuracy: 0.9755 - val_loss: 0.1953 - val_accuracy: 0.9480
# Epoch 94/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0653 - accuracy: 0.9761 - val_loss: 0.1981 - val_accuracy: 0.9483
# Epoch 95/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0642 - accuracy: 0.9757 - val_loss: 0.1980 - val_accuracy: 0.9489
# Epoch 96/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0628 - accuracy: 0.9766 - val_loss: 0.2014 - val_accuracy: 0.9488
# Epoch 97/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0638 - accuracy: 0.9760 - val_loss: 0.1973 - val_accuracy: 0.9489
# Epoch 98/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0638 - accuracy: 0.9758 - val_loss: 0.1983 - val_accuracy: 0.9482
# Epoch 99/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0641 - accuracy: 0.9759 - val_loss: 0.1984 - val_accuracy: 0.9485
# Epoch 100/120
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.0637 - accuracy: 0.9763
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0637 - accuracy: 0.9763 - val_loss: 0.1989 - val_accuracy: 0.9483
# Epoch 101/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0644 - accuracy: 0.9760 - val_loss: 0.1978 - val_accuracy: 0.9482
# Epoch 102/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0646 - accuracy: 0.9765 - val_loss: 0.1973 - val_accuracy: 0.9488
# Epoch 103/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0648 - accuracy: 0.9754 - val_loss: 0.1962 - val_accuracy: 0.9484
# Epoch 104/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0639 - accuracy: 0.9767 - val_loss: 0.1959 - val_accuracy: 0.9481
# Epoch 105/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0635 - accuracy: 0.9755 - val_loss: 0.1976 - val_accuracy: 0.9488
# Epoch 106/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0628 - accuracy: 0.9771 - val_loss: 0.1974 - val_accuracy: 0.9489
# Epoch 107/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0639 - accuracy: 0.9771 - val_loss: 0.1972 - val_accuracy: 0.9491
# Epoch 108/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0623 - accuracy: 0.9768 - val_loss: 0.1978 - val_accuracy: 0.9488
# Epoch 109/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0627 - accuracy: 0.9768 - val_loss: 0.1983 - val_accuracy: 0.9488
# Epoch 110/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0642 - accuracy: 0.9757 - val_loss: 0.1965 - val_accuracy: 0.9491
# Epoch 111/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0617 - accuracy: 0.9771 - val_loss: 0.1981 - val_accuracy: 0.9491
# Epoch 112/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0626 - accuracy: 0.9768 - val_loss: 0.1966 - val_accuracy: 0.9488
# Epoch 113/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0640 - accuracy: 0.9764 - val_loss: 0.1955 - val_accuracy: 0.9490
# Epoch 114/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0615 - accuracy: 0.9773 - val_loss: 0.1972 - val_accuracy: 0.9489
# Epoch 115/120
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9765
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 3.1622778678900043e-06.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0621 - accuracy: 0.9765 - val_loss: 0.1972 - val_accuracy: 0.9487
# Epoch 116/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0637 - accuracy: 0.9768 - val_loss: 0.1976 - val_accuracy: 0.9484
# Epoch 117/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0621 - accuracy: 0.9772 - val_loss: 0.1966 - val_accuracy: 0.9486
# Epoch 118/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0617 - accuracy: 0.9767 - val_loss: 0.1978 - val_accuracy: 0.9488
# Epoch 119/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0623 - accuracy: 0.9770 - val_loss: 0.1981 - val_accuracy: 0.9484
# Epoch 120/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0628 - accuracy: 0.9772 - val_loss: 0.1981 - val_accuracy: 0.9485
# 2020-12-25 18:59:14,607: INFO: finish training [elapsed time: 3328.53 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.1950, Test Accuracy:94.93%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#             train_loss  train_accuracy  test_loss  test_accuracy  \
# vgg8          0.033524          0.9877   0.194974         0.9493
# custom_cnn    0.148819          0.9446   0.192365         0.9291
# lenet         0.164457          0.9375   0.222985         0.9198
# mlp           0.290463          0.8934   0.344575         0.8808
#
#             weight_number  train_time
# vgg8              1442378      3328.0
# custom_cnn          73162      2461.0
# lenet               61750      2435.0
# mlp                101770      2417.0

# %% [markdown]
# ## Resnet
#
# 参考https://github.com/PacktPublishing/Advanced-Deep-Learning-with-Keras/blob/master/chapter2-deep-networks/resnet-cifar10-2.2.1.py

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = layers.Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
    else:
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10, name='resnet_v1'):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = layers.Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = layers.add([x, y])
            x = layers.Activation('relu')(x)

        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = layers.AveragePooling2D(pool_size=7)(x)
    y = layers.Flatten()(x)
    outputs = layers.Dense(num_classes, kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs, name=name)
    return model

def get_resnet_v1(helper, depth=32, name='resnet_v1'):       
    model = resnet_v1(helper.data.input_shape, depth=depth, name='{}_{}'.format(name, depth))
    helper.compile(model)
    return model

model = get_resnet_v1(helper, depth=20)
model.summary()
# Out:
# learning_rate=0.001
# checkpoint_path=./checkpoints/fashion-mnist-aug/resnet_v1_20/checkpoint
# Model: "resnet_v1_20"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 16)   160         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 28, 28, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 16)   0           activation[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 16)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 16)   64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 16)   0           activation_4[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 32)   4640        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 32)   544         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 32)   0           conv2d_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 14, 14, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 32)   0           activation_8[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 14, 14, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 14, 14, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 32)   0           activation_10[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 64)     18496       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 7, 7, 64)     36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 7, 7, 64)     2112        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, 7, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 64)     0           conv2d_21[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 7, 7, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 7, 7, 64)     256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 64)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 7, 7, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 7, 7, 64)     256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 64)     0           activation_14[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 7, 7, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 64)     256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, 7, 64)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 7, 7, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 64)     256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 64)     0           activation_16[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, 7, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10)           650         flatten_4[0][0]
# ==================================================================================================
# Total params: 274,154
# Trainable params: 272,778
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 18:59:36,136: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.6769 - accuracy: 0.8054 - val_loss: 0.6249 - val_accuracy: 0.8170
# Epoch 2/120
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.4883 - accuracy: 0.8719 - val_loss: 0.5147 - val_accuracy: 0.8660
# Epoch 3/120
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.4358 - accuracy: 0.8865 - val_loss: 0.4821 - val_accuracy: 0.8717
# Epoch 4/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.4061 - accuracy: 0.8938 - val_loss: 0.4549 - val_accuracy: 0.8762
# Epoch 5/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3843 - accuracy: 0.8996 - val_loss: 0.4303 - val_accuracy: 0.8855
# Epoch 6/120
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.3704 - accuracy: 0.9041 - val_loss: 0.4243 - val_accuracy: 0.8847
# Epoch 7/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3579 - accuracy: 0.9073 - val_loss: 0.3709 - val_accuracy: 0.9052
# Epoch 8/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3466 - accuracy: 0.9101 - val_loss: 0.4151 - val_accuracy: 0.8842
# Epoch 9/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3371 - accuracy: 0.9128 - val_loss: 0.3448 - val_accuracy: 0.9111
# Epoch 10/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3299 - accuracy: 0.9154 - val_loss: 0.3397 - val_accuracy: 0.9161
# Epoch 11/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3204 - accuracy: 0.9173 - val_loss: 0.3356 - val_accuracy: 0.9119
# Epoch 12/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3174 - accuracy: 0.9191 - val_loss: 0.3344 - val_accuracy: 0.9128
# Epoch 13/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3127 - accuracy: 0.9189 - val_loss: 0.3931 - val_accuracy: 0.8826
# Epoch 14/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3088 - accuracy: 0.9214 - val_loss: 0.3688 - val_accuracy: 0.9102
# Epoch 15/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3032 - accuracy: 0.9224 - val_loss: 0.3424 - val_accuracy: 0.9062
# Epoch 16/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3001 - accuracy: 0.9226 - val_loss: 0.3068 - val_accuracy: 0.9260
# Epoch 17/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2981 - accuracy: 0.9239 - val_loss: 0.4242 - val_accuracy: 0.8748
# Epoch 18/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2943 - accuracy: 0.9243 - val_loss: 0.3469 - val_accuracy: 0.9061
# Epoch 19/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.2927 - accuracy: 0.9250 - val_loss: 0.3140 - val_accuracy: 0.9185
# Epoch 20/120
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.2880 - accuracy: 0.9266 - val_loss: 0.3284 - val_accuracy: 0.9143
# Epoch 21/120
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.2856 - accuracy: 0.9280 - val_loss: 0.3699 - val_accuracy: 0.8927
# Epoch 22/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2837 - accuracy: 0.9282 - val_loss: 0.4057 - val_accuracy: 0.8915
# Epoch 23/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2801 - accuracy: 0.9288 - val_loss: 0.3066 - val_accuracy: 0.9211
# Epoch 24/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2792 - accuracy: 0.9293 - val_loss: 0.3317 - val_accuracy: 0.9122
# Epoch 25/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2765 - accuracy: 0.9306 - val_loss: 0.2958 - val_accuracy: 0.9231
# Epoch 26/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2768 - accuracy: 0.9302 - val_loss: 0.3071 - val_accuracy: 0.9192
# Epoch 27/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2729 - accuracy: 0.9312 - val_loss: 0.2884 - val_accuracy: 0.9258
# Epoch 28/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2745 - accuracy: 0.9305 - val_loss: 0.3433 - val_accuracy: 0.9075
# Epoch 29/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2696 - accuracy: 0.9319 - val_loss: 0.3653 - val_accuracy: 0.9035
# Epoch 30/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2677 - accuracy: 0.9331 - val_loss: 0.3236 - val_accuracy: 0.9144
# Epoch 31/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2695 - accuracy: 0.9319 - val_loss: 0.3163 - val_accuracy: 0.9190
# Epoch 32/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2667 - accuracy: 0.9320 - val_loss: 0.3252 - val_accuracy: 0.9185
# Epoch 33/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2661 - accuracy: 0.9322 - val_loss: 0.2972 - val_accuracy: 0.9204
# Epoch 34/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2632 - accuracy: 0.9346 - val_loss: 0.3028 - val_accuracy: 0.9239
# Epoch 35/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2610 - accuracy: 0.9357 - val_loss: 0.3458 - val_accuracy: 0.9053
# Epoch 36/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.2609 - accuracy: 0.9339 - val_loss: 0.3003 - val_accuracy: 0.9210
# Epoch 37/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2615 - accuracy: 0.9331 - val_loss: 0.3009 - val_accuracy: 0.9238
# Epoch 38/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2575 - accuracy: 0.9352 - val_loss: 0.3054 - val_accuracy: 0.9211
# Epoch 39/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2585 - accuracy: 0.9354 - val_loss: 0.3945 - val_accuracy: 0.8907
# Epoch 40/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2587 - accuracy: 0.9355 - val_loss: 0.3124 - val_accuracy: 0.9164
# Epoch 41/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2578 - accuracy: 0.9348 - val_loss: 0.3454 - val_accuracy: 0.9016
# Epoch 42/120
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.2551 - accuracy: 0.9373
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2552 - accuracy: 0.9373 - val_loss: 0.3421 - val_accuracy: 0.9110
# Epoch 43/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2169 - accuracy: 0.9493 - val_loss: 0.2573 - val_accuracy: 0.9345
# Epoch 44/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.2046 - accuracy: 0.9521 - val_loss: 0.2578 - val_accuracy: 0.9334
# Epoch 45/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1975 - accuracy: 0.9544 - val_loss: 0.2471 - val_accuracy: 0.9376
# Epoch 46/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1913 - accuracy: 0.9555 - val_loss: 0.2518 - val_accuracy: 0.9355
# Epoch 47/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1866 - accuracy: 0.9565 - val_loss: 0.2514 - val_accuracy: 0.9360
# Epoch 48/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1818 - accuracy: 0.9570 - val_loss: 0.2524 - val_accuracy: 0.9353
# Epoch 49/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1788 - accuracy: 0.9576 - val_loss: 0.2456 - val_accuracy: 0.9371
# Epoch 50/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1768 - accuracy: 0.9582 - val_loss: 0.2370 - val_accuracy: 0.9413
# Epoch 51/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1739 - accuracy: 0.9586 - val_loss: 0.2448 - val_accuracy: 0.9390
# Epoch 52/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1714 - accuracy: 0.9595 - val_loss: 0.2468 - val_accuracy: 0.9383
# Epoch 53/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1698 - accuracy: 0.9587 - val_loss: 0.2451 - val_accuracy: 0.9380
# Epoch 54/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1676 - accuracy: 0.9594 - val_loss: 0.2504 - val_accuracy: 0.9374
# Epoch 55/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1649 - accuracy: 0.9614 - val_loss: 0.2549 - val_accuracy: 0.9357
# Epoch 56/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1677 - accuracy: 0.9601 - val_loss: 0.2413 - val_accuracy: 0.9380
# Epoch 57/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1618 - accuracy: 0.9615 - val_loss: 0.2600 - val_accuracy: 0.9323
# Epoch 58/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1635 - accuracy: 0.9607 - val_loss: 0.2474 - val_accuracy: 0.9367
# Epoch 59/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1618 - accuracy: 0.9603 - val_loss: 0.2514 - val_accuracy: 0.9347
# Epoch 60/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1588 - accuracy: 0.9629 - val_loss: 0.2566 - val_accuracy: 0.9313
# Epoch 61/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1566 - accuracy: 0.9623 - val_loss: 0.2410 - val_accuracy: 0.9377
# Epoch 62/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.1588 - accuracy: 0.9619 - val_loss: 0.2904 - val_accuracy: 0.9249
# Epoch 63/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1561 - accuracy: 0.9632 - val_loss: 0.2429 - val_accuracy: 0.9374
# Epoch 64/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1562 - accuracy: 0.9626 - val_loss: 0.2449 - val_accuracy: 0.9368
# Epoch 65/120
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1552 - accuracy: 0.9629
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1552 - accuracy: 0.9630 - val_loss: 0.2480 - val_accuracy: 0.9378
# Epoch 66/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1350 - accuracy: 0.9708 - val_loss: 0.2350 - val_accuracy: 0.9433
# Epoch 67/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1284 - accuracy: 0.9733 - val_loss: 0.2434 - val_accuracy: 0.9421
# Epoch 68/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1243 - accuracy: 0.9739 - val_loss: 0.2467 - val_accuracy: 0.9416
# Epoch 69/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1216 - accuracy: 0.9744 - val_loss: 0.2536 - val_accuracy: 0.9398
# Epoch 70/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1197 - accuracy: 0.9753 - val_loss: 0.2474 - val_accuracy: 0.9397
# Epoch 71/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1182 - accuracy: 0.9756 - val_loss: 0.2518 - val_accuracy: 0.9399
# Epoch 72/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1170 - accuracy: 0.9762 - val_loss: 0.2520 - val_accuracy: 0.9406
# Epoch 73/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1165 - accuracy: 0.9760 - val_loss: 0.2545 - val_accuracy: 0.9409
# Epoch 74/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1134 - accuracy: 0.9769 - val_loss: 0.2594 - val_accuracy: 0.9386
# Epoch 75/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1110 - accuracy: 0.9780 - val_loss: 0.2569 - val_accuracy: 0.9409
# Epoch 76/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1104 - accuracy: 0.9777 - val_loss: 0.2577 - val_accuracy: 0.9414
# Epoch 77/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1112 - accuracy: 0.9774 - val_loss: 0.2593 - val_accuracy: 0.9392
# Epoch 78/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1092 - accuracy: 0.9777 - val_loss: 0.2605 - val_accuracy: 0.9400
# Epoch 79/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.1084 - accuracy: 0.9780 - val_loss: 0.2591 - val_accuracy: 0.9405
# Epoch 80/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.1066 - accuracy: 0.9787 - val_loss: 0.2573 - val_accuracy: 0.9377
# Epoch 81/120
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1057 - accuracy: 0.9790
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.1057 - accuracy: 0.9790 - val_loss: 0.2570 - val_accuracy: 0.9418
# Epoch 82/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0993 - accuracy: 0.9819 - val_loss: 0.2594 - val_accuracy: 0.9417
# Epoch 83/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0954 - accuracy: 0.9829 - val_loss: 0.2587 - val_accuracy: 0.9419
# Epoch 84/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0947 - accuracy: 0.9834 - val_loss: 0.2604 - val_accuracy: 0.9405
# Epoch 85/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0938 - accuracy: 0.9839 - val_loss: 0.2661 - val_accuracy: 0.9398
# Epoch 86/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0929 - accuracy: 0.9839 - val_loss: 0.2639 - val_accuracy: 0.9415
# Epoch 87/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0925 - accuracy: 0.9842 - val_loss: 0.2701 - val_accuracy: 0.9406
# Epoch 88/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0917 - accuracy: 0.9840 - val_loss: 0.2659 - val_accuracy: 0.9410
# Epoch 89/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.0915 - accuracy: 0.9844 - val_loss: 0.2692 - val_accuracy: 0.9403
# Epoch 90/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0909 - accuracy: 0.9839 - val_loss: 0.2671 - val_accuracy: 0.9418
# Epoch 91/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0894 - accuracy: 0.9849 - val_loss: 0.2706 - val_accuracy: 0.9417
# Epoch 92/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0909 - accuracy: 0.9846 - val_loss: 0.2712 - val_accuracy: 0.9413
# Epoch 93/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0901 - accuracy: 0.9840 - val_loss: 0.2696 - val_accuracy: 0.9410
# Epoch 94/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0880 - accuracy: 0.9850 - val_loss: 0.2706 - val_accuracy: 0.9403
# Epoch 95/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0886 - accuracy: 0.9843 - val_loss: 0.2733 - val_accuracy: 0.9412
# Epoch 96/120
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9855
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0876 - accuracy: 0.9855 - val_loss: 0.2723 - val_accuracy: 0.9418
# Epoch 97/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.0854 - accuracy: 0.9859 - val_loss: 0.2737 - val_accuracy: 0.9420
# Epoch 98/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.0848 - accuracy: 0.9861 - val_loss: 0.2738 - val_accuracy: 0.9412
# Epoch 99/120
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0845 - accuracy: 0.9862 - val_loss: 0.2744 - val_accuracy: 0.9415
# Epoch 100/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.0846 - accuracy: 0.9863 - val_loss: 0.2737 - val_accuracy: 0.9413
# Epoch 101/120
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.0851 - accuracy: 0.9864 - val_loss: 0.2754 - val_accuracy: 0.9415
# Epoch 102/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0822 - accuracy: 0.9869 - val_loss: 0.2767 - val_accuracy: 0.9409
# Epoch 103/120
# 1875/1875 [==============================] - 41s 22ms/step - loss: 0.0830 - accuracy: 0.9868 - val_loss: 0.2782 - val_accuracy: 0.9407
# Epoch 104/120
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0827 - accuracy: 0.9869 - val_loss: 0.2786 - val_accuracy: 0.9405
# Epoch 105/120
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0829 - accuracy: 0.9868 - val_loss: 0.2782 - val_accuracy: 0.9428
# Epoch 106/120
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0825 - accuracy: 0.9870 - val_loss: 0.2790 - val_accuracy: 0.9416
# Epoch 00106: early stopping
# 2020-12-25 20:22:45,566: INFO: finish training [elapsed time: 4989.43 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.2350, Test Accuracy:94.33%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#               train_loss  train_accuracy  test_loss  test_accuracy  \
# vgg8            0.033524          0.9877   0.194974         0.9493
# resnet_v1_20    0.118365          0.9771   0.235033         0.9433
# custom_cnn      0.148819          0.9446   0.192365         0.9291
# lenet           0.164457          0.9375   0.222985         0.9198
# mlp             0.290463          0.8934   0.344575         0.8808
#
#               weight_number  train_time
# vgg8                1442378      3328.0
# resnet_v1_20         272778      4989.0
# custom_cnn            73162      2461.0
# lenet                 61750      2435.0
# mlp                  101770      2417.0

# %% [markdown]
# ## 总结
