# %% [markdown]
# <img align=center src="https://rhyme.com/assets/img/logo-dark.png"></img>
# <h2 align=center> Named Entity Recognition (NER) using LSTMs with Keras</h2>

# %% [markdown]
# ### Task 1: Project Overview and Import Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.5.0
# GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %% [markdown]
# ### Task 2: Load and Explore the NER Dataset

# %% [markdown]
# *Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv("ner_dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %% [markdown]
# ### Task 3: Retrieve Sentences and Corresponsing Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ### Task 4: Define Mappings between Sentences and Tags

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'rewrite': 1,
#  'Philippine': 2,
#  'launches': 3,
#  'forgave': 4,
#  'Exact': 5,
#  'Congress': 6,
#  'stoves': 7,
#  'Fawaz': 8,
#  'erosion': 9,
#  'Henghameh': 10,
#  'succumbed': 11,
#  'cleaned': 12,
#  'Tuareg': 13,
#  'wrongfully': 14,
#  'impeachment': 15,
#  'Shidiac': 16,
#  'Rules': 17,
#  'chronically': 18,
#  'Tomar': 19,
#  'Non-Aligned': 20,
#  'Temptations': 21,
#  'VOA': 22,
#  'pickle-fork': 23,
#  'technical': 24,
#  'ashes': 25,
#  'social-conservative': 26,
#  'Railroad': 27,
#  'Hasyim': 28,
#  'US-India': 29,
#  'eating': 30,
#  '1004': 31,
#  'stress': 32,
#  'thwarted': 33,
#  'Kasparov': 34,
#  'nook': 35,
#  'scolded': 36,
#  'exemplifies': 37,
#  'symptom': 38,
#  'snatch': 39,
#  'anti-pollution': 40,
#  'gravely': 41,
#  'Baltim': 42,
#  'items': 43,
#  'wished': 44,
#  'Corrientes': 45,
#  'Annexation': 46,
#  'smallest': 47,
#  'unnamed': 48,
#  'trees': 49,
#  'collecting': 50,
#  'Bajur': 51,
#  'Artemisian-based': 52,
#  '70.7': 53,
#  'bamboo': 54,
#  'Hormuz': 55,
#  'threatening': 56,
#  'Ramzi': 57,
#  'punished': 58,
#  'fathers': 59,
#  'Your': 60,
#  'energetic': 61,
#  'Schlender': 62,
#  'Republic-Central': 63,
#  'prematurely': 64,
#  'Cuba-Venezuela': 65,
#  'Minutes': 66,
#  '26,000-member': 67,
#  'mid-afternoon': 68,
#  'Dulmatin': 69,
#  'Company': 70,
#  'MOHAMMED': 71,
#  'Fisherman': 72,
#  'JPMorgan': 73,
#  'setback': 74,
#  'steroid': 75,
#  'dominates': 76,
#  'middle-income': 77,
#  'Kiefer': 78,
#  'Kaibyshev': 79,
#  'ATP': 80,
#  'grassroots': 81,
#  'subjecting': 82,
#  'Wilhelm': 83,
#  'remnants': 84,
#  'births': 85,
#  'plagues': 86,
#  'swapped': 87,
#  'Graner': 88,
#  'divine': 89,
#  'pillars': 90,
#  'Scimitar': 91,
#  'unsold': 92,
#  'Fahd': 93,
#  'Development': 94,
#  'Tehran': 95,
#  'Redmond': 96,
#  'anti-narcotics': 97,
#  'symbolically': 98,
#  'terribly': 99,
#  'collectivization': 100,
#  'acquaint': 101,
#  'Zenawi': 102,
#  'now-retired': 103,
#  'Nardiello': 104,
#  'Persians': 105,
#  'Truth': 106,
#  'Arabs': 107,
#  'terrorists': 108,
#  'Torsello': 109,
#  'purification': 110,
#  'half-century': 111,
#  'blue-chip': 112,
#  'sank': 113,
#  'once': 114,
#  'Qaisar': 115,
#  'Modell': 116,
#  'banjo': 117,
#  'astronaut': 118,
#  'recognize': 119,
#  'pierced': 120,
#  'Lands': 121,
#  '1-to-1': 122,
#  'hair': 123,
#  'backyard': 124,
#  'aspire': 125,
#  'McGrady': 126,
#  'second-straight': 127,
#  'below': 128,
#  '35-year-old': 129,
#  'deterrent': 130,
#  'Tupac': 131,
#  'Fayyaz': 132,
#  'boatmen': 133,
#  'road-building': 134,
#  'non-Jewish': 135,
#  'radiotherapy': 136,
#  'pedophiles': 137,
#  'abundance': 138,
#  'Commons': 139,
#  'Lambert': 140,
#  'Pulp': 141,
#  'dawn': 142,
#  'Lahoud': 143,
#  'discusses': 144,
#  'Tripoli': 145,
#  'Pu': 146,
#  'grenades': 147,
#  'Bagapsh': 148,
#  'Cedatos-Gallup': 149,
#  'Blears': 150,
#  'Waldron': 151,
#  'accept': 152,
#  'subsidizes': 153,
#  'e-mail': 154,
#  'McCartney': 155,
#  'Chaco': 156,
#  'half-staff': 157,
#  'infiltrations': 158,
#  'Herat': 159,
#  '35.2': 160,
#  'swearing-in': 161,
#  'Mudasir': 162,
#  'Cambridge': 163,
#  'embassies': 164,
#  'company': 165,
#  'Hanoun': 166,
#  'waterways': 167,
#  'Luxembourg-based': 168,
#  'Medecins': 169,
#  'machine-gun': 170,
#  'hypertension': 171,
#  'opponent': 172,
#  'Cote': 173,
#  'hide-outs': 174,
#  'clarifies': 175,
#  'long-awaited': 176,
#  'organizational': 177,
#  'job': 178,
#  'fares': 179,
#  'cheerful': 180,
#  'Shaikh': 181,
#  'Milenkovic': 182,
#  'Trans-Saharan': 183,
#  'conflicts': 184,
#  'view': 185,
#  'allows': 186,
#  'guerrillas': 187,
#  'baboons': 188,
#  '216': 189,
#  'headline': 190,
#  'warmest': 191,
#  'promoted': 192,
#  'school': 193,
#  'Guenter': 194,
#  'Ljubicic': 195,
#  'streaming': 196,
#  'acetylene': 197,
#  '21,000': 198,
#  'bush': 199,
#  'Scheffer': 200,
#  '25': 201,
#  'Anthony': 202,
#  'elite': 203,
#  'Kospi': 204,
#  'atomic': 205,
#  'possess': 206,
#  'Dir': 207,
#  'Rosemond': 208,
#  'boisterous': 209,
#  'hostess-producer': 210,
#  'data': 211,
#  'Memene': 212,
#  'economics': 213,
#  '543-member': 214,
#  'Pulwama': 215,
#  'Carbon': 216,
#  'recanted': 217,
#  'Awe': 218,
#  'misdeeds': 219,
#  'PPP': 220,
#  'enrich': 221,
#  'Mutahida': 222,
#  'Bahamian': 223,
#  'Jong-Nam': 224,
#  'elect': 225,
#  'Powerful': 226,
#  'Americans': 227,
#  'Alassane': 228,
#  'Grimaldi': 229,
#  '450': 230,
#  'Soren': 231,
#  'Kameshli': 232,
#  'Murcia': 233,
#  'Grosjean': 234,
#  'commitment': 235,
#  'Acting': 236,
#  'Shlomo': 237,
#  'noses': 238,
#  'flowed': 239,
#  'bolt': 240,
#  'tall': 241,
#  'al-Hasan': 242,
#  'marines': 243,
#  'one-sixth': 244,
#  'Jalani': 245,
#  'avenue': 246,
#  'SUU': 247,
#  'Vasylyev': 248,
#  'juvenile': 249,
#  'two-week-long': 250,
#  'curbed': 251,
#  'lessened': 252,
#  'hockey': 253,
#  'credentials': 254,
#  'Repsol': 255,
#  'defeat': 256,
#  'recognized': 257,
#  'striving': 258,
#  'Kochi': 259,
#  'Abdouramane': 260,
#  'Valero': 261,
#  'jar': 262,
#  'Israeli-Hizballah': 263,
#  'Huon': 264,
#  'Oceans': 265,
#  'anti-smuggling': 266,
#  'Monte': 267,
#  '481': 268,
#  'virulent': 269,
#  'hub': 270,
#  'dealing': 271,
#  'Ulf': 272,
#  'confront': 273,
#  'auditing': 274,
#  'legacy': 275,
#  'Puma': 276,
#  'termed': 277,
#  'cost-cutting': 278,
#  'samples': 279,
#  'degrees': 280,
#  '35-member': 281,
#  'overpayments': 282,
#  'Thirty-two': 283,
#  'KYI': 284,
#  'performances': 285,
#  'bullying': 286,
#  'told': 287,
#  'standard-of-living': 288,
#  'Ethiopia': 289,
#  'capitalize': 290,
#  'Balakot': 291,
#  'stretching': 292,
#  'despoiling': 293,
#  'disappearances': 294,
#  'Talansky': 295,
#  'Wheeler': 296,
#  'formation': 297,
#  'going': 298,
#  '60': 299,
#  'innovation': 300,
#  'anti-military': 301,
#  'Separatists': 302,
#  'exception': 303,
#  '1916': 304,
#  'Ereli': 305,
#  'audio': 306,
#  'Fatah-led': 307,
#  'Intel': 308,
#  'Bangla': 309,
#  '10-nation': 310,
#  'booking': 311,
#  'Abderrahaman': 312,
#  'Molucca': 313,
#  'TRUJILLO': 314,
#  'fluctuated': 315,
#  'established': 316,
#  'stall': 317,
#  'Football-related': 318,
#  'HUNTSMAN': 319,
#  'furious': 320,
#  'voiced': 321,
#  'consulting': 322,
#  'chilling': 323,
#  'approximates': 324,
#  'Downer': 325,
#  'Israeli-built': 326,
#  '63-year-old': 327,
#  'familiar': 328,
#  'saturated': 329,
#  'respecting': 330,
#  'widower': 331,
#  'Sreten': 332,
#  '1891': 333,
#  '373': 334,
#  'Rico': 335,
#  'Morocco': 336,
#  'sterilized': 337,
#  'voting': 338,
#  'China-USA': 339,
#  'tested': 340,
#  'significantly': 341,
#  'Telerate': 342,
#  'Pak': 343,
#  'Vavi': 344,
#  'pro-al-Sadr': 345,
#  'abandoning': 346,
#  'quake': 347,
#  'snapshot': 348,
#  'H5N1': 349,
#  'believe': 350,
#  'outsiders': 351,
#  '4,00,000': 352,
#  'Catandunes': 353,
#  'From': 354,
#  'confronting': 355,
#  'electorate': 356,
#  'slept': 357,
#  'Innovative': 358,
#  'bias': 359,
#  'anesthetic': 360,
#  'Kani': 361,
#  'babies': 362,
#  'Summits': 363,
#  'creativity': 364,
#  'passive': 365,
#  'semi': 366,
#  'counsel': 367,
#  'Reich': 368,
#  'Afghan-Pakistani': 369,
#  'Panamanian-flagged': 370,
#  'Tornadoes': 371,
#  'gamble': 372,
#  'readying': 373,
#  'anti-missile': 374,
#  'Speaker': 375,
#  'tenure': 376,
#  'Parvanov': 377,
#  'escapees': 378,
#  'Guyana': 379,
#  'voltage': 380,
#  'Cowboys': 381,
#  'radar': 382,
#  'MQM': 383,
#  'Crum': 384,
#  'Asia-Europe': 385,
#  'Lavish': 386,
#  'Krasnodar': 387,
#  'Mitsubishi': 388,
#  'tickets': 389,
#  'UBT': 390,
#  'prosecuting': 391,
#  'mediate': 392,
#  'publish': 393,
#  'Eparses': 394,
#  'planned': 395,
#  'could': 396,
#  'By-election': 397,
#  'Shui-bian': 398,
#  'Lecturer': 399,
#  'requirement': 400,
#  'Provisions': 401,
#  'Instance': 402,
#  'Awareness': 403,
#  'Pol-e-Charkhi': 404,
#  'nonrefundable': 405,
#  'acutely': 406,
#  'pluralism': 407,
#  'non-EU': 408,
#  'Purnomo': 409,
#  'PetroChina': 410,
#  'removes': 411,
#  'overhauling': 412,
#  'discussion': 413,
#  'Anh': 414,
#  'anticorruption': 415,
#  'privatizations': 416,
#  'follower': 417,
#  'ambition': 418,
#  'V': 419,
#  'income': 420,
#  'clamping': 421,
#  '19': 422,
#  'midestern': 423,
#  '23rd': 424,
#  'Kurram': 425,
#  'Connie': 426,
#  'transcripts': 427,
#  'jobs': 428,
#  'Andrus': 429,
#  'dread': 430,
#  'appeals': 431,
#  'Alliot-Marie': 432,
#  'beneficial': 433,
#  'drugmaker': 434,
#  'requital': 435,
#  'Peacocks': 436,
#  'unimaginable': 437,
#  'Seventy-five': 438,
#  'Badghis': 439,
#  'inhibits': 440,
#  'Jordanian-born': 441,
#  '50-year-old': 442,
#  'PRGF': 443,
#  'Krabok': 444,
#  'losers': 445,
#  'Rois': 446,
#  'Iraq-based': 447,
#  'barley': 448,
#  'Nahal': 449,
#  'Dong-Young': 450,
#  'duration': 451,
#  'backtrack': 452,
#  'mixed-race': 453,
#  'statistically': 454,
#  'Peipah': 455,
#  'Triumf': 456,
#  'Jordanian': 457,
#  'harbors': 458,
#  'Kandy': 459,
#  'talker': 460,
#  'cautious': 461,
#  'Sint': 462,
#  'OPEC': 463,
#  'navies': 464,
#  'Amritsar': 465,
#  'British-born': 466,
#  'Symptoms': 467,
#  'Dzhennet': 468,
#  'Top': 469,
#  'redoing': 470,
#  'Port': 471,
#  '2,100': 472,
#  'Protesters': 473,
#  'Cameroonian': 474,
#  'transaction': 475,
#  'represents': 476,
#  'may': 477,
#  'As-Sahab': 478,
#  '73.85': 479,
#  'catalysts': 480,
#  'retirements': 481,
#  'Tariceanu': 482,
#  'Armenian': 483,
#  '1772': 484,
#  'purged': 485,
#  'Dunleavy': 486,
#  'dioceses': 487,
#  'indissoluble': 488,
#  'UN-brokered': 489,
#  'servicing': 490,
#  'Cracks': 491,
#  'mistrust': 492,
#  'cross-ethnic': 493,
#  'canyons': 494,
#  '23-year-old': 495,
#  'Abakar': 496,
#  'Indian-': 497,
#  'Ophelia': 498,
#  'Chenembiri': 499,
#  'PRODUCTS': 500,
#  'Arbaeen': 501,
#  'limped': 502,
#  'prevailed': 503,
#  'Amman': 504,
#  'rowed': 505,
#  'locating': 506,
#  'Ghormley': 507,
#  'splintered': 508,
#  'Bologna': 509,
#  'Beck': 510,
#  'Rhodesia': 511,
#  'tissue': 512,
#  'suppressed': 513,
#  'Bahrainian': 514,
#  'Marghzar': 515,
#  'decelerated': 516,
#  'wrinkled': 517,
#  'reassessed': 518,
#  'wide-scale': 519,
#  'Concern': 520,
#  'eliminates': 521,
#  'pro-Aristide': 522,
#  'Joan': 523,
#  'rekindled': 524,
#  '1600': 525,
#  'bite': 526,
#  'mingling': 527,
#  'perch': 528,
#  'Pakistani-based': 529,
#  'Directorate': 530,
#  'Economics': 531,
#  'Vukovar': 532,
#  'Cheadle': 533,
#  'drug-resistant': 534,
#  'Normalization': 535,
#  'Oresund': 536,
#  'Zimmerman': 537,
#  'KENYATTA': 538,
#  'appliances': 539,
#  'Allahabad': 540,
#  'Khamas': 541,
#  'grudges': 542,
#  'Curacao': 543,
#  'Whispers': 544,
#  'Jufeng': 545,
#  'front-runners': 546,
#  'AKAEV': 547,
#  'KFM': 548,
#  'stuff': 549,
#  'kilometers': 550,
#  'cities': 551,
#  'turns': 552,
#  'inked': 553,
#  'regimes': 554,
#  'Index': 555,
#  '19.7': 556,
#  'politically': 557,
#  'involuntary': 558,
#  'Abdolvahed': 559,
#  'Chiapolino': 560,
#  'biometric': 561,
#  'parting': 562,
#  'treetops': 563,
#  'reefs': 564,
#  'Woo-Suk': 565,
#  'Influential': 566,
#  'Indicators': 567,
#  'fragile': 568,
#  'Twenty': 569,
#  'severely': 570,
#  'coefficient': 571,
#  'decision-making': 572,
#  'frequent': 573,
#  'great-uncle': 574,
#  'levees': 575,
#  'tellers': 576,
#  'Responsibility': 577,
#  'Naqib': 578,
#  'Dhakla': 579,
#  '76.7': 580,
#  'Jaap': 581,
#  'Fat': 582,
#  'Supreme': 583,
#  'Patch': 584,
#  'tributes': 585,
#  'thermal': 586,
#  'Wit': 587,
#  'McCann': 588,
#  'plants': 589,
#  'annual': 590,
#  'stakes': 591,
#  'Obamas': 592,
#  'Thanou': 593,
#  'commenced': 594,
#  'inexpensive': 595,
#  'telephoned': 596,
#  'U.N.-proposed': 597,
#  'five-tenths': 598,
#  'controversial': 599,
#  'S&P': 600,
#  'Alexeyenko': 601,
#  "I'd": 602,
#  '0.82': 603,
#  'Tijuana': 604,
#  'forward': 605,
#  '1870': 606,
#  'varieties': 607,
#  'McCullogh': 608,
#  'rice-growing': 609,
#  'Initial': 610,
#  'acknowledging': 611,
#  'Private': 612,
#  'resource-poor': 613,
#  'Foxy': 614,
#  'rand': 615,
#  'Istanbul': 616,
#  'transformation': 617,
#  'Shinzo': 618,
#  'Brother': 619,
#  'invalid': 620,
#  'unconscious': 621,
#  'Hu': 622,
#  'Recognizing': 623,
#  'Abed': 624,
#  'spectacles': 625,
#  'vaccinations': 626,
#  'Game': 627,
#  'twisted': 628,
#  'armada': 629,
#  'Subaru': 630,
#  'intensifying': 631,
#  'Buffeted': 632,
#  'Mulongoti': 633,
#  'Cate': 634,
#  'Gogh': 635,
#  'Mazlum-Der': 636,
#  'Testimony': 637,
#  'Convention': 638,
#  'Emroz': 639,
#  'Kanyabayonga': 640,
#  'indicators': 641,
#  'Office': 642,
#  'Nest': 643,
#  'films': 644,
#  'indirect': 645,
#  'Metin': 646,
#  '1697': 647,
#  'GNASSINGBE': 648,
#  'construct': 649,
#  'deteriorated': 650,
#  'DAY': 651,
#  'television': 652,
#  'conversations': 653,
#  'At': 654,
#  'deficient': 655,
#  'Ulus': 656,
#  'plowlands': 657,
#  'reestablished': 658,
#  'Rowan': 659,
#  'Sooden': 660,
#  'recreation': 661,
#  'remodeled': 662,
#  'exclusively': 663,
#  'Euro-Atlantic': 664,
#  're-export': 665,
#  'logs': 666,
#  'MPP': 667,
#  'UN-sponsored': 668,
#  'game-bag': 669,
#  'HARIRI': 670,
#  'Zhulyany': 671,
#  'fearing': 672,
#  'insurgency-hit': 673,
#  'Greenville': 674,
#  'LaBeouf': 675,
#  'ratio': 676,
#  'dreaded': 677,
#  'meteorologists': 678,
#  'Grace': 679,
#  'revolver': 680,
#  'encountering': 681,
#  'exiled': 682,
#  'Witness': 683,
#  'Saada': 684,
#  'Serie': 685,
#  'awaiting': 686,
#  'Consulate': 687,
#  'snowstorm': 688,
#  'Textiles': 689,
#  'Wlodzimierz': 690,
#  'endowed': 691,
#  'tortured': 692,
#  'Bangalore': 693,
#  'crazy': 694,
#  'Rwandan': 695,
#  'Inspector': 696,
#  'Conn.': 697,
#  'clarification': 698,
#  'robberies': 699,
#  'achieved': 700,
#  'Advertisers': 701,
#  'collisions': 702,
#  'airports': 703,
#  'Colt': 704,
#  'Farris': 705,
#  'Liban': 706,
#  'Bahia': 707,
#  'Julio': 708,
#  'Prithvi': 709,
#  'span': 710,
#  'al-Watan': 711,
#  'airstrikes': 712,
#  'Banaue': 713,
#  'noncolonial': 714,
#  'disobey': 715,
#  'Qassem': 716,
#  'Mauritian': 717,
#  'well-placed': 718,
#  'condemn': 719,
#  '#NAME?': 720,
#  'volume': 721,
#  'categorically': 722,
#  'rain-swollen': 723,
#  'indecent': 724,
#  'debt-ridden': 725,
#  'Comerio': 726,
#  'inundate': 727,
#  '1895': 728,
#  'Taiwanese': 729,
#  'The': 730,
#  'Sicily': 731,
#  'Victims': 732,
#  'Cerberus': 733,
#  'Raising': 734,
#  'GAME': 735,
#  'devaluation': 736,
#  'duties': 737,
#  'Complaints': 738,
#  'Hauts-de-Seine': 739,
#  'largely-Muslim': 740,
#  'Subsequently': 741,
#  'wayward': 742,
#  'resolutions': 743,
#  'Native': 744,
#  'counting': 745,
#  'faint': 746,
#  'compared': 747,
#  'succumb': 748,
#  'advisers': 749,
#  'contagious': 750,
#  'jihadist': 751,
#  'bodily': 752,
#  'candlelit': 753,
#  'accepting': 754,
#  'exploding': 755,
#  'Lambeth': 756,
#  'AB': 757,
#  'quicken': 758,
#  'Ilam': 759,
#  'Stephen': 760,
#  'self-sustainable': 761,
#  'recipients': 762,
#  'disclaimer': 763,
#  'Natwar': 764,
#  'Berra': 765,
#  'investment': 766,
#  '13': 767,
#  '3,65,000': 768,
#  'treacherous': 769,
#  'spinach': 770,
#  'deposed': 771,
#  'policeman': 772,
#  'Return': 773,
#  'relaying': 774,
#  'alleging': 775,
#  'firsts': 776,
#  'truth': 777,
#  'instituted': 778,
#  'Popularly-elected': 779,
#  'murdered': 780,
#  'Volta': 781,
#  'uptick': 782,
#  'Pilots': 783,
#  'phase-out': 784,
#  'Shek': 785,
#  'filibuster': 786,
#  'peeping': 787,
#  'E.U.': 788,
#  'exercise': 789,
#  'ultra-nationalist': 790,
#  'infomation': 791,
#  'bust': 792,
#  'Ant': 793,
#  'designs': 794,
#  '1845': 795,
#  'birch-tree': 796,
#  'vagaries': 797,
#  'ZANU-PF': 798,
#  'Neiva': 799,
#  'detonating': 800,
#  '2050': 801,
#  'Tampa': 802,
#  'centers': 803,
#  '6.44': 804,
#  'Ange-Felix': 805,
#  'refugees': 806,
#  'ribbon': 807,
#  'exhaustion': 808,
#  'reporters': 809,
#  'Geo': 810,
#  'Purple': 811,
#  'imagine': 812,
#  'narrow': 813,
#  'Yong': 814,
#  'Logar': 815,
#  'independents': 816,
#  'Pro-business': 817,
#  'al-Tahreer': 818,
#  'Mindaoudou': 819,
#  'skyrocketed': 820,
#  'Mahara': 821,
#  'daunting': 822,
#  'Tarmiyah': 823,
#  'Thierse': 824,
#  'turbo': 825,
#  'orphaned': 826,
#  'Hagino': 827,
#  'upgrading': 828,
#  'Jong-il': 829,
#  'designer': 830,
#  'lower-than-normal': 831,
#  'jazz': 832,
#  '7.7': 833,
#  'Lawyers': 834,
#  'TIFA': 835,
#  'day': 836,
#  'Torshin': 837,
#  'nano-technology': 838,
#  'Emperor': 839,
#  'Kanyarukiga': 840,
#  'Mashonaland': 841,
#  'Legg': 842,
#  'foul': 843,
#  'asteroid': 844,
#  'movements': 845,
#  'Dniester': 846,
#  'Fish': 847,
#  'stable': 848,
#  'entice': 849,
#  'hot': 850,
#  'compliant': 851,
#  'Mayor': 852,
#  'Ashland': 853,
#  '387.8': 854,
#  'rob': 855,
#  'AFP': 856,
#  '10-person': 857,
#  'medley': 858,
#  'passport-forging': 859,
#  'grenade': 860,
#  'Michuki': 861,
#  'McCormack': 862,
#  'breaks': 863,
#  'Hayat': 864,
#  'like': 865,
#  '336': 866,
#  '26,000': 867,
#  'Don': 868,
#  'atheist': 869,
#  'rustic': 870,
#  'costumed': 871,
#  'theatergoers': 872,
#  'Guere': 873,
#  'FDIC': 874,
#  'filing': 875,
#  'center-right': 876,
#  'Beattie': 877,
#  'testing': 878,
#  'Chinotimba': 879,
#  'additives': 880,
#  'Theological': 881,
#  'Ould': 882,
#  'KADAR': 883,
#  'Blood': 884,
#  'messes': 885,
#  'Abductees': 886,
#  'Sunna': 887,
#  'Peaceful': 888,
#  'hydrocarbon': 889,
#  'hideout': 890,
#  'PSLAV': 891,
#  'Majdal': 892,
#  'Self-Defense': 893,
#  'pre-natal': 894,
#  'crew': 895,
#  'KIBAKI': 896,
#  '1331': 897,
#  'corn': 898,
#  'unsuccessful': 899,
#  'Mohmmed': 900,
#  'Collingwood': 901,
#  'igniting': 902,
#  'ecology': 903,
#  'freeskate': 904,
#  'employers': 905,
#  'lights': 906,
#  'remarkable': 907,
#  'elves': 908,
#  'cotton': 909,
#  'ground': 910,
#  'Razumkov': 911,
#  'Scilingo': 912,
#  'antagonizes': 913,
#  'essentially': 914,
#  'Guatemala': 915,
#  'Paralympic': 916,
#  'blessing': 917,
#  'Non-Violent': 918,
#  'Field': 919,
#  'commodity-based': 920,
#  'Aquarium': 921,
#  'Mahmud': 922,
#  'Equipment-2': 923,
#  'spacecraft': 924,
#  'shofar': 925,
#  'acquittal': 926,
#  'Anatolianews': 927,
#  'Belaroussi': 928,
#  'Olmert': 929,
#  'unaffiliated': 930,
#  'Henri': 931,
#  '361': 932,
#  'Shawkat': 933,
#  'WOLF': 934,
#  'slowly-implemented': 935,
#  'Roll': 936,
#  'Frontier': 937,
#  'attention': 938,
#  'Vieira': 939,
#  'earthquake-triggered': 940,
#  'nationalities': 941,
#  'multi-party': 942,
#  'instigating': 943,
#  '1865': 944,
#  'Jan.': 945,
#  'Manger': 946,
#  'al-Adamiya': 947,
#  'Chodo': 948,
#  'Venus': 949,
#  'undemocratic': 950,
#  'responsive': 951,
#  'nickel': 952,
#  'capability': 953,
#  'Shuai': 954,
#  'caps': 955,
#  'Prefecture': 956,
#  'rap': 957,
#  'husbandry': 958,
#  'Glacier': 959,
#  'aiming': 960,
#  'Dmitrivev': 961,
#  'snuff': 962,
#  'Marjah': 963,
#  'African-based': 964,
#  '1810': 965,
#  'hill': 966,
#  'aviation': 967,
#  'investors': 968,
#  'mis-2009': 969,
#  'shares': 970,
#  'embrace': 971,
#  'Orakzai': 972,
#  'BOSCH': 973,
#  'Tan': 974,
#  'Murdered': 975,
#  'Open': 976,
#  'tsunami-producing': 977,
#  'Rouge': 978,
#  'Wen': 979,
#  'Harrison': 980,
#  'abolishes': 981,
#  'laments': 982,
#  'cinema': 983,
#  'Saqiz': 984,
#  'molesting': 985,
#  'insiders': 986,
#  'Hailu': 987,
#  'Soderling': 988,
#  'Marinin': 989,
#  'Maldives': 990,
#  'filthy': 991,
#  'widow': 992,
#  'Panther': 993,
#  '1939': 994,
#  'sophistication': 995,
#  'Celso': 996,
#  'Marie': 997,
#  'drawings': 998,
#  'Ngabo': 999,
#  'fingerprinted': 1000,
#  ...}

# %% [markdown]
# ### Task 5: Padding Input Sentences and Creating Train/Test Splits

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Task 6: Build and Compile a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 50, 50)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed (TimeDistri (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Task 7: Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)

callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test,y_test),
    batch_size=32, 
    epochs=5,
    callbacks=callbacks,
    verbose=1
)
# Out:
# accuracy
# 	training         	 (min:    0.959, max:    0.991, cur:    0.991)
# 	validation       	 (min:    0.981, max:    0.986, cur:    0.986)
# Loss
# 	training         	 (min:    0.026, max:    0.179, cur:    0.026)
# 	validation       	 (min:    0.048, max:    0.067, cur:    0.049)
#
# Epoch 00005: val_loss did not improve from 0.04815
# CPU times: user 1h 14min 56s, sys: 12min 58s, total: 1h 27min 55s
# Wall time: 42min 44s

# %% [markdown]
# ### Task 8: Evaluate Named Entity Recognition Model

# %%
model.evaluate(x_test, y_test)

# best result
# epochs=3 [0.047939226031303406, 0.9856776595115662]
# epochs=5 [0.04905456677079201, 0.9860342144966125]
# Out:
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0491 - accuracy: 0.9860
# [0.04905456677079201, 0.9860342144966125]

# %%
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# The            O	O
# United         B-org	B-org
# Nations        I-org	I-org
# has            O	O
# been           O	O
# under          O	O
# fire           O	O
# for            O	O
# failing        O	O
# to             O	O
# stop           O	O
# ongoing        O	O
# ethnic         O	O
# violence       O	O
# in             O	O
# Ituri          B-geo	B-geo
# .              O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
# sail           O	O
