# %% [markdown]
# ---
# title: Fashion MNIST
# categories: deep-learning
# date: 2020-12-15
# ---
#
#
# 数据集State-of-the-Art详见
#
# - [mnist](https://paperswithcode.com/sota/image-classification-on-mnist)
# - [fashion-mnist](https://paperswithcode.com/sota/image-classification-on-fashion-mnist)
# - [cifar-10](https://paperswithcode.com/sota/image-classification-on-cifar-10)
#
# ## 初始化
#
# 首先引入所用的包。然后是一些公共函数。下面代码比较长，可以先把函数的中文解释看过就好，细节忽略，后面用到再回来看。

# %%
import sys
from tensorflow.keras import Model, layers, regularizers, preprocessing

base_path = '/tf/eipi10/xuxiangwen.github.io/_notes/05-ai/54-tensorflow/code'
sys.path.append(base_path)

from image_classification import set_gpu_memory, lr_schedule, image_data_generator 
from image_classification import ImageClassificationHelper, ImageDataset

set_gpu_memory(1024)
model_results={}

# 代码自动重新加载
# %load_ext autoreload
# %autoreload 2

# #当module有新的方法的时候，需要运行下面方法。
# %reload_ext autoreload
# Out:
# set max gpu memory to 1024

# %% [markdown]
# 下面初始化模型运行的参数。

# %%
def image_data_generator():
    datagen = preprocessing.image.ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=30,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=False,
        # randomly flip images
        vertical_flip=False
    )    
    return datagen    

params = {
    'dataset_name': 'mnist-aug',
    'validation_percent': 0,    
    'use_data_augmentation': True,
    'augmentation_generator': image_data_generator(),   
    'batch_size': 32,    
    'epochs': 120,    
    'learning_rate':0.001,
    'dropout':0.1,
    'metrics':['accuracy'], 
    'use_lr_schedule': False,
    'lr_schedule': lr_schedule,
    'model_params':{
        'mlp':{'dropout':0.1},
        'lenet':{'dropout':0.1},
        'custom':{'dropout':0.2},
        'vgg':{'dropout':0.3},
        'resnet':{}
    }
}

helper = ImageClassificationHelper()
helper.set_params(params)
helper.set_model_results(model_results)
helper.set_data(ImageDataset(params))
# Out:
# load mnist-aug data from source
# train: (60000, 28, 28, 1) (60000,)
# test: (10000, 28, 28, 1) (10000,)
# create train, validation and test dataset

# %% [markdown]
# ## 数据
#
# MNIST数据集包含60,000张training图片和10,000张test图片，每张图片由$28\times28$ 个像素点构成，每个像素点用一个灰度值(0−255)表示。下面查看一下其中的图片。

# %%
images, labels = iter(helper.data.train_dataset).next()
helper.show_images(images, labels, x_num=4, y_num=8, figsize=(12, 6))

# %% [markdown]
# 然后看看做了data augmentation的图片。

# %%
images, labels = helper.data.train_dataset_aug.next()
helper.show_images(images, labels, x_num=4, y_num=8, figsize=(12, 6))

# %% [markdown]
# 下面来看看各个class的数据分布。可以看到各个数字的分布还是比较均匀的。

# %%
helper.plot_distribution()

# %% [markdown]
# ## MLP

# %%
def get_mlp(helper, name='mlp', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name) 
    print('dropout={}'.format(dropout))
    
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Flatten()(input)
    x = layers.Dense(128, activation='relu')(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model

model = get_mlp(helper)
model.summary()
# Out:
# dropout=0.1
# learning_rate=0.001
# checkpoint_path=./checkpoints/mnist-aug/mlp/checkpoint
# Model: "mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 下面来训练模型。

# %%
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 16:01:06,648: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.7166 - accuracy: 0.7802 - val_loss: 0.1970 - val_accuracy: 0.9451
# Epoch 2/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.3810 - accuracy: 0.8849 - val_loss: 0.1502 - val_accuracy: 0.9546
# Epoch 3/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.3155 - accuracy: 0.9046 - val_loss: 0.1299 - val_accuracy: 0.9609
# Epoch 4/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2895 - accuracy: 0.9108 - val_loss: 0.1161 - val_accuracy: 0.9632
# Epoch 5/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2714 - accuracy: 0.9179 - val_loss: 0.1089 - val_accuracy: 0.9664
# Epoch 6/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2553 - accuracy: 0.9226 - val_loss: 0.1022 - val_accuracy: 0.9668
# Epoch 7/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2508 - accuracy: 0.9250 - val_loss: 0.0987 - val_accuracy: 0.9698
# Epoch 8/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2399 - accuracy: 0.9274 - val_loss: 0.0923 - val_accuracy: 0.9713
# Epoch 9/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2308 - accuracy: 0.9293 - val_loss: 0.0860 - val_accuracy: 0.9731
# Epoch 10/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2266 - accuracy: 0.9316 - val_loss: 0.0842 - val_accuracy: 0.9744
# Epoch 11/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2218 - accuracy: 0.9322 - val_loss: 0.0815 - val_accuracy: 0.9741
# Epoch 12/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2218 - accuracy: 0.9327 - val_loss: 0.0887 - val_accuracy: 0.9719
# Epoch 13/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2180 - accuracy: 0.9338 - val_loss: 0.0855 - val_accuracy: 0.9706
# Epoch 14/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2114 - accuracy: 0.9354 - val_loss: 0.0812 - val_accuracy: 0.9746
# Epoch 15/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2153 - accuracy: 0.9345 - val_loss: 0.0805 - val_accuracy: 0.9748
# Epoch 16/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2089 - accuracy: 0.9357 - val_loss: 0.0867 - val_accuracy: 0.9712
# Epoch 17/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2044 - accuracy: 0.9388 - val_loss: 0.0720 - val_accuracy: 0.9776
# Epoch 18/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2047 - accuracy: 0.9392 - val_loss: 0.0794 - val_accuracy: 0.9757
# Epoch 19/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1977 - accuracy: 0.9398 - val_loss: 0.0737 - val_accuracy: 0.9771
# Epoch 20/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1981 - accuracy: 0.9408 - val_loss: 0.0728 - val_accuracy: 0.9768
# Epoch 21/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1984 - accuracy: 0.9402 - val_loss: 0.0767 - val_accuracy: 0.9748
# Epoch 22/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1916 - accuracy: 0.9424 - val_loss: 0.0769 - val_accuracy: 0.9744
# Epoch 23/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1945 - accuracy: 0.9414 - val_loss: 0.0751 - val_accuracy: 0.9769
# Epoch 24/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1948 - accuracy: 0.9420 - val_loss: 0.0753 - val_accuracy: 0.9761
# Epoch 25/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1911 - accuracy: 0.9420 - val_loss: 0.0770 - val_accuracy: 0.9755
# Epoch 26/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1925 - accuracy: 0.9416 - val_loss: 0.0701 - val_accuracy: 0.9780
# Epoch 27/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.
120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1353 - accuracy: 0.9584 - val_loss: 0.0567 - val_accuracy: 0.9816
# Epoch 118/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1358 - accuracy: 0.9592 - val_loss: 0.0543 - val_accuracy: 0.9827
# Epoch 119/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1336 - accuracy: 0.9594 - val_loss: 0.0549 - val_accuracy: 0.9826
# Epoch 120/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1332 - accuracy: 0.9587 - val_loss: 0.0541 - val_accuracy: 0.9825
# 2020-12-25 16:46:01,485: INFO: finish training [elapsed time: 2694.84 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.0548, Test Accuracy:98.35%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#      train_loss  train_accuracy  test_loss  test_accuracy  weight_number  \
# mlp    0.056438          0.9826   0.054761         0.9835         101770
#
#      train_time
# mlp      2694.0

# %% [markdown]
# 从上面的错误来看，模型对一些细节的判断不是很准。下面来尝试一下LeNet。
#
# ## LeNet
#
# ![image-20201019113632136](images/image-20201019113632136.png)
#
# LeNet诞生于1994年，是Yann LeCun等人提出的，是最早的卷积神经网络之一。在LeNet中，输入层是32×32的图片，而MNIST是28×28的图片，为了保持模型的结构不变，在第一个Conv2D设置参数padding=’same’。首先创建模型，并训练。

# %%
def get_lenet(helper, name='lenet', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name) 
    print('dropout={}'.format(dropout))
    
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Conv2D(6, (5, 5), activation='relu', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(16, (5, 5), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)   
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(120, activation='relu')(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(84, activation='relu')(x)   
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)  

    return model    

# 创建模型
model = get_lenet(helper)
model.summary()
# Out:
# dropout=0.1
# learning_rate=0.001
# checkpoint_path=./checkpoints/mnist-aug/lenet/checkpoint
# Model: "lenet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 6)         24
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 16)        64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 84)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,794
# Trainable params: 61,750
# Non-trainable params: 44
# _________________________________________________________________

# %% [markdown]
# 下面来训练模型。

# %%
# 训练
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 16:46:09,626: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.4655 - accuracy: 0.8498 - val_loss: 0.1007 - val_accuracy: 0.9671
# Epoch 2/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1917 - accuracy: 0.9409 - val_loss: 0.0985 - val_accuracy: 0.9696
# Epoch 3/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1571 - accuracy: 0.9520 - val_loss: 0.0535 - val_accuracy: 0.9832
# Epoch 4/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1369 - accuracy: 0.9577 - val_loss: 0.0481 - val_accuracy: 0.9847
# Epoch 5/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1261 - accuracy: 0.9625 - val_loss: 0.0434 - val_accuracy: 0.9861
# Epoch 6/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1183 - accuracy: 0.9646 - val_loss: 0.0389 - val_accuracy: 0.9886
# Epoch 7/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1111 - accuracy: 0.9662 - val_loss: 0.0353 - val_accuracy: 0.9882
# Epoch 8/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.
120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0512 - accuracy: 0.9845 - val_loss: 0.0231 - val_accuracy: 0.9925
# Epoch 100/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0532 - accuracy: 0.9834 - val_loss: 0.0208 - val_accuracy: 0.9925
# Epoch 101/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0528 - accuracy: 0.9836 - val_loss: 0.0192 - val_accuracy: 0.9933
# Epoch 102/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0522 - accuracy: 0.9835 - val_loss: 0.0232 - val_accuracy: 0.9922
# Epoch 103/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0503 - accuracy: 0.9848 - val_loss: 0.0234 - val_accuracy: 0.9923
# Epoch 104/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0526 - accuracy: 0.9842 - val_loss: 0.0193 - val_accuracy: 0.9943
# Epoch 105/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0538 - accuracy: 0.9842 - val_loss: 0.0248 - val_accuracy: 0.9913
# Epoch 106/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0538 - accuracy: 0.9836 - val_loss: 0.0205 - val_accuracy: 0.9929
# Epoch 107/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0513 - accuracy: 0.9839 - val_loss: 0.0238 - val_accuracy: 0.9919
# Epoch 108/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0516 - accuracy: 0.9845 - val_loss: 0.0191 - val_accuracy: 0.9934
# Epoch 109/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0507 - accuracy: 0.9847 - val_loss: 0.0219 - val_accuracy: 0.9933
# Epoch 110/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0504 - accuracy: 0.9850 - val_loss: 0.0194 - val_accuracy: 0.9944
# Epoch 111/120
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0513 - accuracy: 0.9842
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0513 - accuracy: 0.9843 - val_loss: 0.0177 - val_accuracy: 0.9948
# Epoch 112/120
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0447 - accuracy: 0.9865 - val_loss: 0.0165 - val_accuracy: 0.9942
# Epoch 113/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0444 - accuracy: 0.9862 - val_loss: 0.0167 - val_accuracy: 0.9944
# Epoch 114/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0434 - accuracy: 0.9869 - val_loss: 0.0166 - val_accuracy: 0.9953
# Epoch 115/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0421 - accuracy: 0.9871 - val_loss: 0.0165 - val_accuracy: 0.9949
# Epoch 116/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0411 - accuracy: 0.9876 - val_loss: 0.0170 - val_accuracy: 0.9941
# Epoch 117/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0441 - accuracy: 0.9865 - val_loss: 0.0173 - val_accuracy: 0.9938
# Epoch 118/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0415 - accuracy: 0.9876 - val_loss: 0.0161 - val_accuracy: 0.9946
# Epoch 119/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0426 - accuracy: 0.9875 - val_loss: 0.0174 - val_accuracy: 0.9942
# Epoch 120/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0406 - accuracy: 0.9873 - val_loss: 0.0160 - val_accuracy: 0.9948
# 2020-12-25 17:31:19,820: INFO: finish training [elapsed time: 2710.19 seconds]

# %% [markdown]
# 下面来评估模型并和mlp模型进行对比。

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.0166, Test Accuracy:99.53%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#        train_loss  train_accuracy  test_loss  test_accuracy  weight_number  \
# lenet    0.014347          0.9955   0.016634         0.9953          61750
# mlp      0.056438          0.9826   0.054761         0.9835         101770
#
#        train_time
# lenet      2710.0
# mlp        2694.0

# %% [markdown]
# 从上面的图中，可以看到，Lenet的参数只有mlp的60%，但其的准确率比mlp提升了差不多1%。上面最后一张图中，有三列，第一列是数字图片，它们是mlp中分错的数字，第二列是mlp中的分类，第三列是lenet中的分类，可以看到lenet的确学到了一些mlp中没有的模式。下面再来看看哪些数字在lenet也分错了。

# %% [markdown]
# 上图中，可以看到对于部分数字的识别，mlp甚至要更好一点啊，还有一些数字，则是一起都错了。
#
# ## Custom 1
#
# 下面自己定义一个模型，这个模型和lenet的主要区别是，增加了卷积的深度。

# %%
def get_custom1(helper, name='custom_cnn', dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name)
    print('dropout={}'.format(dropout))
        
    input = layers.Input(shape=helper.data.input_shape)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x) 
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Conv2D(64, (3, 3), activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    if dropout>0: x = layers.Dropout(dropout)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation='relu')(x)  
    if dropout>0: x = layers.Dropout(dropout)(x)
    x = layers.Dense(10)(x)  
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model   

# 创建模型
model = get_custom1(helper)
model.summary()
# Out:
# dropout=0.2
# learning_rate=0.001
# checkpoint_path=./checkpoints/mnist-aug/custom_cnn/checkpoint
# Model: "custom_cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 73,482
# Trainable params: 73,162
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# 可以发现参数的个数已经和mlp差不多了，下面来训练模型。

# %%
# 训练
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 17:31:34,128: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.4604 - accuracy: 0.8500 - val_loss: 0.0647 - val_accuracy: 0.9791
# Epoch 2/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1787 - accuracy: 0.9452 - val_loss: 0.0413 - val_accuracy: 0.9864
# Epoch 3/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1394 - accuracy: 0.9568 - val_loss: 0.0392 - val_accuracy: 0.9873
# Epoch 4/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1271 - accuracy: 0.9611 - val_loss: 0.0355 - val_accuracy: 0.9885
# Epoch 5/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1124 - accuracy: 0.9662 - val_loss: 0.0384 - val_accuracy: 0.9883
# Epoch 6/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1026 - accuracy: 0.9694 - val_loss: 0.0274 - val_accuracy: 0.9911
# Epoch 7/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0951 - accuracy: 0.9711 - val_loss: 0.0310 - val_accuracy: 0.9898
# Epoch 8/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0899 - accuracy: 0.9728 - val_loss: 0.0261 - val_accuracy: 0.9911
# Epoch 9/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0896 - accuracy: 0.9736 - val_loss: 0.0256 - val_accuracy: 0.9913
# Epoch 10/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0824 - accuracy: 0.9750 - val_loss: 0.0242 - val_accuracy: 0.9920
# Epoch 11/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0803 - accuracy: 0.9759 - val_loss: 0.0222 - val_accuracy: 0.9925
# Epoch 12/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0815 - accuracy: 0.9760 - val_loss: 0.0280 - val_accuracy: 0.9916
# Epoch 13/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0759 - accuracy: 0.9775 - val_loss: 0.0248 - val_accuracy: 0.9910
# Epoch 14/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0737 - accuracy: 0.9778 - val_loss: 0.0231 - val_accuracy: 0.9924
# Epoch 15/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0728 - accuracy: 0.9783 - val_loss: 0.0193 - val_accuracy: 0.9931
# Epoch 16/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.
120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0348 - accuracy: 0.9897 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 106/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0340 - accuracy: 0.9901 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 107/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0341 - accuracy: 0.9897 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 108/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0337 - accuracy: 0.9898 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 109/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0348 - accuracy: 0.9894 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 110/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0343 - accuracy: 0.9895 - val_loss: 0.0150 - val_accuracy: 0.9946
# Epoch 111/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0345 - accuracy: 0.9895 - val_loss: 0.0150 - val_accuracy: 0.9948
# Epoch 112/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0334 - accuracy: 0.9894 - val_loss: 0.0150 - val_accuracy: 0.9946
# Epoch 113/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0351 - accuracy: 0.9892 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 114/120
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0364 - accuracy: 0.9894 - val_loss: 0.0150 - val_accuracy: 0.9945
# Epoch 00114: early stopping
# 2020-12-25 18:14:58,142: INFO: finish training [elapsed time: 2604.01 seconds]

# %% [markdown]
# 下面来评估模型并和lenet模型进行对比。

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.0149, Test Accuracy:99.51%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#             train_loss  train_accuracy  test_loss  test_accuracy  \
# lenet         0.014347          0.9955   0.016634         0.9953
# custom_cnn    0.010507          0.9970   0.014906         0.9951
# mlp           0.056438          0.9826   0.054761         0.9835
#
#             weight_number  train_time
# lenet               61750      2710.0
# custom_cnn          73162      2604.0
# mlp                101770      2694.0

# %% [markdown]
# 可以看到custom1模型的效果比lenet有些许提升（经过多次测试，平均好0.1-0.3个百分点）。上面最后一幅图，也能看到custom1模型学习到了不少新的模式。下面来看错误分析。

# %% [markdown]
# ## VGG

# %%
def get_block(x, filters, conv_count, kernel_size=(3, 3), padding='same', use_bn=True, dropout=0, block_name='block'):
    for i in range(conv_count):
        x = layers.Conv2D(filters, kernel_size, padding=padding, name='{}_con{}'.format(block_name, i+1))(x)
        if use_bn: x = layers.BatchNormalization(name='{}_bn{}'.format(block_name, i+1))(x)
        x = layers.ReLU(name='{}_relu{}'.format(block_name, i+1))(x)
    x = layers.MaxPooling2D((2, 2), name='{}_maxpooling1'.format(block_name))(x)
    if dropout>0: x = layers.Dropout(dropout, name='{}_dropout1'.format(block_name))(x)
    return x
    
def get_vgg(helper, name='vgg',
              dense_layer_count=1, 
              dense_layer_units=128,
              conv_filters=64,
              block_count=3,
              use_bn=True,
              dropout=None):
    if dropout is None:
        dropout = helper.get_dropout(name)
    print('dropout={}'.format(dropout))
        
    input = layers.Input(shape=helper.data.input_shape)
    x = input    
    for i in range(block_count): 
        x = get_block(x, conv_filters, conv_count=2, use_bn=use_bn, dropout=dropout, 
                      block_name='block{}'.format(i+1))
        conv_filters = conv_filters*2
                    
    x = layers.Flatten()(x)
    for i in range(dense_layer_count):
        x = layers.Dense(128, activation='relu')(x)
        if dropout>0: x = layers.Dropout(dropout)(x)    
    x = layers.Dense(10)(x)
    
    model = Model(inputs=input, outputs=x, name=name) 
    helper.compile(model)
    return model


model = get_vgg(helper, dense_layer_count=1, block_count=3, name='vgg8')
model.summary()
# Out:
# dropout=0.3
# learning_rate=0.001
# checkpoint_path=./checkpoints/mnist-aug/vgg8/checkpoint
# Model: "vgg8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# block1_con1 (Conv2D)         (None, 28, 28, 64)        640
# _________________________________________________________________
# block1_bn1 (BatchNormalizati (None, 28, 28, 64)        256
# _________________________________________________________________
# block1_relu1 (ReLU)          (None, 28, 28, 64)        0
# _________________________________________________________________
# block1_con2 (Conv2D)         (None, 28, 28, 64)        36928
# _________________________________________________________________
# block1_bn2 (BatchNormalizati (None, 28, 28, 64)        256
# _________________________________________________________________
# block1_relu2 (ReLU)          (None, 28, 28, 64)        0
# _________________________________________________________________
# block1_maxpooling1 (MaxPooli (None, 14, 14, 64)        0
# _________________________________________________________________
# block1_dropout1 (Dropout)    (None, 14, 14, 64)        0
# _________________________________________________________________
# block2_con1 (Conv2D)         (None, 14, 14, 128)       73856
# _________________________________________________________________
# block2_bn1 (BatchNormalizati (None, 14, 14, 128)       512
# _________________________________________________________________
# block2_relu1 (ReLU)          (None, 14, 14, 128)       0
# _________________________________________________________________
# block2_con2 (Conv2D)         (None, 14, 14, 128)       147584
# _________________________________________________________________
# block2_bn2 (BatchNormalizati (None, 14, 14, 128)       512
# _________________________________________________________________
# block2_relu2 (ReLU)          (None, 14, 14, 128)       0
# _________________________________________________________________
# block2_maxpooling1 (MaxPooli (None, 7, 7, 128)         0
# _________________________________________________________________
# block2_dropout1 (Dropout)    (None, 7, 7, 128)         0
# _________________________________________________________________
# block3_con1 (Conv2D)         (None, 7, 7, 256)         295168
# _________________________________________________________________
# block3_bn1 (BatchNormalizati (None, 7, 7, 256)         1024
# _________________________________________________________________
# block3_relu1 (ReLU)          (None, 7, 7, 256)         0
# _________________________________________________________________
# block3_con2 (Conv2D)         (None, 7, 7, 256)         590080
# _________________________________________________________________
# block3_bn2 (BatchNormalizati (None, 7, 7, 256)         1024
# _________________________________________________________________
# block3_relu2 (ReLU)          (None, 7, 7, 256)         0
# _________________________________________________________________
# block3_maxpooling1 (MaxPooli (None, 3, 3, 256)         0
# _________________________________________________________________
# block3_dropout1 (Dropout)    (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               295040
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,444,170
# Trainable params: 1,442,378
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
# 训练
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 18:15:15,517: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.4405 - accuracy: 0.8598 - val_loss: 0.1016 - val_accuracy: 0.9720
# Epoch 2/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1556 - accuracy: 0.9567 - val_loss: 0.0399 - val_accuracy: 0.9887
# Epoch 3/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.1184 - accuracy: 0.9672 - val_loss: 0.0393 - val_accuracy: 0.9881
# Epoch 4/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0923 - accuracy: 0.9744 - val_loss: 0.0306 - val_accuracy: 0.9924
# Epoch 5/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0805 - accuracy: 0.9787 - val_loss: 0.0353 - val_accuracy: 0.9901
# Epoch 6/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.
120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0242 - accuracy: 0.9931 - val_loss: 0.0132 - val_accuracy: 0.9958
# Epoch 37/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0231 - accuracy: 0.9936 - val_loss: 0.0149 - val_accuracy: 0.9955
# Epoch 38/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0231 - accuracy: 0.9933 - val_loss: 0.0134 - val_accuracy: 0.9955
# Epoch 39/120
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9936
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0223 - accuracy: 0.9936 - val_loss: 0.0144 - val_accuracy: 0.9955
# Epoch 40/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0165 - accuracy: 0.9953 - val_loss: 0.0126 - val_accuracy: 0.9960
# Epoch 41/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 0.0113 - val_accuracy: 0.9960
# Epoch 42/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.0106 - val_accuracy: 0.9964
# Epoch 43/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.0113 - val_accuracy: 0.9964
# Epoch 44/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0138 - accuracy: 0.9962 - val_loss: 0.0117 - val_accuracy: 0.9968
# Epoch 45/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0124 - val_accuracy: 0.9966
# Epoch 46/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0096 - val_accuracy: 0.9969
# Epoch 47/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.0102 - val_accuracy: 0.9972
# Epoch 48/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0096 - val_accuracy: 0.9969
# Epoch 49/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0115 - val_accuracy: 0.9965
# Epoch 50/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0111 - val_accuracy: 0.9963
# Epoch 51/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0110 - val_accuracy: 0.9966
# Epoch 52/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0105 - val_accuracy: 0.9969
# Epoch 53/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0123 - val_accuracy: 0.9962
# Epoch 54/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0098 - val_accuracy: 0.9970
# Epoch 55/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0100 - val_accuracy: 0.9973
# Epoch 56/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0102 - val_accuracy: 0.9969
# Epoch 57/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 0.0105 - val_accuracy: 0.9969
# Epoch 58/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0123 - val_accuracy: 0.9965
# Epoch 59/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0123 - val_accuracy: 0.9961
# Epoch 60/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 61/120
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9969
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0134 - val_accuracy: 0.9967
# Epoch 62/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0111 - val_accuracy: 0.9971
# Epoch 63/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0102 - val_accuracy: 0.9970
# Epoch 64/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0104 - val_accuracy: 0.9969
# Epoch 65/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.0111 - val_accuracy: 0.9971
# Epoch 66/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0113 - val_accuracy: 0.9969
# Epoch 67/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.0118 - val_accuracy: 0.9969
# Epoch 68/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0108 - val_accuracy: 0.9967
# Epoch 69/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0114 - val_accuracy: 0.9970
# Epoch 70/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0115 - val_accuracy: 0.9970
# Epoch 71/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0116 - val_accuracy: 0.9969
# Epoch 72/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0104 - val_accuracy: 0.9970
# Epoch 73/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0106 - val_accuracy: 0.9968
# Epoch 74/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0100 - val_accuracy: 0.9968
# Epoch 75/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0110 - val_accuracy: 0.9966
# Epoch 76/120
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9979
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0110 - val_accuracy: 0.9966
# Epoch 77/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0111 - val_accuracy: 0.9968
# Epoch 78/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0104 - val_accuracy: 0.9968
# Epoch 79/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.0102 - val_accuracy: 0.9969
# Epoch 80/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0102 - val_accuracy: 0.9970
# Epoch 81/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0105 - val_accuracy: 0.9969
# Epoch 82/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0110 - val_accuracy: 0.9970
# Epoch 83/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0108 - val_accuracy: 0.9971
# Epoch 84/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0110 - val_accuracy: 0.9969
# Epoch 85/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0107 - val_accuracy: 0.9971
# Epoch 86/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0107 - val_accuracy: 0.9970
# Epoch 87/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0107 - val_accuracy: 0.9972
# Epoch 88/120
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0106 - val_accuracy: 0.9972
# Epoch 89/120
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0106 - val_accuracy: 0.9970
# Epoch 90/120
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0107 - val_accuracy: 0.9969
# Epoch 91/120
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9984
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0103 - val_accuracy: 0.9971
# Epoch 92/120
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0103 - val_accuracy: 0.9972
# Epoch 93/120
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0103 - val_accuracy: 0.9972
# Epoch 94/120
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0103 - val_accuracy: 0.9972
# Epoch 95/120
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0104 - val_accuracy: 0.9971
# Epoch 00095: early stopping
# 2020-12-25 19:01:58,801: INFO: finish training [elapsed time: 2803.28 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.0100, Test Accuracy:99.73%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#             train_loss  train_accuracy  test_loss  test_accuracy  \
# vgg8          0.003905          0.9989   0.009997         0.9973
# lenet         0.014347          0.9955   0.016634         0.9953
# custom_cnn    0.010507          0.9970   0.014906         0.9951
# mlp           0.056438          0.9826   0.054761         0.9835
#
#             weight_number  train_time
# vgg8              1442378      2803.0
# lenet               61750      2710.0
# custom_cnn          73162      2604.0
# mlp                101770      2694.0

# %% [markdown]
# ## Resnet
#
# 参考https://github.com/PacktPublishing/Advanced-Deep-Learning-with-Keras/blob/master/chapter2-deep-networks/resnet-cifar10-2.2.1.py

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = layers.Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
    else:
        if batch_normalization:
            x = layers.BatchNormalization()(x)
        if activation is not None:
            x = layers.Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10, name='resnet_v1'):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = layers.Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = layers.add([x, y])
            x = layers.Activation('relu')(x)

        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = layers.AveragePooling2D(pool_size=7)(x)
    y = layers.Flatten()(x)
    outputs = layers.Dense(num_classes, kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs, name=name)
    return model

def get_resnet_v1(helper, depth=32, name='resnet_v1'):       
    model = resnet_v1(helper.data.input_shape, depth=depth, name='{}_{}'.format(name, depth))
    helper.compile(model)
    return model

model = get_resnet_v1(helper, depth=20)
model.summary()
# Out:
# learning_rate=0.001
# checkpoint_path=./checkpoints/mnist-aug/resnet_v1_20/checkpoint
# Model: "resnet_v1_20"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 16)   160         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 28, 28, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 16)   0           activation[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 16)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 16)   64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 16)   0           activation_4[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 32)   4640        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 32)   544         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 32)   0           conv2d_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 14, 14, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 32)   0           activation_8[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 14, 14, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 14, 14, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 32)   0           activation_10[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 64)     18496       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 7, 7, 64)     36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 7, 7, 64)     2112        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, 7, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 64)     0           conv2d_21[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 7, 7, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 7, 7, 64)     256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 64)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 7, 7, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 7, 7, 64)     256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 64)     0           activation_14[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 7, 7, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 64)     256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, 7, 64)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 7, 7, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 64)     256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 64)     0           activation_16[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, 7, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10)           650         flatten_4[0][0]
# ==================================================================================================
# Total params: 274,154
# Trainable params: 272,778
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
history = helper.train(model, epochs=helper.epochs)
helper.plot_history(history)
# Out:
# 2020-12-25 19:02:19,282: INFO: start training
# stopping_patience=40
# learning_rate_patience=15
# using data augmentation
# Epoch 1/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.3519 - accuracy: 0.9378 - val_loss: 0.4196 - val_accuracy: 0.9051
# Epoch 2/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2057 - accuracy: 0.9744 - val_loss: 0.1978 - val_accuracy: 0.9734
# Epoch 3/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.1723 - accuracy: 0.9783 - val_loss: 0.1654 - val_accuracy: 0.9773
# Epoch 4/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1538 - accuracy: 0.9801 - val_loss: 0.1683 - val_accuracy: 0.9732
# Epoch 5/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1414 - accuracy: 0.9814 - val_loss: 0.1664 - val_accuracy: 0.9695
# Epoch 6/120
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.1305 - accuracy: 0.9827 - val_loss: 0.1508 - val_accuracy: 0.9732
# Epoch 7/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.1229 - accuracy: 0.9837 - val_loss: 0.0972 - val_accuracy: 0.9900
# Epoch 8/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1169 - accuracy: 0.9836 - val_loss: 0.1403 - val_accuracy: 0.9781
# Epoch 9/120
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.1117 - accuracy: 0.9845 - val_loss: 0.1143 - val_accuracy: 0.9838
# Epoch 10/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1056 - accuracy: 0.9854 - val_loss: 0.0894 - val_accuracy: 0.9895
# Epoch 11/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1055 - accuracy: 0.9851 - val_loss: 0.0940 - val_accuracy: 0.9874
# Epoch 12/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.1011 - accuracy: 0.9853 - val_loss: 0.0768 - val_accuracy: 0.9917
# Epoch 13/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0973 - accuracy: 0.9859 - val_loss: 0.0916 - val_accuracy: 0.9871
# Epoch 14/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0940 - accuracy: 0.9863 - val_loss: 0.0832 - val_accuracy: 0.9889
# Epoch 15/120
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.0908 - accuracy: 0.9870 - val_loss: 0.0824 - val_accuracy: 0.9886
# Epoch 16/120
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0890 - accuracy: 0.9872 - val_loss: 0.0717 - val_accuracy: 0.9916
# Epoch 17/120
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0873 - accuracy: 0.9871 - val_loss: 0.1319 - val_accuracy: 0.9715
# Epoch 18/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0856 - accuracy: 0.9873 - val_loss: 0.0774 - val_accuracy: 0.9903
# Epoch 19/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0823 - accuracy: 0.9878 - val_loss: 0.0760 - val_accuracy: 0.9887
# Epoch 20/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0819 - accuracy: 0.9882 - val_loss: 0.0753 - val_accuracy: 0.9900
# Epoch 21/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0815 - accuracy: 0.9880 - val_loss: 0.0632 - val_accuracy: 0.9929
# Epoch 22/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0808 - accuracy: 0.9877 - val_loss: 0.1029 - val_accuracy: 0.9808
# Epoch 23/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0777 - accuracy: 0.9882 - val_loss: 0.0828 - val_accuracy: 0.9854
# Epoch 24/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0774 - accuracy: 0.9884 - val_loss: 0.0702 - val_accuracy: 0.9898
# Epoch 25/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0767 - accuracy: 0.9880 - val_loss: 0.0621 - val_accuracy: 0.9932
# Epoch 26/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0749 - accuracy: 0.9884 - val_loss: 0.0703 - val_accuracy: 0.9895
# Epoch 27/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0750 - accuracy: 0.9885 - val_loss: 0.0627 - val_accuracy: 0.9912
# Epoch 28/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0743 - accuracy: 0.9883 - val_loss: 0.0783 - val_accuracy: 0.9865
# Epoch 29/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0733 - accuracy: 0.9888 - val_loss: 0.0787 - val_accuracy: 0.9871
# Epoch 30/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0722 - accuracy: 0.9887 - val_loss: 0.0895 - val_accuracy: 0.9824
# Epoch 31/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0713 - accuracy: 0.9893 - val_loss: 0.1110 - val_accuracy: 0.9766
# Epoch 32/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0687 - accuracy: 0.9897 - val_loss: 0.0603 - val_accuracy: 0.9914
# Epoch 33/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0687 - accuracy: 0.9898 - val_loss: 0.0803 - val_accuracy: 0.9858
# Epoch 34/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0706 - accuracy: 0.9884 - val_loss: 0.1516 - val_accuracy: 0.9663
# Epoch 35/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0697 - accuracy: 0.9893 - val_loss: 0.0654 - val_accuracy: 0.9909
# Epoch 36/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0685 - accuracy: 0.9895 - val_loss: 0.0580 - val_accuracy: 0.9930
# Epoch 37/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0670 - accuracy: 0.9902 - val_loss: 0.0635 - val_accuracy: 0.9894
# Epoch 38/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0672 - accuracy: 0.9897 - val_loss: 0.0967 - val_accuracy: 0.9803
# Epoch 39/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0690 - accuracy: 0.9886 - val_loss: 0.0698 - val_accuracy: 0.9876
# Epoch 40/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0656 - accuracy: 0.9896 - val_loss: 0.0598 - val_accuracy: 0.9916
# Epoch 41/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0666 - accuracy: 0.9895 - val_loss: 0.0523 - val_accuracy: 0.9938
# Epoch 42/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0649 - accuracy: 0.9900 - val_loss: 0.0571 - val_accuracy: 0.9918
# Epoch 43/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0664 - accuracy: 0.9897 - val_loss: 0.0633 - val_accuracy: 0.9901
# Epoch 44/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0647 - accuracy: 0.9897 - val_loss: 0.0562 - val_accuracy: 0.9922
# Epoch 45/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0636 - accuracy: 0.9900 - val_loss: 0.0660 - val_accuracy: 0.9890
# Epoch 46/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0634 - accuracy: 0.9899 - val_loss: 0.0595 - val_accuracy: 0.9908
# Epoch 47/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0664 - accuracy: 0.9892 - val_loss: 0.0740 - val_accuracy: 0.9868
# Epoch 48/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0634 - accuracy: 0.9898 - val_loss: 0.0575 - val_accuracy: 0.9912
# Epoch 49/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0635 - accuracy: 0.9898 - val_loss: 0.0637 - val_accuracy: 0.9897
# Epoch 50/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0632 - accuracy: 0.9901 - val_loss: 0.0783 - val_accuracy: 0.9854
# Epoch 51/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0630 - accuracy: 0.9903 - val_loss: 0.0693 - val_accuracy: 0.9872
# Epoch 52/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0631 - accuracy: 0.9901 - val_loss: 0.0558 - val_accuracy: 0.9910
# Epoch 53/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0627 - accuracy: 0.9900 - val_loss: 0.0569 - val_accuracy: 0.9916
# Epoch 54/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0612 - accuracy: 0.9897 - val_loss: 0.0839 - val_accuracy: 0.9857
# Epoch 55/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0627 - accuracy: 0.9898 - val_loss: 0.0625 - val_accuracy: 0.9893
# Epoch 56/120
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0633 - accuracy: 0.9897
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0633 - accuracy: 0.9897 - val_loss: 0.0551 - val_accuracy: 0.9919
# Epoch 57/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0500 - accuracy: 0.9932 - val_loss: 0.0463 - val_accuracy: 0.9935
# Epoch 58/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0463 - accuracy: 0.9940 - val_loss: 0.0425 - val_accuracy: 0.9947
# Epoch 59/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0432 - accuracy: 0.9943 - val_loss: 0.0385 - val_accuracy: 0.9952
# Epoch 60/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0426 - accuracy: 0.9941 - val_loss: 0.0393 - val_accuracy: 0.9951
# Epoch 61/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0412 - accuracy: 0.9939 - val_loss: 0.0396 - val_accuracy: 0.9947
# Epoch 62/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0396 - accuracy: 0.9945 - val_loss: 0.0368 - val_accuracy: 0.9952
# Epoch 63/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0392 - accuracy: 0.9947 - val_loss: 0.0405 - val_accuracy: 0.9942
# Epoch 64/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0386 - accuracy: 0.9942 - val_loss: 0.0354 - val_accuracy: 0.9950
# Epoch 65/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0371 - accuracy: 0.9947 - val_loss: 0.0413 - val_accuracy: 0.9916
# Epoch 66/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0371 - accuracy: 0.9945 - val_loss: 0.0348 - val_accuracy: 0.9944
# Epoch 67/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0357 - accuracy: 0.9950 - val_loss: 0.0341 - val_accuracy: 0.9941
# Epoch 68/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0355 - accuracy: 0.9949 - val_loss: 0.0338 - val_accuracy: 0.9946
# Epoch 69/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0351 - accuracy: 0.9944 - val_loss: 0.0424 - val_accuracy: 0.9927
# Epoch 70/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0343 - accuracy: 0.9948 - val_loss: 0.0363 - val_accuracy: 0.9937
# Epoch 71/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0357 - accuracy: 0.9944 - val_loss: 0.0330 - val_accuracy: 0.9951
# Epoch 72/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0333 - accuracy: 0.9950 - val_loss: 0.0361 - val_accuracy: 0.9944
# Epoch 73/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0338 - accuracy: 0.9950 - val_loss: 0.0328 - val_accuracy: 0.9948
# Epoch 74/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0331 - accuracy: 0.9949 - val_loss: 0.0321 - val_accuracy: 0.9943
# Epoch 75/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0346 - accuracy: 0.9948 - val_loss: 0.0322 - val_accuracy: 0.9944
# Epoch 76/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0339 - accuracy: 0.9944 - val_loss: 0.0353 - val_accuracy: 0.9940
# Epoch 77/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0340 - accuracy: 0.9941 - val_loss: 0.0308 - val_accuracy: 0.9958
# Epoch 78/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0330 - accuracy: 0.9948 - val_loss: 0.0368 - val_accuracy: 0.9929
# Epoch 79/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0324 - accuracy: 0.9949 - val_loss: 0.0333 - val_accuracy: 0.9943
# Epoch 80/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0317 - accuracy: 0.9950 - val_loss: 0.0338 - val_accuracy: 0.9942
# Epoch 81/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0321 - accuracy: 0.9949 - val_loss: 0.0326 - val_accuracy: 0.9949
# Epoch 82/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0312 - accuracy: 0.9953 - val_loss: 0.0315 - val_accuracy: 0.9941
# Epoch 83/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0333 - accuracy: 0.9946 - val_loss: 0.0334 - val_accuracy: 0.9939
# Epoch 84/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0325 - accuracy: 0.9948 - val_loss: 0.0309 - val_accuracy: 0.9948
# Epoch 85/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0311 - accuracy: 0.9950 - val_loss: 0.0392 - val_accuracy: 0.9933
# Epoch 86/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0323 - accuracy: 0.9947 - val_loss: 0.0325 - val_accuracy: 0.9945
# Epoch 87/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0310 - accuracy: 0.9951 - val_loss: 0.0333 - val_accuracy: 0.9930
# Epoch 88/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0320 - accuracy: 0.9945 - val_loss: 0.0308 - val_accuracy: 0.9943
# Epoch 89/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0314 - accuracy: 0.9948 - val_loss: 0.0303 - val_accuracy: 0.9956
# Epoch 90/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0310 - accuracy: 0.9951 - val_loss: 0.0328 - val_accuracy: 0.9944
# Epoch 91/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0300 - accuracy: 0.9954 - val_loss: 0.0341 - val_accuracy: 0.9943
# Epoch 92/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0302 - accuracy: 0.9951 - val_loss: 0.0300 - val_accuracy: 0.9950
# Epoch 93/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0312 - accuracy: 0.9948 - val_loss: 0.0443 - val_accuracy: 0.9911
# Epoch 94/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0303 - accuracy: 0.9951 - val_loss: 0.0343 - val_accuracy: 0.9935
# Epoch 95/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0310 - accuracy: 0.9951 - val_loss: 0.0297 - val_accuracy: 0.9950
# Epoch 96/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0308 - accuracy: 0.9947 - val_loss: 0.0283 - val_accuracy: 0.9956
# Epoch 97/120
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0321 - accuracy: 0.9947 - val_loss: 0.0315 - val_accuracy: 0.9946
# Epoch 98/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0302 - accuracy: 0.9951 - val_loss: 0.0323 - val_accuracy: 0.9939
# Epoch 99/120
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0300 - accuracy: 0.9952 - val_loss: 0.0322 - val_accuracy: 0.9938
# Epoch 100/120
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0310 - accuracy: 0.9948 - val_loss: 0.0319 - val_accuracy: 0.9938
# Epoch 101/120
# 1875/1875 [==============================] - 42s 23ms/step - loss: 0.0303 - accuracy: 0.9947 - val_loss: 0.0354 - val_accuracy: 0.9926
# Epoch 102/120
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0288 - accuracy: 0.9957 - val_loss: 0.0328 - val_accuracy: 0.9944
# Epoch 103/120
# 1875/1875 [==============================] - 43s 23ms/step - loss: 0.0312 - accuracy: 0.9946 - val_loss: 0.0314 - val_accuracy: 0.9952
# Epoch 104/120
# 1875/1875 [==============================] - 42s 23ms/step - loss: 0.0306 - accuracy: 0.9949 - val_loss: 0.0313 - val_accuracy: 0.9951
# Epoch 105/120
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0306 - accuracy: 0.9951 - val_loss: 0.0288 - val_accuracy: 0.9950
# Epoch 106/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0302 - accuracy: 0.9952 - val_loss: 0.0421 - val_accuracy: 0.9915
# Epoch 107/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0300 - accuracy: 0.9950 - val_loss: 0.0327 - val_accuracy: 0.9932
# Epoch 108/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0287 - accuracy: 0.9953 - val_loss: 0.0301 - val_accuracy: 0.9950
# Epoch 109/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0299 - accuracy: 0.9951 - val_loss: 0.0345 - val_accuracy: 0.9928
# Epoch 110/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0306 - accuracy: 0.9946 - val_loss: 0.0349 - val_accuracy: 0.9932
# Epoch 111/120
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9946
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0309 - accuracy: 0.9946 - val_loss: 0.0284 - val_accuracy: 0.9949
# Epoch 112/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0253 - accuracy: 0.9965 - val_loss: 0.0277 - val_accuracy: 0.9952
# Epoch 113/120
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0242 - accuracy: 0.9970 - val_loss: 0.0275 - val_accuracy: 0.9960
# Epoch 114/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0233 - accuracy: 0.9969 - val_loss: 0.0259 - val_accuracy: 0.9955
# Epoch 115/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0222 - accuracy: 0.9974 - val_loss: 0.0272 - val_accuracy: 0.9951
# Epoch 116/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0231 - accuracy: 0.9969 - val_loss: 0.0262 - val_accuracy: 0.9955
# Epoch 117/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0222 - accuracy: 0.9969 - val_loss: 0.0263 - val_accuracy: 0.9957
# Epoch 118/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0212 - accuracy: 0.9974 - val_loss: 0.0281 - val_accuracy: 0.9952
# Epoch 119/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0218 - accuracy: 0.9971 - val_loss: 0.0262 - val_accuracy: 0.9952
# Epoch 120/120
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0209 - accuracy: 0.9973 - val_loss: 0.0264 - val_accuracy: 0.9954
# 2020-12-25 20:31:16,667: INFO: finish training [elapsed time: 5337.38 seconds]

# %%
helper.model_summary(model, history=history)
# Out:
# ---------------------------------------- evaluate ----------------------------------------
# Test loss:0.0275, Test Accuracy:99.60%
# ---------------------------------------- confusion matrix ----------------------------------------
# ---------------------------------------- model improvement ----------------------------------------
# ---------------------------------------- error analysis ----------------------------------------
# -------------------------------------------------- all models --------------------------------------------------
#               train_loss  train_accuracy  test_loss  test_accuracy  \
# vgg8            0.003905          0.9989   0.009997         0.9973
# resnet_v1_20    0.020490          0.9979   0.027485         0.9960
# lenet           0.014347          0.9955   0.016634         0.9953
# custom_cnn      0.010507          0.9970   0.014906         0.9951
# mlp             0.056438          0.9826   0.054761         0.9835
#
#               weight_number  train_time
# vgg8                1442378      2803.0
# resnet_v1_20         272778      5337.0
# lenet                 61750      2710.0
# custom_cnn            73162      2604.0
# mlp                  101770      2694.0

# %% [markdown]
# ## 总结
