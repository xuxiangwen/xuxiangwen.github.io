# %% [markdown]
# # L2: Normalizing the Content

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
# !pip install panel python-dotenv python-pptx unstructured unstructured_client
# Out:
# Requirement already satisfied: panel in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dotenv in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (1.0.1)
# Requirement already satisfied: python-pptx in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (0.6.23)
# Requirement already satisfied: unstructured in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (0.13.3)
# Requirement already satisfied: unstructured_client in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (0.22.0)
# Requirement already satisfied: bokeh<3.5.0,>=3.4.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (3.4.1)
# Requirement already satisfied: param<3.0,>=2.0.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (2.1.0)
# Requirement already satisfied: pyviz-comms>=2.0.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (3.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (2024.4.0)
# Requirement already satisfied: markdown in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (3.6)
# Requirement already satisfied: markdown-it-py in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (3.0.0)
# Requirement already satisfied: linkify-it-py in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (0.4.0)
# Requirement already satisfied: requests in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (4.66.2)
# Requirement already satisfied: bleach in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (6.1.0)
# Requirement already satisfied: typing-extensions in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (4.11.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from panel) (2.2.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from python-pptx) (5.2.1)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from python-pptx) (10.3.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from python-pptx) (3.2.0)
# Requirement already satisfied: chardet in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: nltk in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (2.11.1)
# Requirement already satisfied: dataclasses-json in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (0.6.4)
# Requirement already satisfied: python-iso639 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (2024.2.7)
# Requirement already satisfied: langdetect in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: backoff in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: wrapt in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (2024.2.2)
# Requirement already satisfied: charset-normalizer>=3.2.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (3.3.2)
# Requirement already satisfied: deepdiff>=6.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (7.0.1)
# Requirement already satisfied: idna>=3.4 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (3.7)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (1.0.6)
# Requirement already satisfied: marshmallow>=3.19.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (3.21.1)
# Requirement already satisfied: mypy-extensions>=1.0.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (24.0)
# Requirement already satisfied: pypdf>=4.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (2.9.0.post0)
# Requirement already satisfied: six>=1.16.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (1.16.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (0.9.0)
# Requirement already satisfied: urllib3>=1.26.18 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from unstructured_client) (2.2.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from bokeh<3.5.0,>=3.4.0->panel) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from bokeh<3.5.0,>=3.4.0->panel) (1.2.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from bokeh<3.5.0,>=3.4.0->panel) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from bokeh<3.5.0,>=3.4.0->panel) (6.4)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from deepdiff>=6.0->unstructured_client) (4.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from pandas>=1.2->panel) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from pandas>=1.2->panel) (2024.1)
# Requirement already satisfied: colorama in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from tqdm>=4.48.0->panel) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: webencodings in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from linkify-it-py->panel) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: click in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from nltk->unstructured) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from nltk->unstructured) (2024.4.16)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\xu6\appdata\local\miniconda3\envs\dev\lib\site-packages (from Jinja2>=2.9->bokeh<3.5.0,>=3.4.0->panel) (2.1.5)

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - unstructured_client 可能是一个客户端对象，用于与处理非结构化数据的服务器进行通信。它可能有一些方法，例如上传非结构化数据、查询非结构化数据等。
# - unstructured 可能是一个类或对象，代表非结构化数据。这个对象可能包含数据本身以及与数据相关的元数据。

# %%
from IPython.display import JSON

import json

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared
from unstructured_client.models.errors import SDKError

from unstructured.partition.html import partition_html
from unstructured.partition.pptx import partition_pptx
from unstructured.staging.base import dict_to_elements, elements_to_json

# %%
from Utils import Utils
utils = Utils()

DLAI_API_KEY = utils.get_dlai_api_key()
DLAI_API_URL = utils.get_dlai_url()

s = UnstructuredClient(
    api_key_auth=DLAI_API_KEY,
    server_url=DLAI_API_URL,
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3d5eea15-7b6a-44d3-b7d6-7cec118eb8c9'>
#   <div id="aec7fbd7-147c-41f1-83d1-4f9d02c9a8bf" data-root-id="3d5eea15-7b6a-44d3-b7d6-7cec118eb8c9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8f5a4b84-b2dc-41ed-9240-6f676c25fa5b":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"3d5eea15-7b6a-44d3-b7d6-7cec118eb8c9"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"98724040-63de-43c7-9912-bf952c827718","attributes":{"plot_id":"3d5eea15-7b6a-44d3-b7d6-7cec118eb8c9","comm_id":"402abbb988544df89abfe55c6c1bfd24","client_comm_id":"197bc7dd9d0741a3ac0a99ec8733fe4c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"8f5a4b84-b2dc-41ed-9240-6f676c25fa5b","roots":{"3d5eea15-7b6a-44d3-b7d6-7cec118eb8c9":"aec7fbd7-147c-41f1-83d1-4f9d02c9a8bf"},"root_ids":["3d5eea15-7b6a-44d3-b7d6-7cec118eb8c9"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
import os 
os.getenv("DLAI_API_KEY"), os.getenv("DLAI_API_URL")
# Out:
# (None, None)

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access Utils File and Helper Functions:</b> To access helper functions and other related files for this notebook, 1) click on the <em>"View"</em> option on the top menu of the notebook and then 2) click on <em>"File Browser"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Example Document: Medium Blog HTML Page

# %%
from IPython.display import Image
Image(filename="images/HTML_demo.png", height=600, width=600)

# %%
filename = "example_files/medium_blog.html"
elements = partition_html(filename=filename)

# %%
element_dict = [el.to_dict() for el in elements]
example_output = json.dumps(element_dict[11:15], indent=2)
print(example_output)

# %%
JSON(example_output)

# %% [markdown]
# ## Example Doc: MSFT PowerPoint on OpenAI

# %%
Image(filename="images/pptx_slide.png", height=600, width=600)

# %%
filename = "example_files/msft_openai.pptx"
elements = partition_pptx(filename=filename)

# %%
element_dict = [el.to_dict() for el in elements]
JSON(json.dumps(element_dict[:], indent=2))

# %% [markdown]
# ## Example Document: PDF on Chain-of-Thought

# %%
Image(filename="images/cot_paper.png", height=600, width=600)

# %%
filename = "example_files/CoT.pdf"
with open(filename, "rb") as f:
    files=shared.Files(
        content=f.read(), 
        file_name=filename,
    )

req = shared.PartitionParameters(
    files=files,
    strategy='hi_res',
    pdf_infer_table_structure=True,
    languages=["eng"],
)
try:
    resp = s.general.partition(req)
    print(json.dumps(resp.elements[:3], indent=2))
except SDKError as e:
    print(e)

# %%
JSON(json.dumps(resp.elements, indent=2))

# %% [markdown]
# ## Work With Your Own Files

# %%
import panel as pn
#import param
from Utils import upld_file
pn.extension()

# %%
upld_widget = upld_file()
pn.Row(upld_widget.widget_file_upload)

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> 🖥 &nbsp; <b>Note:</b> If the file upload interface isn't functioning properly, the issue may be related to your browser version. In such a case, please ensure your browser is updated to the latest version, or try using a different browser.</p>

# %%
# !ls ./example_files

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Uploading Your Own File - Method 2:</b> To upload your own files, you can also 1) click on the <em>"View"</em> option on the top menu of the notebook and then 2) click on <em>"File Browser"</em>. Then 3) click on <em>"Upload"</em> button to upload your files. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>
